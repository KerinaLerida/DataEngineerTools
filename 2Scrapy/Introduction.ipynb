# %% [markdown]
# # Introduction
#
# [Scrapy](https://scrapy.org/) est un framework permettant de crawler des
# sites web et d'en extraire les données de façon structurée.
#
# ## Installation
#
# Nous travaillerons dans un environnement
# [Anaconda](https://www.anaconda.com/download/), déjà présent sur les
# machines de l'ESIEE. Sur vos machines personnelles, télécharger la
# distribution correspondant à la version la plus récente de Python.
#
# [Scrapy](https://scrapy.org/) ne fait pas partie de la distribution par
# défaut de Python et doit être installé manuellement. Ici, le package est
# déjà installé grâce à Pipenv.
#
# Si vous avez besoin d'installer dans un autre cadre.
#
# -   Avec **Pipenv** : `pipenv install scrapy`
# -   Avec **Anaconda** : `conda install -c conda-forge scrapy`
#
# Tester la réussite de l'opération dans un interpréteur Python. Avant
# installation:

# %%
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (2.11.0)
# Requirement already satisfied: Twisted<23.8.0,>=18.9.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (22.10.0)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (41.0.7)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (1.8.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (23.3.0)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: service-identity>=18.1.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (23.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (2.1.2)
# Requirement already satisfied: zope.interface>=5.1.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (6.1)
# Requirement already satisfied: protego>=0.1.15 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (0.8.0)
# Requirement already satisfied: setuptools in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (68.2.0)
# Requirement already satisfied: packaging in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (23.2)
# Requirement already satisfied: tldextract in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (5.1.1)
# Requirement already satisfied: lxml>=4.4.1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (4.9.3)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from cryptography>=36.0.0->scrapy) (1.16.0)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from service-identity>=18.1.0->scrapy) (23.1.0)
# Requirement already satisfied: pyasn1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.5.1)
# Requirement already satisfied: pyasn1-modules in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.3.0)
# Requirement already satisfied: constantly>=15.1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (23.10.4)
# Requirement already satisfied: incremental>=21.3.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: Automat>=0.8.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (4.8.0)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (1.0.4)
# Requirement already satisfied: idna in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from tldextract->scrapy) (3.6)
# Requirement already satisfied: requests>=2.1.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from tldextract->scrapy) (2.31.0)
# Requirement already satisfied: requests-file>=1.4 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from tldextract->scrapy) (3.13.1)
# Requirement already satisfied: six in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Automat>=0.8.0->Twisted<23.8.0,>=18.9.0->scrapy) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2023.11.17)

# %%
import scrapy

# %% [markdown]
# ## Architecture
#
# [Scrapy](https://scrapy.org/) est un framework comportant plusieurs
# composants.
#
# <img src="images/architecture.png" alt="image" class="align-center" />
#
# L'ensemble du processus est contrôlé par l'**engine** (les termes anglo
# saxons ont été retenus pour un meilleur référencement dans la
# [documentation officielle](https://docs.scrapy.org/en/latest/)).
#
# Le framework est articulé avec plusieurs composants qui gèrent chacun un
# rôle différent. Nous allons les détailler.
#
# -   Les **Spiders** : permettent de naviguer sur un site et de
#     référencer les règles d'extraction de la donnée.
# -   Les **Pipelines** : font le lien entre la donnée brute et des objets
#     structurés
# -   Les **Middlewares** : permettent d'effectuer des transformations sur
#     les objets ou sur les requêtes exécutées par l'engine.
# -   Le **Scheduler** : gère l'ordre et le timing des requêtes
#     effectuées.
#
# ## Fonctionnement
#
# [Scrapy](https://scrapy.org/) est entièrement organisé autour d'un
# composant central : l'*engine*.
#
# Le rôle de l'*engine* est de contrôler le flux de données entre les
# différents composants du système.
#
# 1.  En particulier, il est chargé de récupérer les *requests* définies
#     dans les *spiders*
# 2.  Ces *requests* sont ensuite fournies au *scheduler* qui se charge de
#     leur ordonnancement
# 3.  Les *requests* sont présentées selon cet ordonnancement à
#     l'*engine*...
# 4.  ... qui les transmet au *downloader*
# 5.  Le *downloader* effectue la *request* et transmet la *response* (le
#     contenu de la page web) à l'*engine*...
# 6.  ... puis l'envoie au *spider* pour traitement
# 7.  Le *spider* génére des *items* qui sont transmis à l'*engine*
# 8.  Les *items* sont ensuite poussés dans un pipeline pour nettoyage,
#     validation et stockage
#
# Ce processus est répété jusqu'à épuisement des requêtes.
#
# [Scrapy](https://scrapy.org/) est un [framework orienté
# événements](https://en.wikipedia.org/wiki/Event-driven_architecture)
# (basé sur [Twisted](https://twistedmatrix.com/)) permettant une
# programmation asynchrone (non bloquante). C'est particulièrement
# intéressant dans les opérations de scraping, puisque **le programme
# n'attend pas le résultat d'une requête pour en lancer une autre**.
#
# En effet, lorsque l'on sollicite une ressource (requête réseau, système
# de fichier, etc.) en mode bloquant, l'exécution du programme est
# suspendue le temps que la transaction avec la ressource se termine (par
# exemple le temps qu'une page web soit complètement téléchargée).
# L'intérêt de faire des appels non bloquants, c'est que l'on peut gérer
# de multiples téléchargements en parallèle, et que le programme peut
# continuer à tourner pendant ce temps.

# %% [markdown]
# # Un scraping élémentaire
#
# Avant de rentrer dans les détails du framework, nous allons mettre en
# oeuvre un premier script permettant de récupérer l'information présente
# sur [la page web](http://evene.lefigaro.fr/citations/winston-churchill)
# recensant les citations de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill).
#
# **Exercice**
#
# Examiner le code source de cette page avec l'inspecteur de votre
# navigateur. Identifier les éléments contenant l'information recherchée,
# ici la chaîne de caractères contenant la citation proprement dite.
#
# ## Le code source
#
# Le code utilisé est le suivant:

# %%
class ChurchillQuotesSpider(scrapy.Spider):
    name = "citations de Churchill"
    start_urls = ["http://evene.lefigaro.fr/citations/winston-churchill",]

    def parse(self, response):
        for cit in response.xpath('//div[@class="figsco__quote__text"]'):
            text_value = cit.xpath('a/text()').extract_first()
            
            cleaned_text = text_value.replace('“', '').replace('”', '')
            
            yield { 'text' : cleaned_text }

# %% [markdown]
# ## Le fonctionnement
#
# Le fonctionnement est le suivant:
#
# -   On importe le module [Scrapy](https://scrapy.org/) (3)
# -   et on définit une sous classe de `scrapy.Spider` (5)
# -   la variable `start_urls` contient la liste des pages à scraper (7)
# -   On redéfinit la méthode $parse$ dont la signature est définie dans
#     la classe mère (9)
# -   L'objet
#     [response](https://docs.scrapy.org/en/latest/topics/request-response.html#response-objects)
#     représente la réponse à la requête HTTP (l'attribut $text$ permet
#     d'accéder à son contenu). On recherche ensuite tous les containers
#     `<div>` identifiés dans l'exercice précédent. Ici la page est
#     particulièrement bien structurée et les citations disposent de leur
#     propre container, identifié par l'attribut `class` de valeur
#     `figsco__quote__text`. La sélection se fait par une expression
#     [XPath](https://en.wikipedia.org/wiki/XPath), un langage de
#     sélection de noeud dans un document XML (10). En langage naturel, la
#     requête pourrait se formuler : "On recherche tous les containers
#     `<div>` dont la valeur de l'attribut `class` est égal à
#     `figsco__quote__text`".
# -   Pour chaque résultat, on construit un dictionnaire dont la clé est
#     `text` et la valeur le contenu du lien `<a>`. Ce résultat est fourni
#     par un générateur ($yield$) (12).
#
# On lance le scraping depuis un terminal:

# %%
# !scrapy runspider citations_churchill_spider1.py
# Out:
# 2023-12-12 18:29:23 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2023-12-12 18:29:23 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
# 2023-12-12 18:29:23 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-12 18:29:23 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-12 18:29:23 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-12 18:29:23 [scrapy.extensions.telnet] INFO: Telnet Password: 0ab5383be7f30496
# 2023-12-12 18:29:23 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-12 18:29:23 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2023-12-12 18:29:23 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-12 18:29:23 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-12 18:29:23 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-12 18:29:23 [scrapy.core.engine] INFO: Spider opened
# 2023-12-12 18:29:23 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-12 18:29:23 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-12 18:29:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.'}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "Un conciliateur c'est quelqu'un qui nourrit un crocodile en espérant qu'il sera le dernier à être mangé."}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'Il est une bonne chose de lire des livres de citations, car les citations lorsqu’elles sont gravées dans la mémoire vous donnent de bonnes pensées.'}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "Je suis toujours prêt à apprendre, bien que je n'aime pas toujours qu'on me donne des leçons."}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "C'est une belle chose d'être honnête, mais il est également important d'avoir raison."}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'J’ai retiré plus de choses de l’alcool que l’alcool ne m’en a retirées.'}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "Pour s'améliorer, il faut changer. Donc, pour être parfait, il faut avoir changé souvent."}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "On considère le chef d'entreprise comme un homme à abattre, ou une vache à traire. Peu voient en lui le cheval qui tire le char."}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'En Angleterre, tout est permis, sauf ce qui est interdit. En Allemagne, tout est interdit, sauf ce qui est permis. En France, tout est permis, même ce qui est interdit. En U.R.S.S., tout est interdit, même ce qui est permis.'}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'On vit de ce que l’on obtient.\rOn construit sa vie sur ce que l’on donne.'}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "Si deux hommes ont toujours la même opinion, l'un d'eux est de trop."}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'Plus vous saurez regarder loin dans le passé, plus vous verrez loin dans le futur.'}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'L’Angleterre s’écroule dans l’ordre, et la France se relève dans le désordre.'}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "En avalant les méchantes paroles qu'on ne profère pas, on ne s'est jamais abîmé l'estomac."}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'Comité : Un groupe de personnes incapables de faire quoi que ce soit par elles-mêmes qui décident collectivement que rien ne peut être fait !'}
# 2023-12-12 18:29:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "Vous n'avez pas besoin d'être constamment le meilleur, vous avez simplement à l'être au bon moment."}
# 2023-12-12 18:29:23 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-12 18:29:23 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 245,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 14849,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.239367,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 12, 17, 29, 23, 917737, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 85057,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 16,
#  'log_count/DEBUG': 18,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 12, 12, 17, 29, 23, 678370, tzinfo=datetime.timezone.utc)}
# 2023-12-12 18:29:23 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On y trouve des informations sur les paramètres
# utilisés:

# %%
2023-11-29 11:10:07 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
2023-11-29 11:10:07 [scrapy.crawler] INFO: Overridden settings: {'SPIDER_LOADER_WARN_ONLY': True}
# Out:
#   Cell In[7], line 1
#     2023-11-29 11:10:07 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
#                      ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# les
# [extensions](https://docs.scrapy.org/en/latest/topics/extensions.html)
# ...:

# %%
2023-11-29 11:10:08 [scrapy.middleware] INFO: Enabled extensions:
['scrapy.extensions.corestats.CoreStats',
'scrapy.extensions.telnet.TelnetConsole',
'scrapy.extensions.logstats.LogStats']

# %% [markdown]
# [Les composants middleware
# downloader](https://docs.scrapy.org/en/latest/topics/downloader-middleware.html)
# ... :

# %%
2023-11-29 11:48:20 [scrapy.middleware] INFO: Enabled downloader middlewares:
['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
 'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
 'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
 'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
 'scrapy.downloadermiddlewares.retry.RetryMiddleware',
 'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
 'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
 'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
 'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
 'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
 'scrapy.downloadermiddlewares.stats.DownloaderStats']

# %% [markdown]
# Idem pour [les composants middleware
# spider](https://docs.scrapy.org/en/latest/topics/spider-middleware.html)
# ...:

# %%
2023-11-29 11:48:20 [scrapy.middleware] INFO: Enabled spider middlewares:
['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
 'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
 'scrapy.spidermiddlewares.referer.RefererMiddleware',
 'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
 'scrapy.spidermiddlewares.depth.DepthMiddleware']

# %% [markdown]
# Aucun
# [pipeline](https://docs.scrapy.org/en/latest/topics/item-pipeline.html)
# n'est activé :

# %%
2023-11-29 11:48:20 [scrapy.middleware] INFO: Enabled item pipelines:
[]

# %% [markdown]
# **Exercice**
#
# Identifier la position des [composants middleware
# downloader](https://docs.scrapy.org/en/latest/topics/downloader-middleware.html),
# des [composants middleware
# spider](https://docs.scrapy.org/en/latest/topics/spider-middleware.html)
# et du
# [pipeline](https://docs.scrapy.org/en/latest/topics/item-pipeline.html)
# dans $l'architecture <Introduction>$
#
# L'exécution du scraping proprement dit débute :

# %%
2023-11-29 11:50:45 [scrapy.core.engine] INFO: Spider opened
2023-11-29 11:50:45 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
2023-11-29 11:50:45 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# Out:
#   File "C:\Users\keren\AppData\Local\Temp\ipykernel_23300\4224969182.py", line 1
#     2018-01-10 17:21:05 [scrapy.core.engine] INFO: Spider opened
#           ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# La première URL est poussée par le scheduler:

# %%
2023-11-29 11:50:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)

# %% [markdown]
# ## Les résultats
#
# Les résultats sont fournis par le générateur défini dans la méthode
# $parse$ dans un dictionnaire. Ils contiennent le texte des citations
# dans la valeur de la clé `text` :

# %%
2023-11-29 11:50:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>

{'text': 'Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.'}
2023-11-29 11:50:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>

{'text': "Un conciliateur c'est quelqu'un qui nourrit un crocodile en espérant qu'il sera le dernier à être mangé."}

# %% [markdown]
# ## Les statistiques
#
# Une fois le scraping effectué, quelques statistiques sont affichées sur
# le terminal:

# %%
2023-11-29 11:50:45 [scrapy.core.engine] INFO: Closing spider (finished)
2023-11-29 11:50:45 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
{'downloader/request_bytes': 248,
 'downloader/request_count': 1,
 'downloader/request_method_count/GET': 1,
 'downloader/response_bytes': 14812,
 'downloader/response_count': 1,
 'downloader/response_status_count/200': 1,
 'elapsed_time_seconds': 0.216067,
 'finish_reason': 'finished',
 'finish_time': datetime.datetime(2023, 11, 29, 10, 50, 45, 685437),
 'httpcompression/response_bytes': 84969,
 'httpcompression/response_count': 1,
 'item_scraped_count': 16,
 'log_count/DEBUG': 18,
 'log_count/INFO': 10,
 'response_received_count': 1,
 'scheduler/dequeued': 1,
 'scheduler/dequeued/memory': 1,
 'scheduler/enqueued': 1,
 'scheduler/enqueued/memory': 1,
 'start_time': datetime.datetime(2023, 11, 29, 10, 50, 45, 469370)}
2023-11-29 11:50:45 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On observe notamment que notre code permet de récupérer la taille de la
# page web (17435 bytes), le temps d'exécution à partir des valeurs
# `finish_time` et `start_time`, le nombre d'items scrapés (16), etc...
#
# **Exercice**
#
# Les citations extraites sont elles toutes de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill) ? Il sera
# peut être nécessaire de modifier le sélecteur XPath. Nous verrons ça
# lorsque il faudra récupérer les données relative à l'auteur.
#
# ## Modifier les données
#
# Il est parfois nécessaire de faire un traitement sur les données
# scrapées, pour ajouter ou retirer de l'information.
#
# **Exercice**
#
# Retirer les caractères `“` et `”` qui délimitent la citation. Ces
# caractères sont identifiés en Unicode comme [LEFT DOUBLE QUOTATION
# MARK](http://www.fileformat.info/info/unicode/char/201c/index.htm) et
# [RIGHT DOUBLE QUOTATION
# MARK](http://www.fileformat.info/info/unicode/char/201d/index.htm).
#
# ## Plus de données
#
# Il est souvent nécessaire de récupérer plusieurs informations relatives
# à un même item. Dans cet exemple, il est judicieux d'associer à la
# citation le nom de son auteur, en allant chercher cette information au
# plus près du texte lui même.
#
# **Exercice**
#
# Examiner le code source de la page web et identifier la structuration de
# la donnée associée à l'auteur. En déduire l'expression XPath permettant
# de la récupérer. S'assurer que seules les citations de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill) sont
# extraites. Ajouter une clé `author` au dictionnaire retourné par le
# $yield$ dont la valeur est précisément la chaîne de caractères contenant
# l'auteur.
#
# Un exemple de dictionnaire retourné:

# %%
import scrapy

class ChurchillQuotesSpider(scrapy.Spider):
    name = "citations de Churchill"
    start_urls = ["http://evene.lefigaro.fr/citations/winston-churchill",]

    def parse(self, response):
        # Trouver l'auteur sur la page
        author = response.css('a[href="/celebre/biographie/winston-churchill-675.php"]::text').extract_first()

        for cit in response.xpath('//div[@class="figsco__quote__text"]'):
            text_value = cit.xpath('a//text()').extract_first()

            # Supprimer les caractères “ et ” avec la méthode replace
            cleaned_text = text_value.replace('“', '').replace('”', '')

            yield {'author': author, 'text': cleaned_text}

# %%
{   'text': "“Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.”", 
    'author': 'Winston Churchill'}
# Out:
# {'text': "“Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.”",
#  'author': 'Winston Churchill'}

# %% [markdown]
# Pour lancer l'exécution de la spider :
#
# > \$ scrapy runspider spiders/citations\_churchill\_spider2.py
#
# On peut aussi vouloir stocker les données extraites :
#
# > \$ scrapy runspider spiders/citations\_churchill\_spider2.py -o
# > data/citation.json -t json

# %% [markdown]
# # Votre premier projet
#
#
# Dans un premier temps vous devez créer un projet Scrapy avec la commande
# :

# %%
# !scrapy startproject newscrawler
# Out:
# Error: scrapy.cfg already exists in C:\Users\keren\Documents\ESIEE\E4\S1\P2\DSIA_4201C_DataEngineerTools\DataEngineerTools\2Scrapy\newscrawler

# %% [markdown]
# Cette commande va créer un dossier `monprojet` contenant les éléments
# suivants correspondant au squelette :

# %%
newscrawler/
    scrapy.cfg            # Options de déploiement

    newscrawler/             # Le module Python contenant les informations
        __init__.py

        items.py          # Fichier contenant les items

        middlewares.py    # Fichier contenant les middlewares

        pipelines.py      # Fichier contenant les pipelines

        settings.py       # Fichier contenant les paramètres du projet

        spiders/          # Dossier contenant toutes les spiders
            __init__.py
# Out:
#   Cell In[33], line 1
#     newscrawler/
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Votre première Spider
#
# Une Spider est une classe Scrapy qui permet de mettre en place toute
# l'architecture complexe vue dans l'introduction. Pour définir une
# spider, il vous faut hériter de la classe $scrapy.Spider$. La seule
# chose à faire est de définir la première requête à effectuer et comment
# suivre les liens. La Spider s'arrêtera lorsqu'elle aura parcouru tous
# les liens qu'on lui a demandé de suivre.
#
# Pour créer une Spider on utilise la syntaxe:

# %%
# !scrapy genspider <SPIDER_NAME> <DOMAIN_NAME>
# Out:
# < �tait inattendu.

# %% [markdown]
# Par exemple,

# %%
# !cd newscrawler && scrapy genspider lemonde lemonde.fr
# Out:
# Spider 'lemonde' already exists in module:
#   newscrawler.spiders.lemonde

# %% [markdown]
# Cette commande permet de créer une spider appelée `lemonde` pour scraper
# le domaine `lemonde.fr`. Cela crée le fichier Python
# `spiders/lemonde.py` suivant :

# %%
# %load newscrawler/newscrawler/spiders/lemonde.py
import scrapy


class LemondeSpider(scrapy.Spider):
    name = 'lemonde'
    allowed_domains = ['lemonde.fr']
    start_urls = ['http://lemonde.fr/']

    def parse(self, response):
        pass

# %% [markdown]
# Une bonne pratique pour commencer à développer une Spider est de passer
# par l'interface Shell proposée par Scrapy. Elle permet de récupérer un
# objet `Response` et de tester les méthodes de récupération des données.

# %% [markdown]
# # ATTENTION : Les commandes scrapy shell doivent être lancées dans un terminal

# %%
# !scrapy shell 'http://lemonde.fr'
# Out:
# 2023-12-12 18:31:22 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2023-12-12 18:31:22 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
# 2023-12-12 18:31:22 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-12 18:31:22 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-12 18:31:22 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-12 18:31:22 [scrapy.extensions.telnet] INFO: Telnet Password: aac0dba0815315cb
# 2023-12-12 18:31:22 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole']
# 2023-12-12 18:31:22 [scrapy.crawler] INFO: Overridden settings:
# {'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter',
#  'LOGSTATS_INTERVAL': 0}
# 2023-12-12 18:31:22 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-12 18:31:22 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-12 18:31:22 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-12 18:31:22 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-12 18:31:22 [scrapy.core.engine] INFO: Spider opened
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Scripts\scrapy.exe\__main__.py", line 7, in <module>
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\cmdline.py", line 161, in execute
#     _run_print_help(parser, _run_command, cmd, args, opts)
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\cmdline.py", line 114, in _run_print_help
#     func(*a, **kw)
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\cmdline.py", line 169, in _run_command
#     cmd.run(args, opts)
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\commands\shell.py", line 88, in run
#     shell.start(url=url, redirect=not opts.no_redirect)
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\shell.py", line 43, in start
#     self.fetch(url, spider, redirect=redirect)
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\shell.py", line 118, in fetch
#     response, spider = threads.blockingCallFromThread(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\twisted\internet\threads.py", line 120, in blockingCallFromThread
#     result.raiseException()
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\twisted\python\failure.py", line 504, in raiseException
#     raise self.value.with_traceback(self.tb)
# ValueError: invalid hostname: 'http

# %% [markdown]
# Pour les utilisateurs de windows il vous faut mettre des doubles quotes
# :

# %%
scrapy shell "http://lemonde.fr"
# Out:
#   Cell In[12], line 1
#     scrapy shell "http://lemonde.fr"
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# Scrapy lance un kernel Python

# %%
2018-12-02 16:05:50 [scrapy.utils.log] INFO: Scrapy 1.3.3 started (bot: newscrawler)
2018-12-02 16:05:50 [scrapy.utils.log] INFO: Overridden settings: {'BOT_NAME': 'newscrawler', 'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter', 'LOGSTATS_INTERVAL': 0, 'NEWSPIDER_MODULE': 'newscrawler.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['newscrawler.spiders']}
2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled extensions:
['scrapy.extensions.corestats.CoreStats',
'scrapy.extensions.telnet.TelnetConsole']
2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled downloader middlewares:
['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
'scrapy.downloadermiddlewares.retry.RetryMiddleware',
'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
'scrapy.downloadermiddlewares.stats.DownloaderStats']
2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled spider middlewares:
['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
'scrapy.spidermiddlewares.referer.RefererMiddleware',
'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
'scrapy.spidermiddlewares.depth.DepthMiddleware']
2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled item pipelines:
[]
2018-12-02 16:05:50 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
2018-12-02 16:05:50 [scrapy.core.engine] INFO: Spider opened
2018-12-02 16:05:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
2018-12-02 16:05:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/> (referer: None)
2018-12-02 16:05:54 [traitlets] DEBUG: Using default logger
2018-12-02 16:05:54 [traitlets] DEBUG: Using default logger
[s] Available Scrapy objects:
[s]   scrapy     scrapy module (contains scrapy.Request, scrapy.Selector, etc)
[s]   crawler    <scrapy.crawler.Crawler object at 0x10fc38c18>
[s]   item       {}
[s]   request    <GET https://www.lemonde.fr/>
[s]   response   <200 https://www.lemonde.fr/>
[s]   settings   <scrapy.settings.Settings object at 0x113bb0898>
[s]   spider     <DefaultSpider 'default' at 0x113e60cc0>
[s] Useful shortcuts:
[s]   fetch(url[, redirect=True]) Fetch URL and update local objects (by default, redirects are followed)
[s]   fetch(req)                  Fetch a scrapy.Request and update local objects
[s]   shelp()           Shell help (print this help)
[s]   view(response)    View response in a browser

# %% [markdown]
# Grâce à cette interface, vous avez accès à plusieurs objets comme la
# `Response`, la `Request`, la `Spider` par exemple. Vous pouvez aussi
# exécuter `view(response)` pour afficher ce que Scrapy récupère dans un
# navigateur.

# %%
In [1]: response
Out[1]: <200 https://www.lemonde.fr/>

In [3]: request
Out[3]: <GET https://www.lemonde.fr/>

In [4]: type(request)
Out[4]: scrapy.http.request.Request

In [5]: spider
Out[5]: <LemondeSpider 'lemonde' at 0x1080fccc0>

In [6]: type(spider)
Out[6]: monprojet.spiders.lemonde.LeMondeSpider

# %% [markdown]
# Ici on voit que la Spider est une instance de LemondeSpider. Lorsqu'on
# lance le $scrapy shell$ scrapy va chercher dans les spiders si une
# correspond au lien passé en paramètre, si oui , il l'utilise sinon une
# $DefaultSpider$ est instanciée.
#
# ## Vos premières requêtes
#
# On peut commencer à regarder comment extraire les données de la page web
# en utilisant le langage de requêtes proposé par Scrapy. Il existe deux
# types de requêtes : les requêtes `css` et `xpath`. Les requêtes `xpath`
# sont plus complexes mais plus puissantes que les requêtes `css`. Dans le
# cadre de ce tutorial, nous allons uniquement aborder les requêtes `css`,
# elles nous suffiront pour extraire les données dont nous avons besoin
# (en interne, Scrapy transforme les requêtes `css`en requêtes `xpath`.
#
# Que ce soit les requêtes `css` ou `xpath`, elles crééent des sélecteurs
# de différents types. Quelques exemples :
#
# Pour récupérer le titre d'une page :

# %%
In [1]: response.css('title')
Out[1]: [<Selector xpath='descendant-or-self::title' data='<title>Le Monde.fr - Actualités et Infos'>]

# %% [markdown]
# On récupère une liste de sélecteurs correspondant à la requête `css`
# appelée. La requête précédente était unique, d'autres requêtes moins
# restrictives permettent de récupérer plusieurs résultats. Par exemple
# pour rechercher l'ensemble des liens présents sur la page, on va
# rechercher les balises HTML `<a></a>`

# %%
In [5]: response.css("a")[0:10]
Out[5]:
[<Selector xpath='descendant-or-self::a' data='<a target="_blank" data-target="jelec-he'>,
<Selector xpath='descendant-or-self::a' data='<a href="/"> <div class="logo__lemonde l'>,
<Selector xpath='descendant-or-self::a' data='<a href="https://secure.lemonde.fr/sfuse'>,
<Selector xpath='descendant-or-self::a' data='<a href="https://abo.lemonde.fr/#xtor=CS'>,
<Selector xpath='descendant-or-self::a' data='<a href="/" class="Burger__right-arrow j'>,
<Selector xpath='descendant-or-self::a' data='<a href="/" class="Burger__right-arrow j'>,
<Selector xpath='descendant-or-self::a' data='<a href="#" class="js-dropdown Burger__r'>,
<Selector xpath='descendant-or-self::a' data='<a href="/mouvement-des-gilets-jaunes/" '>,
<Selector xpath='descendant-or-self::a' data='<a href="/carlos-ghosn/" data-suggestion'>,
<Selector xpath='descendant-or-self::a' data='<a href="/implant-files/" data-suggestio'>]

# %% [markdown]
# Pour récupérer le texte contenu dans les balises, on passe le paramètre
# `<TAG>::text`. Par exemple :

# %%
In [6]: response.css("title::text")
Out[6]: [<Selector xpath='descendant-or-self::title/text()' data='Le Monde.fr - Actualités et Infos en Fra'>]

# %% [markdown]
# ### Exercice
#
#   Comparer les résultats des deux requêtes `response.css('title')` et
# `response.css('title::text')`.
#
# => La première requête (response.css("title::text")) cible le texte à l'intérieur de la balise <title>, alors que la deuxième requête (response.css('title')) cible directement la balise <title> elle-même.
#
# Maintenant pour extraire les données des selecteurs on utilise l'une des
# deux méthodes suivantes : - `extract()` permet de récupérer une liste
# des données extraites de tous les sélecteurs - `extract_first()` permet
# de récupérer une `String` provenant du premier sélecteur de la liste.

# %%
In [7]: response.css('title::text').extract_first()
Out[7]: 'Le Monde.fr - Actualités et Infos en France et dans le monde'

# %% [markdown]
# On peut récupérer un attribut d'une balise avec la syntaxe
# `<TAG>::attr(<ATTRIBUTE_NAME>)` :
#
# Par exemple, les liens sont contenus dans un attribut `href`.

# %%
In [9]: response.css('a::attr(href)')[0:10]
Out[9]:
[<Selector xpath='descendant-or-self::a/@href' data='https://journal.lemonde.fr'>,
<Selector xpath='descendant-or-self::a/@href' data='/'>,
<Selector xpath='descendant-or-self::a/@href' data='https://secure.lemonde.fr/sfuser/connexi'>,
<Selector xpath='descendant-or-self::a/@href' data='https://abo.lemonde.fr/#xtor=CS1-454[CTA'>,
<Selector xpath='descendant-or-self::a/@href' data='/'>,
<Selector xpath='descendant-or-self::a/@href' data='/'>,
<Selector xpath='descendant-or-self::a/@href' data='#'>,
<Selector xpath='descendant-or-self::a/@href' data='/mouvement-des-gilets-jaunes/'>,
<Selector xpath='descendant-or-self::a/@href' data='/carlos-ghosn/'>,
<Selector xpath='descendant-or-self::a/@href' data='/implant-files/'>]

# %% [markdown]
# Comme vu précédemment, si on veut récupérer la liste des liens de la page on applique la méthode $extract()$

# %%
In [11]: response.css('a::attr(href)').extract()[0:10]
Out[11]:
['https://journal.lemonde.fr',
'/',
'https://secure.lemonde.fr/sfuser/connexion',
'https://abo.lemonde.fr/#xtor=CS1-454[CTA_LMFR]-[HEADER]-5-[Home]',
'/',
'/',
'#',
'/mouvement-des-gilets-jaunes/',
'/carlos-ghosn/',
'/implant-files/']

# %% [markdown]
# Les liens dans une page HTML sont souvent codés de manière relative par
# rapport à la page courante. La méthode de l'objet `Response` peut être
# utilisée pour recréer l'url complet.
#
# Un exemple sur le 4e élément :

# %%
In [14]: response.urljoin(response.css('a::attr(href)').extract()[8])
Out[14]: 'https://www.lemonde.fr/carlos-ghosn/'

# %% [markdown]
# alors que

# %%
In [15]: response.css('a::attr(href)').extract()[8]
Out[15]: '/carlos-ghosn/'

# %% [markdown]
# ### Exercice :
#
# Utiliser une liste compréhension pour transformer les 10
# premiers liens relatifs récupérés par la méthode `extract()` en liens
# absolus.
#
# Le résultat doit ressembler à :

# %%
relative_links = response.css('a::attr(href)').extract()[0:10]

# Transforme les liens relatifs en liens absolus avec response.urljoin
absolute_links = [response.urljoin(link) for link in relative_links]

# Affiche les liens absolus
print(absolute_links)

# %%
Out[23]: 
['https://journal.lemonde.fr',
'https://www.lemonde.fr/',
'https://secure.lemonde.fr/sfuser/connexion',
'https://abo.lemonde.fr/#xtor=CS1-454[CTA_LMFR]-[HEADER]-5-[Home]',
'https://www.lemonde.fr/',
'https://www.lemonde.fr/',
'https://www.lemonde.fr/',
'https://www.lemonde.fr/mouvement-des-gilets-jaunes/',
'https://www.lemonde.fr/carlos-ghosn/',
'https://www.lemonde.fr/implant-files/']

# %% [markdown]
# ## Des requêtes plus complexes
#
# On peut créer des requêtes plus complexes en utilisant à la fois la
# structuration HTML du document mais également la couche de présentation
# CSS. On utilise l'inspecteur de `Google Chrome` pour identifier le type
# et l'identifiant de la balise contenant les informations.
#
# Il y a au moins deux choses à savoir en `css` :
#
# -   Les `.` représentent les classes
# -   Les `#` représentent les id
#
# On se propose de récupérer toutes les sous-catégories de news dans la
# catégorie **Actualités**. On remarque en utilisant l'inspecteur
# d'élement de Chrome que toutes les catégories sont rangées dans une
# balise avec l'id $#nav-markup$ ensuite dans les classes $Nav__item$.
#
# A partir de cette structure HTML on peut construire la requête suivante
# pour récupérer la barre de navigation:

# %%
In [19]: response.css("#nav-markup")
Out[19]: [<Selector xpath="descendant-or-self::*[@id = 'nav-markup']" data='<ul id="nav-markup"> <li class="Nav__ite'>]

# %% [markdown]
# Ensuite pour récupérer les différentes catégories :

# %%
In [24]: response.css("#nav-markup .Nav__item")
Out[24]:
[<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item js-burger-to-show N'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--home Nav'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="/" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="/recherc'>]

# %% [markdown]
# On veut maintenant retourner tous les liens présents dans cette
# catégorie. On remarque qu'elle apparait à la 4eme position.

# %%
In [34]: response.css("#nav-markup .Nav__item")[3]
Out[34]: <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>

# %% [markdown]
# Maintenant pour récupérer tous les liens on peut chainer les requêtes.
# On accède alors à toutes les balises $a$.

# %%
In [35]: response.css("#nav-markup .Nav__item")[3].css("a")
Out[35]:
[<Selector xpath='descendant-or-self::a' data='<a href="#" class="js-dropdown Burger__r'>,
<Selector xpath='descendant-or-self::a' data='<a href="/mouvement-des-gilets-jaunes/" '>,
<Selector xpath='descendant-or-self::a' data='<a href="/carlos-ghosn/" data-suggestion'>,
<Selector xpath='descendant-or-self::a' data='<a href="/implant-files/" data-suggestio'>,
<Selector xpath='descendant-or-self::a' data='<a href="/climat/" data-suggestion>Clima'>,
<Selector xpath='descendant-or-self::a' data='<a href="/affaire-khashoggi/" data-sugge'>,
<Selector xpath='descendant-or-self::a' data='<a href="/emmanuel-macron/" data-suggest'>,
<Selector xpath='descendant-or-self::a' data='<a href="/ukraine/" data-suggestion>Ukra'>,
<Selector xpath='descendant-or-self::a' data='<a href="/russie/" data-suggestion>Russi'>,
<Selector xpath='descendant-or-self::a' data='<a href="/referendum-sur-le-brexit/" dat'>,
<Selector xpath='descendant-or-self::a' data='<a href="/harcelement-sexuel/" data-sugg'>,
<Selector xpath='descendant-or-self::a' data='<a href="/actualite-en-continu/" data-su'>,
<Selector xpath='descendant-or-self::a' data='<a href="/international/">International<'>,
<Selector xpath='descendant-or-self::a' data='<a href="/politique/">Politique</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/societe/">Société</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/les-decodeurs/">Les Décodeurs<'>,
<Selector xpath='descendant-or-self::a' data='<a href="/sport/">Sport</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/planete/">Planète</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/sciences/">Sciences</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/campus/">M Campus</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/afrique/">Le Monde Afrique</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/pixels/">Pixels</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/actualite-medias/">Médias</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/sante/">Santé</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/big-browser/">Big Browser</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/disparitions/">Disparitions</a'>]

# %% [markdown]
# Et pour récupérer les titres :

# %%
In [37]: response.css("#nav-markup .Nav__item")[3].css("a::text").extract()
Out[37]:
['Actualités',
'Mouvement des "gilets jaunes"',
'Carlos Ghosn',
'Implant Files',
'Climat',
'Affaire Khashoggi',
'Emmanuel Macron',
'Ukraine',
'Russie',
'Brexit',
'Harcèlement sexuel',
'Toute l’actualité en continu',
'International',
'Politique',
'Société',
'Les Décodeurs',
'Sport',
'Planète',
'Sciences',
'M Campus',
'Le Monde Afrique',
'Pixels',
'Médias',
'Santé',
'Big Browser',
'Disparitions']

# %% [markdown]
# Le shell Scrapy permet de définir la structure des requêtes et de
# s'assurer de la pertinence du résultat retourné. Pour automatiser le
# processus, il faut intégrer cette syntaxe au code Python des modules de
# spider définis dans la structure du projet.
#
# ## Intégration des requêtes
#
# Le squelette de la classe `LeMondeSpider` généré lors de la création du
# projet doit maintenant être enrichi. Par défaut 3 attributs et une
# méthode `parse()` ont été créés :
#
# -   `name` permet d'identifier sans ambiguïté la spider dans le code.
# -   `allowed_domain` permet de filtrer les requêtes et forcer la spider
#     à rester sur une liste de domaines.
# -   `starts_urls` est la liste des urls d'où la spider va partir pour
#     commencer son scraping.
# -   `parse()` est une méthode héritée de la classe `scrapy.Spider`. Elle
#     doit être redéfinie selon les requêtes que l'on doit effectuer et
#     sera appelée sur l'ensemble des urls contenus dans la liste
#     `starts_urls`.
#
# `parse()` est une fonction `callback` qui sera appelée automatiquement
# sur chaque objet `Response` retourné par la requête. Cette fonction est
# appelée de manière asynchrone. Plusieurs requêtes peuvent ainsi être
# lancées en parallèles sans bloquer le thread principal. L'objet
# `Response` passé en paramètre est le même que celui mis à disposition
# lors de l'exécution du Scrapy Shell.

# %%
def parse(self, response):
    title = response.css('title::text').extract_first()
    all_links = {
        name:response.urljoin(url) for name, url in zip(
        response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
        response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
    }
    yield {
        "title":title,
        "all_links":all_links
    }

# %% [markdown]
# La fonction est un générateur (`yield`) et retourne un dictionnaire
# composé de deux éléments :
#
# -   Le titre de la page;
# -   La liste des liens sortants sous forme de String.
#
# Pour le moment cette spider ne parcourt que la page d'accueil, ce qui
# n'est pas très productif.
#
# ## Votre premier scraper
#
# Récupérer les données sur un ensemble de pages webs nécessite d'explorer
# en profondeur la structure du site en suivant tout ou partie des liens
# rencontrés.
#
# La spider peut se `balader` sur un site assez efficacement. Il suffit de
# lui indiquer comment faire. Il faut spécifier à Scrapy de générer une
# requête vers une nouvelle page en construisant l'objet `Request`
# correspondant. Ce nouvel objet `Request` est alors inséré dans le
# scheduler de Scrapy. On peut évidemment générer plusieurs `Request`
# simultanément, correspondant par exemple, à différents liens sur la page
# courante. Ils sont insérés séquentiellement dans le scheduler.
#
# Pour cela on modifie la méthode `parse()` de façon à ce qu'elle retourne
# un objet `Request` pour chaque nouveau lien rencontré. On associe
# également à cet objet une fonction de callback qui déterminera la
# manière dont cette nouvelle page doit être extraite.
#
# Par exemple, pour que la spider continue dans les liens des différentes
# régions (pour l'instant la fonction de callback ne fait rien) :

# %%
# %load newscrawler/newscrawler/spiders/lemonde_v2.py
import scrapy
from scrapy import Request


class LemondeSpider(scrapy.Spider):
    name = "lemondev2"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name:response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        yield {
            "title":title,
            "all_links":all_links
        }

# %% [markdown]
# Pour lancer la spider

# %%
# !cd newscrawler && scrapy crawl lemondev2
# Out:
# 2023-12-05 13:42:14 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-12-05 13:42:14 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.6 (tags/v3.11.6:8b6ee5b, Oct  2 2023, 14:57:12) [MSC v.1935 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22631-SP0
# 2023-12-05 13:42:14 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-05 13:42:14 [py.warnings] WARNING: C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-05 13:42:15 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-05 13:42:15 [scrapy.extensions.telnet] INFO: Telnet Password: 05a96054988c7335
# 2023-12-05 13:42:15 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-05 13:42:15 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-12-05 13:42:15 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-05 13:42:15 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-05 13:42:15 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-05 13:42:15 [scrapy.core.engine] INFO: Spider opened
# 2023-12-05 13:42:15 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-05 13:42:15 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-05 13:42:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-05 13:42:15 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): publicsuffix.org:443
# 2023-12-05 13:42:15 [urllib3.connectionpool] DEBUG: https://publicsuffix.org:443 "GET /list/public_suffix_list.dat HTTP/1.1" 200 83860
# 2023-12-05 13:42:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2023-12-05 13:42:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr>
#
# {'title': 'Le Monde.fr - Actualités et Infos en France et dans le monde', 'all_links': {'Actualités': 'https://www.lemonde.fr', 'Guerre Israël-Hamas': 'https://www.lemonde.fr/attaque-du-hamas-contre-israel/', 'Guerre en Ukraine': 'https://www.lemonde.fr/crise-ukrainienne/', 'COP28': 'https://www.lemonde.fr/cop28/', 'Antisémitisme': 'https://www.lemonde.fr/antisemitisme/', 'Immigration et diversité': 'https://www.lemonde.fr/immigration-et-diversite/', "Procès d'Éric Dupond-Moretti": 'https://www.lemonde.fr/proces-eric-dupond-moretti/', 'Inflation': 'https://www.lemonde.fr/inflation/', 'Jeux olympiques de Paris 2024': 'https://www.lemonde.fr/jeux-olympiques-2024/', 'Chine': 'https://www.lemonde.fr/chine/', 'Toute l’actualité en continu': 'https://www.lemonde.fr/actualite-en-continu/', 'International': 'https://www.lemonde.fr/international/', 'Politique': 'https://www.lemonde.fr/politique/', 'Société': 'https://www.lemonde.fr/societe/', 'Planète': 'https://www.lemonde.fr/planete/', 'Climat': 'https://www.lemonde.fr/climat/', 'Le Monde Afrique': 'https://www.lemonde.fr/afrique/', 'Les Décodeurs': 'https://www.lemonde.fr/les-decodeurs/', 'Sport': 'https://www.lemonde.fr/sport/', 'Education': 'https://www.lemonde.fr/education/', 'M Campus': 'https://www.lemonde.fr/campus/', 'Santé': 'https://www.lemonde.fr/sante/', 'Intimités': 'https://www.lemonde.fr/intimites/', 'Sciences': 'https://www.lemonde.fr/sciences/', 'Pixels': 'https://www.lemonde.fr/pixels/', 'Disparitions': 'https://www.lemonde.fr/disparitions/', 'Le Fil Good': 'https://www.lemonde.fr/le-fil-good/', 'Podcasts': 'https://www.lemonde.fr/podcasts/', 'Le Monde & Vous': 'https://www.lemonde.fr/le-monde-et-vous/'}}
# 2023-12-05 13:42:15 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-05 13:42:15 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 440,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 81874,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 0.65995,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 5, 12, 42, 15, 947887, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 301840,
#  'httpcompression/response_count': 2,
#  'item_scraped_count': 1,
#  'log_count/DEBUG': 6,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 12, 5, 12, 42, 15, 287937, tzinfo=datetime.timezone.utc)}
# 2023-12-05 13:42:15 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On veut ensuite *entrer* dans les liens des différentes sous-catégories
# pour récupérer les articles. Pour cela, nous créons une méthode
# `parse_category()` prend en argument un objet `Response` qui sera la
# réponse correspondant aux liens des régions. On peut comme ceci
# traverser un site en définissant des méthodes différentes en fonction du
# type de contenu.
#
# Si la structure du site est plus profonde, on peut empiler autant de
# couches que souhaité.
#
# Quand on arrive sur une page d'une sous-catégorie, on peut vouloir
# récupérer tous les éléments de la page. Pour cela, on réutilise le
# scrapy Shell pour commencer le développement de la nouvelle méthode
# d'extraction.
#
# Par exemple pour la page `https://www.lemonde.fr/international/` :

# %%
scrapy shell 'https://www.lemonde.fr/international/'

# %% [markdown]
# Le fil des articles est stocké dans une balise avec la classe
# `class=river`.

# %%
In [3]: response.css(".river")
Out[3]:
[<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' fleuve ')]" data='<div class="fleuve">\n   <section>\n      '>,
<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' fleuve ')]" data='<div class="fleuve">\n</div>'>]

# %% [markdown]
# Pour récupérer chacun des articles, il faut adresser les balises
# `<article>` contenues dans le sélecteur:

# %%
In [4]: response.css(".river")[0].css(".teaser")
Out[4]:
[<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi mg'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>]

# %% [markdown]
# Comme précédemment, on peut empiler les sélecteurs `css` pour créer des
# requêtes plus complexes.
#
# Par exemple, pour récupérer tous les titres des différents articles :

# %%
In [8]: response.css(".river")[0].css(".teaser h3::text").extract()
Out[8]:
['Des dizaines de milliers de Géorgiens contestent dans la rue l’élection de Salomé Zourabichvili\r\n\r\n\r\n',
'A Budapest en Hongrie, un îlot décroissant pour favoriser la transition\r\n\r\n\r\n',
'En Israël, la police recommande l’inculpation de Nétanyahou dans une troisième enquête\r\n\r\n\r\n',
'Donald Trump veut «\xa0mettre fin\xa0» à l’Aléna rapidement\r\n\r\n\r\n',
'Le cauchemar de la «\xa0rééducation\xa0» des musulmans en Chine\r\n\r\n',
'\r\n',
'«\xa0AMLO\xa0» lance sa transformation du Mexique\r\n\r\n\r\n',
'«\xa0Paris brûle\xa0»\xa0: les médias étrangers relatent le «\xa0chaos\xa0» en marge des défilés des «\xa0gilets jaunes\xa0»\r\n\r\n\r\n',
'Andrés Manuel Lopez Obrador intronisé président du Mexique\r\n\r\n\r\n']

# %% [markdown]
# En HTML les données sont souvent de très mauvaise qualité. Il faut
# définir des méthodes permettant de les nettoyer pour être intégrées dans
# des bases de données.
#
# Par exemple, pour supprimer tous les espaces superflus :

# %%
def clean_spaces(string_):
    if string_ is not None: 
        return " ".join(string_.split())

# %% [markdown]
# Pour l'appliquer à tous les titres récupérés, on peut faire une list
# comprehension :

# %%
In [11]: [clean_spaces(article) for article in response.css(".river")[0].css(".teaser h3::text").extract()]  

Out[11]: ['Des dizaines de milliers de Géorgiens contestent dans la rue l’élection de Salomé Zourabichvili',
          'A Budapest en Hongrie, un îlot décroissant pour favoriser la transition', 
          'En Israël, la police recommande l’inculpation de Nétanyahou dans une troisième enquête',
          'Donald Trump veut « mettre fin » à l’Aléna rapidement', 
          'Le cauchemar de la « rééducation » des musulmans en Chine',
          '',
          '« AMLO » lance sa transformation du Mexique', 
          '« Paris brûle » : les médias étrangers relatent le « chaos » en marge des défilés des « gilets jaunes »',
          'Andrés Manuel Lopez Obrador intronisé président du Mexique'
         ]

# %% [markdown]
# La méthode précédente est intéressante si l'on ne recherche qu'une seule
# information par article.
#
# Par contre si l'on veut récupérer d'autres caractéristiques comme
# l'image ou la description par exemple, il est plus intéressant et plus
# efficace de récupérer l'objet et d'effectuer plusieurs traitements sur
# ce dernier.
#
# Chaque objet retourné par les requêtes `css` est un selecteur avec
# lequel on peut interagir.
#
# Par exemple pour récupérer le titre et le prix

# %%
In [25]: for article in response.css(".fleuve")[0].css("article"):
...:     title = clean_spaces(article.css("h3 a::text").extract_first())
...:     image = article.css("img::attr(data-src)").extract_first()
...:     description = article.css(".txt3::text").extract_first()
...:     print(f"Title {title} \nImage {image}\nDescription {description}\n ----")

# %%
Title Des dizaines de milliers de Géorgiens contestent dans la rue l’élection de Salomé Zourabichvili
Image https://s1.lemde.fr/image/2018/12/02/147x97/5391641_7_5874_les-partisans-de-l-opposant-grigol-vashadze_20d2e8693a49b83fd3c5578f7799ae9c.jpg
Description Elue présidente (un rôle essentiellement symbolique en Géorgie), l’ex-diplomate française, candidate du pouvoir, est contestée par l’opposition.
----
Title A Budapest en Hongrie, un îlot décroissant pour favoriser la transition
Image https://img.lemde.fr/2018/12/01/10/0/4214/2809/147/97/60/0/15b32ca_1EY4qISQ_BP4kPAh1fozJdXZ.jpg
Description Le centre logistique Cargonomia sert de matrice aux coopératives de l’économie durable et solidaire hongroise.
----
Title En Israël, la police recommande l’inculpation de Nétanyahou dans une troisième enquête
Image https://img.lemde.fr/2018/12/02/167/0/4207/2804/147/97/60/0/9e02c9b_3580d043ebc94b48b0f2cfef4e9a21e7-3580d043ebc94b48b0f2cfef4e9a21e7-0.jpg
Description Le premier ministre est soupçonné de corruption, fraude et abus de pouvoir, dans une affaire impliquant le groupe de télécoms israélien Bezeq.
----
Title Donald Trump veut « mettre fin » à l’Aléna rapidement
Image https://img.lemde.fr/2018/11/30/0/0/4861/3240/147/97/60/0/8b87184_5826023-01-06.jpg
Description Le président américain souhaite voir disparaître l’accord de libre-échange remontant à 1994 avec le Mexique et le Canada, qu’il qualifie régulièrement de « pire accord jamais signé », en faveur du nouveau traité négocié difficilement avec ses voisins nord-américains ces derniers mois.
----
Title Le cauchemar de la « rééducation » des musulmans en Chine
Image https://img.lemde.fr/2018/11/15/151/0/5000/3333/147/97/60/0/118c78f_248b226e6b91450aa8a68bd0ea5525a8-248b226e6b91450aa8a68bd0ea5525a8-0.jpg
Description Ouïgours et Kazakhs du Xinjiang... C’est toute une population musulmane que Pékin veut « rééduquer » en internant des centaines de milliers d’entre eux dans des camps.
----
Title « AMLO » lance sa transformation du Mexique
Image https://img.lemde.fr/2018/12/02/45/0/1497/998/147/97/60/0/a33c174_GGGTBR84_MEXICO-POLITICS-_1202_11.JPG
Description Education et santé gratuites, hausse du salaire minimum, bourses scolaires : à peine investi, le président Andres Manuel Lopez Obrador a listé les mesures qu’il entend prendre pour redresser le pays.
----
Title « Paris brûle » : les médias étrangers relatent le « chaos » en marge des défilés des « gilets jaunes »
Image https://img.lemde.fr/2018/12/02/361/0/598/396/147/97/60/0/ba46a6e_XVIt1Ffwm50iYBheccVieUQQ.jpg
Description Les images de destructions, d’échauffourées ou de voitures enflammées s’affichaient samedi soir en « une » de nombreux sites d’actualité internationaux.
----
Title Andrés Manuel Lopez Obrador intronisé président du Mexique
Image https://img.lemde.fr/2018/12/02/91/145/1346/897/147/97/60/0/877cd51_a4618baa8da2414bb62bab28a6d4c745-a4618baa8da2414bb62bab28a6d4c745-0.jpg
Description Le nouveau chef d’Etat a promis de lutter contre la corruption en menant une transformation « profonde et radicale » du pays.
----

# %% [markdown]
# ## Persistence des données
#
# Pour pouvoir stocker les informations que l'on récupère en parcourant un
# site il faut pouvoir les stocker. On utilise soit de simples
# dictionnaires Python, ou mieux des `scrapy.Item` qui sont des
# dictionnaires améliorés.
#
# Nous allons voir les deux façons de faire. On peut réécrire la méthode
# `parse_category()` pour lui faire retourner un dictionnaire
# correspondant à chaque offre rencontrée.

# %%
def parse_category(self, response):
    for article in response.css(".fleuve")[0].css("article"):
        title = self.clean_spaces(article.css("h3 a::text").extract_first())
        image = article.css("img::attr(data-src)").extract_first()
        description = article.css(".txt3::text").extract_first()
        yield {
            "title":title,
            "image":image,
            "description":description
        }

# %% [markdown]
# Si on combine tout dans la spider :

# %%
# %load newscrawler/newscrawler/spiders/lemonde_v3.py
import scrapy
from scrapy import Request


class LemondeSpider(scrapy.Spider):
    name = "lemondev3"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name:response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        for link in all_links.values():
            yield Request(link, callback=self.parse_category)
            
    def parse_category(self, response):
        for article in response.css(".river")[0].css(".teaser"):
            title = self.clean_spaces(article.css("h3::text").extract_first())
            image = article.css("img::attr(data-src)").extract_first()
            description = article.css(".txt3::text").extract_first()
            yield {
                "title":title,
                "image":image,
                "description":description
            }

    def clean_spaces(self, string):
        if string:
            return " ".join(string.split())

# %% [markdown]
# On peut maintenant lancer notre spider avec la commande suivante :

# %%
scrapy crawl <NAME>

# %% [markdown]
# `scrapy crawl` permet de démarrer le processus en allant chercher la
# classe `scrapy.Spider` dont l'attribut `name` = &lt;NAME&gt;.
#
# Par exemple, pour la spider `LeMondeSpider` :

# %%
# !cd newscrawler && scrapy crawl lemondev3
# Out:
# 2023-12-05 13:43:22 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-12-05 13:43:22 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.6 (tags/v3.11.6:8b6ee5b, Oct  2 2023, 14:57:12) [MSC v.1935 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22631-SP0
# 2023-12-05 13:43:22 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-05 13:43:22 [py.warnings] WARNING: C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-05 13:43:22 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-05 13:43:22 [scrapy.extensions.telnet] INFO: Telnet Password: 6f28cae7c06cd1e4
# 2023-12-05 13:43:22 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-05 13:43:22 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-12-05 13:43:22 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-05 13:43:22 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-05 13:43:22 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-05 13:43:22 [scrapy.core.engine] INFO: Spider opened
# 2023-12-05 13:43:22 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-05 13:43:22 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-05 13:43:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-05 13:43:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2023-12-05 13:43:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\ESIEE\E4\S1\P2\DSIA_4201C_DataEngineerTools\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde_v3.py", line 21, in parse_category
#     for article in response.css(".river")[0].css(".teaser"):
#                    ~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/disparitions/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-fil-good/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sante/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/pixels/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/intimites/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sciences/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/climat/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/planete/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sport/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/podcasts/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort de Léonard Gianadda, entrepreneur suisse, mécène et bâtisseur', 'image': 'https://img.lemde.fr/2023/12/04/0/0/3000/2000/110/73/60/0/5efbe22_1701723312772-sipa-00474902-000005.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/actualite-en-continu/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/societe/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Mort à 90 ans de Juanita Castro, opposante en exil et sœur des dirigeants cubains Fidel et Raul Castro', 'image': 'https://img.lemde.fr/2023/12/05/288/0/2100/1400/110/73/60/0/3c9b2d5_1701737690809-castro-juanita-tcm7-18080.jpeg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Tai-Luc, le chanteur de La Souris déglinguée, est mort', 'image': 'https://img.lemde.fr/2023/12/04/13/0/4895/3263/110/73/60/0/c4cb5dc_1701677516319-sipa-00712886-000003.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Sandra Day O’Connor, première femme à siéger à la Cour suprême des Etats-Unis, est morte', 'image': 'https://img.lemde.fr/2023/12/01/0/0/3693/2462/110/73/60/0/dd586db_f3f4bf744d3343809a233dcb4f921843-1-36dcb7ffa27c498cac59d4afdc869067.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': '« Kissinger était-il cet oracle géopolitique infaillible dont il faudrait maintenant honorer la mémoire et suivre l’exemple ? »', 'image': 'https://img.lemde.fr/2023/12/01/264/0/3000/2000/110/73/60/0/ac97690_69e493e2638c48a8b3183722c0f67756-0-9b072590a86740e6a0806e35b96af4a1.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort d’Alistair Darling, l’homme du sauvetage des banques britanniques de 2008', 'image': 'https://img.lemde.fr/2023/11/30/50/0/3200/2133/110/73/60/0/1fb03b8_2023-11-30t125415z-1865467417-rc2nn4ac3smj-rtrmadp-3-people-alistair-darling.JPG', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort d’Elliott Erwitt, photographe de la comédie humaine… et canine', 'image': 'https://img.lemde.fr/2023/12/01/1116/0/3552/2368/110/73/60/0/3c9bc92_1701436499771-nyc17561.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Elliott Erwitt, photographe emblématique de l’agence Magnum, est mort', 'image': 'https://img.lemde.fr/2023/11/30/0/0/5184/3456/110/73/60/0/0e37073_1701376969575-000-par8028279.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort de Michèle Rivasi, figure du mouvement antinucléaire puis d’Europe Ecologie-Les Verts', 'image': 'https://img.lemde.fr/2023/11/30/0/0/5184/3456/110/73/60/0/ea872f9_1701354971036-998172.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Vassilis Vassilikos, auteur du roman-réquisitoire « Z », est mort', 'image': 'https://img.lemde.fr/2023/11/30/0/0/5725/3817/110/73/60/0/fad0268_5002229-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Shane MacGowan, chanteur des Pogues, « perdant magnifique », est mort', 'image': 'https://img.lemde.fr/2023/11/30/0/4/4920/3280/110/73/60/0/aed8168_2023-11-30t122120z-2143159505-rc2nn4aoknbk-rtrmadp-3-people-shane-macgowan.JPG', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'L’ex-secrétaire d’Etat américain et Prix Nobel de la paix Henry Kissinger est mort', 'image': 'https://img.lemde.fr/2014/10/01/0/30/5169/3446/110/73/60/0/669b2f3_4c993850e1e14291be49de97981eb7d2-4c993850e1e14291be49de97981eb7d2-0.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Mort d’Henry Kissinger : les zones d’ombre d’une éminence grise', 'image': 'https://img.lemde.fr/2023/11/30/7/0/3500/2333/110/73/60/0/ba818ea_2023-11-30t014456z-629928293-rc2dn4ayz79j-rtrmadp-3-people-henry-kissinger.JPG', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Henry Kissinger, ancien secrétaire d’Etat et figure historique de la diplomatie américaine, est mort à 100 ans', 'image': 'https://img.lemde.fr/2016/01/13/282/0/6229/4152/110/73/60/0/488f40d_8569-o5gqlv.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': '« De Le Roy Ladurie, retenons cette incomparable langue, portant haut l’audace d’être historien »', 'image': 'https://img.lemde.fr/2023/11/23/0/22/2556/1704/110/73/60/0/2526799_5947194-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Gérard Collomb salué comme un « homme d’Etat » par Emmanuel Macron lors de ses obsèques à Lyon', 'image': 'https://img.lemde.fr/2023/11/29/0/0/5616/3744/110/73/60/0/f01c16b_5990652-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'L’eurodéputée écologiste Michèle Rivasi est morte', 'image': 'https://img.lemde.fr/2016/10/29/0/4/4248/2832/110/73/60/0/4d365d8_5011171-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': '« Face aux périls qui menacent nos sociétés, le message d’Emmanuel Le Roy Ladurie reste d’actualité »', 'image': 'https://img.lemde.fr/2023/11/23/0/0/4368/2912/110/73/60/0/8ea14a2_5947196-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort d’Edgar Reichmann, écrivain et ancien collaborateur du « Monde des livres »', 'image': 'https://img.lemde.fr/2023/11/27/135/0/480/320/110/73/60/0/36aa72d_1701100711203-img-5973-1.JPG', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort d’Aldo Lado, maître oublié du cinéma populaire italien', 'image': 'https://img.lemde.fr/2023/11/27/495/0/3391/2260/110/73/60/0/8d73cfe_1701077473120-bal-3511447.JPG', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Alain Corbin : « Emmanuel Le Roy Ladurie était la personnification de l’historien innovant, sans cesse en quête d’objets encore inédits »', 'image': 'https://img.lemde.fr/2023/11/23/0/33/2434/1623/110/73/60/0/bf6b847_5947193-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Robert Darnton, historien : « Avec Emmanuel Le Roy Ladurie, j’ai découvert une histoire sociale, tout aussi scientifique qu’humaine »', 'image': 'https://img.lemde.fr/2023/11/23/0/4/4248/2832/110/73/60/0/4887ca6_5947195-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Mort de Gérard Collomb : ses funérailles auront lieu mercredi à Lyon ; Emmanuel Macron salue un « ami cher » et « un homme d’Etat qui incarnait l’autorité républicaine »', 'image': 'https://img.lemde.fr/2023/11/25/0/274/2962/1975/110/73/60/0/12e0d58_5965230-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Gérard Collomb, ancien maire de Lyon et ministre de l’intérieur, est mort à l’âge de 76 ans', 'image': 'https://img.lemde.fr/2023/05/02/686/0/3932/2621/110/73/60/0/7776263_1683040182823-gerard-collomb-l1040056-modifier-3.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La chanteuse et actrice Rona Hartner, connue pour son rôle dans « Gadjo Dilo » avec Romain Duris, est morte', 'image': 'https://img.lemde.fr/2023/11/23/464/0/2377/1584/110/73/60/0/140704a_5948912-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort de Jacques Vallet, écrivain et fondateur de la revue « Le fou parle »', 'image': 'https://img.lemde.fr/2023/11/23/249/0/2362/1574/110/73/60/0/6426786_1700729281300-bal-4380533.JPG', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Le Roy Ladurie : « Braudel fut un peu jaloux des centaines de milliers d’exemplaires de mon “Montaillou” »', 'image': None, 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Emmanuel Le Roy Ladurie, le moissonneur d’archives derrière « Montaillou » et « L’Histoire du climat depuis l’an mil »', 'image': 'https://img.lemde.fr/2018/08/14/115/176/3720/2480/110/73/60/0/285107a_t6Sll9np7Ayjhf0lCrhlk30E.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Emmanuel Le Roy Ladurie : mort d’un pionnier de l’histoire du climat', 'image': 'https://img.lemde.fr/2018/08/14/396/0/1633/1087/110/73/60/0/41450cf_nt1dL4pCEc1zUHVK5GRyAVtI.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'L’historien Emmanuel Le Roy Ladurie est mort', 'image': 'https://img.lemde.fr/2018/05/22/484/0/2362/1567/110/73/60/0/af4a49f_10003-1ug57gd.l3hy.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort de Claude Fléouter, journaliste musical, réalisateur et producteur', 'image': 'https://img.lemde.fr/2023/11/20/0/30/900/600/110/73/60/0/1e9395f_1700467815271-63e41694199eb9227f2c714a.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort de Rosalynn Carter, épouse du président américain Jimmy Carter et première dame très politique', 'image': 'https://img.lemde.fr/2023/11/19/0/0/2469/1646/110/73/60/0/4e3a7fe_674cbce379d34819a1fd8f3820dcb541-0-e609776c53994e5fa26ee18773acfc8b.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'L’autrice britannique A.S. Byatt ne cherchera plus « la juste relation entre les mots et les choses »', 'image': 'https://img.lemde.fr/2023/11/18/5/0/3872/2581/110/73/60/0/577f22f_1700315042224-aurimages-art-histoire-aurimages-0032930-193.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Daisaku Ikeda, dirigeant adulé et controversé de l’organisation bouddhiste japonaise Soka Gakkai, est mort', 'image': 'https://img.lemde.fr/2023/11/18/923/0/5000/3333/110/73/60/0/60b3c53_1700306269048-2023-11-18t111353z-1850906992-mt1yomiur000gaxek8-rtrmadp-3-soka-gakkai-honorary-president-daisaku-ikeda-passes-away.JPG', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Henri Stambouli, ancien joueur et entraîneur de l’OM, est mort à 62 ans', 'image': 'https://img.lemde.fr/2023/11/17/30/0/2100/1400/110/73/60/0/50f7b36_5901035-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Bob De Groot, cocréateur de génie de la BD « Léonard », est mort', 'image': 'https://img.lemde.fr/2023/11/17/51/0/546/364/110/73/60/0/1ebe223_1700236926171-groot4.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Le pianiste français Claude Kahn est mort à l’âge de 88 ans', 'image': 'https://img.lemde.fr/2023/11/17/837/0/3744/2496/110/73/60/0/b10bca0_1700222060732-000-8rp2jw.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Karl Tremblay, le chanteur québécois des Cowboys fringants, est mort', 'image': 'https://img.lemde.fr/2023/11/15/1043/739/3006/2004/110/73/60/0/6899b7b_1700092773964-epalivefour197363.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort de Michel Ciment, « le plus raffiné, le plus érudit, le moins blasé » des critiques de cinéma', 'image': 'https://img.lemde.fr/2023/11/14/237/0/3865/2576/110/73/60/0/6bc2f68_1699971350238-opaleplus-lxa1280-05.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Michel Ciment, critique de cinéma, est mort à l’âge de 85 ans', 'image': 'https://img.lemde.fr/2023/11/14/0/0/511/341/110/73/60/0/405a079_1699920234381-000-1go8i9-1.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort de Jean-Louis Aragon, ancien journaliste au « Monde », technicien et pédagogue de talent', 'image': 'https://img.lemde.fr/2023/11/13/135/0/833/555/110/73/60/0/39f6cf0_1699896720798-aragon.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La créatrice Maria Pergay, spécialiste du mobilier en Inox, est morte', 'image': 'https://img.lemde.fr/2023/11/13/2149/164/3665/2443/110/73/60/0/9ab911e_1699862100136-myop-pergay-alcock010.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Développer les quadriceps pour retarder l’arthrose du genou', 'image': 'https://img.lemde.fr/2023/12/04/0/0/5568/3712/110/73/60/0/1668e9d_1701709306262-pns-712210121.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\ESIEE\E4\S1\P2\DSIA_4201C_DataEngineerTools\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde_v3.py", line 21, in parse_category
#     for article in response.css(".river")[0].css(".teaser"):
#                    ~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Alain Moreau, éditeur, producteur et scénariste, est mort', 'image': 'https://img.lemde.fr/2023/11/13/0/6/5988/3992/110/73/60/0/2a28f8b_1699862802047-gettyimages-847632598.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Mort d’Henri Lopes : retour sur « Tribaliques », livre fondateur de l’écrivain congolais', 'image': 'https://img.lemde.fr/2023/11/10/58/0/3264/2176/110/73/60/0/6effcb5_1699611116986-henri-lopes.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Le prince Karel Schwarzenberg, ancien ministre tchèque et collaborateur de Vaclav Havel, est mort', 'image': 'https://img.lemde.fr/2023/11/12/0/47/3957/2638/110/73/60/0/7a58ad6_5eead089f1b2494e87b7ad085e3b1e25-0-93d20c7014cc49b99bd0031d072896f1.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort de Haruo Wako, ancien militant de l’Armée rouge japonaise', 'image': 'https://img.lemde.fr/2023/11/10/33/0/2048/1365/110/73/60/0/0fa9b2f_1699629541935-2000-02-22t000000z-1909487292-rp2drhybjjab-rtrmadp-3-lebanon.JPG', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort de Francette Lazard, dirigeante historique du Parti communiste français', 'image': 'https://img.lemde.fr/2023/11/09/1825/0/4409/2939/110/73/60/0/9de317e_1699512873049-gamma-6936439.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort de Laurent Greilsamer, ancien directeur adjoint du « Monde », essayiste et biographe', 'image': 'https://img.lemde.fr/2023/11/09/0/4/3000/2000/110/73/60/0/7d30008_1699510860039-lemonde271.JPG', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Le journaliste Laurent Greilsamer, ancien directeur adjoint du « Monde », est mort', 'image': 'https://img.lemde.fr/2023/11/08/0/0/5184/3456/110/73/60/0/b3e327b_1699443093024-000-par7814130.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort du philosophe argentin Enrique Dussel, penseur de la libération et de la décolonisation', 'image': 'https://img.lemde.fr/2023/11/08/0/152/2146/1431/110/73/60/0/de0a1e2_1699438843258-014-30531099.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Charles Piaget, figure emblématique du combat des ouvriers de Lip, est mort', 'image': 'https://img.lemde.fr/2018/09/17/0/25/2970/1980/110/73/60/0/bba60e1_G5oFpeowuT7WwB0k-SBSeDkD.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Le grand chef d’orchestre Yuri Temirkanov s’est éteint à Saint-Pétersbourg', 'image': 'https://img.lemde.fr/2023/11/04/0/0/4272/2848/110/73/60/0/39d770a_1699114222345-gettyimages-476877201.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Mort de l’astronaute américain Thomas Mattingly, sauveur de la mission Apollo-13', 'image': 'https://img.lemde.fr/2023/11/02/212/0/1539/1026/110/73/60/0/a093aa0_5766938-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'La mort de Francis Mer, ancien PDG d’Arcelor et ministre de l’économie', 'image': 'https://img.lemde.fr/2023/11/02/3/0/2464/1642/110/73/60/0/21b60e1_1698940931756-2003-09-25t120000z-1479465790-pbeahuomxby-rtrmadp-3-mer.JPG', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Francis Mer, ancien ministre de l’économie sous Jacques Chirac, est mort', 'image': 'https://img.lemde.fr/2023/11/01/0/0/2047/1365/110/73/60/0/066d5ad_1698848093460-000-app2003051778772.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Matthew Perry, élégie pour un clown triste', 'image': 'https://img.lemde.fr/2023/11/01/0/0/6000/4000/110/73/60/0/1aef72e_1698831411903-143677.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Mort de Matthew Perry : les acteurs de « Friends » se disent « totalement effondrés »', 'image': 'https://img.lemde.fr/2023/10/29/65/0/2000/1333/110/73/60/0/bde22e2_bc735e46bacb408da5801e9dd1ddc3e2-1-a0c5e961004f42649dcd30c5bf951efd.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'A New York, l’hommage des fans de « Friends » à Matthew Perry', 'image': 'https://img.lemde.fr/2023/10/29/0/0/4999/3333/110/73/60/0/da7e070_5729297-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Le rugbyman Guy Camberabero, vainqueur du premier grand chelem avec le XV de France, est mort', 'image': 'https://img.lemde.fr/2023/10/29/454/0/3020/2013/110/73/60/0/d084307_1698587842073-pressesports-011013-0001.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
#
# {'title': 'Avec la mort de Matthew Perry, « Friends » perd son Chandler Bing', 'image': 'https://img.lemde.fr/2023/10/29/7/0/3544/2362/110/73/60/0/d997a24_408c9a35f03841df95e9ff299482abc3-1-cc9d676e59d34a3aa0aefef951b01716.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Quand, en entreprise, les outils « de productivité » comme Slack et Teams donnent l’illusion de l’efficacité', 'image': 'https://img.lemde.fr/2023/12/04/0/26/3679/2453/110/73/60/0/8957c7b_1701704179641-000-33va3zu.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'AI Act : « La meilleure protection c’est d’avoir des modèles européens »', 'image': 'https://img.lemde.fr/2023/12/04/1/0/8192/5461/110/73/60/0/4b5fac8_1701705510018-000-344c2ta.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/intimites/>
#
# {'title': 'En Autriche, le tabou de la garde des jeunes enfants', 'image': 'https://img.lemde.fr/2023/12/03/0/0/4544/3029/110/73/60/0/b735b12_5026333-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/campus/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/international/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Noël vous met l’eau à la bûche ? La sélection des quinze meilleures du « Monde »', 'image': 'https://img.lemde.fr/2023/11/30/0/0/6720/4480/110/73/60/0/9e2ae7e_1701337936337-c-thetravelbuds3.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Même menstruelle, la culotte se fait belle', 'image': 'https://img.lemde.fr/2023/11/28/57/0/2066/1377/110/73/60/0/44b9389_1701180849435-chantelle-03-copie.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Au Chili, sur le chantier du plus grand télescope du monde', 'image': 'https://img.lemde.fr/2023/11/30/0/125/5439/3626/110/73/60/0/43a48c5_1701337992385-potw2336a-copie.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Une soirée d’observation au Very Large Telescope dans le désert d’Atacama', 'image': 'https://img.lemde.fr/2023/11/30/0/0/4368/2912/110/73/60/0/9837b76_1701337844666-esopia00092sites-copie.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Trois livres de mode pour être à la page', 'image': 'https://img.lemde.fr/2023/11/29/16/0/3298/2198/110/73/60/0/daeeb8b_1701270365665-double-page-2-a-editions-de-la-martiniei-re.png', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'A Paris Nord-Est, le projet d’un « parc urbain » de 27 hectares', 'image': 'https://img.lemde.fr/2023/12/04/0/11/7263/4842/110/73/60/0/57ce31f_1701681962096-000-9dt973.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Georges Maubert, un parfum de discrétion', 'image': 'https://img.lemde.fr/2023/11/24/410/0/1111/740/110/73/60/0/4c5f1fb_314476-3345575.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Le plan de Paris pour ouvrir 300 nouveaux hectares d’espaces verts au public', 'image': 'https://img.lemde.fr/2023/12/04/71/0/1024/682/110/73/60/0/9a3eb88_1701655984002-robinier-st-julien-le-pauvre.jpeg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Nos idées de concerts et festivals : Mozart, Soso Maness, Trans Musicales de Rennes, Orchestra Baobab…', 'image': 'https://img.lemde.fr/2021/12/05/2/0/6260/4173/110/73/60/0/75f367e_5140403-01-06.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': '« Pour une grande partie de la population, la quête du bonheur passe forcément par le fait de tomber amoureux, pas pour moi, je suis aromantique »', 'image': 'https://img.lemde.fr/2023/11/07/0/0/3543/2362/110/73/60/0/f45fb73_1699383816451-premiei-re-fois-lemonde-02.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': '« Les Neuf Parfaites », quand Ngugi Wa Thiong’o réinterprète l’épopée du peuple kikuyu', 'image': 'https://img.lemde.fr/2023/12/01/31/0/842/561/110/73/60/0/81bbeab_1701443831778-thiongo.PNG', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Au Burgundy, à Paris, la pavlova est « un festival de sucre et d’acidité imprévisible mais bien tempéré »', 'image': 'https://img.lemde.fr/2023/11/22/278/0/1125/750/110/73/60/0/8088d69_314149-3348672.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': '« Jean-Sébastien Bach », de René Belletto : Bach, Dieu et l’écrivain, de concert', 'image': 'https://img.lemde.fr/2023/11/27/721/0/2914/1942/110/73/60/0/5f599a4_1701083014213-pns-2838882.jpeg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'De Londres à Penzance, les Cornouailles sur les rails', 'image': 'https://img.lemde.fr/2023/11/24/3/0/2479/1652/110/73/60/0/32ec9b3_1700835903010-penzance-dsc8965.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'La chaise Belleville dans tous ses états', 'image': 'https://img.lemde.fr/2023/11/28/0/0/1800/1200/110/73/60/0/6aae4db_1701181790576-fotojet.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'L’entonnoir à confiture, une ouverture gourmande', 'image': 'https://img.lemde.fr/2023/11/23/330/0/1154/769/110/73/60/0/3ad6e15_314361-3348703.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Saint-Malo, le meilleur du « Monde »', 'image': 'https://img.lemde.fr/2023/11/30/0/0/3424/2283/110/73/60/0/c46c8e0_1701338850648-mei-dia-appel-crtb-ae04551-poriel-thibault.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Les meilleurs livres de 2023 : la sélection du « Monde des livres »', 'image': 'https://img.lemde.fr/2023/12/01/0/250/1500/1000/110/73/60/0/763f78d_1701427276580-03-livres2023.png', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Anne L’Huillier, Prix Nobel de physique : « J’ai toujours fonctionné à l’intuition »', 'image': 'https://img.lemde.fr/2023/12/01/0/0/5100/3400/110/73/60/0/4243b5a_1701425807185-000-33xa32b.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Les expressions populaires font-elles violence aux animaux ? : « Noyer le poisson », « fouetter un chat »', 'image': 'https://img.lemde.fr/2023/11/01/175/0/4256/2837/110/73/60/0/0c28b39_1698853925701-rec-231013-panier-de-crabes-x-le-monde-dsf3593-c-guillaume-blot-copie.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'De la Palestine à Paris, Chana Orloff, une artiste dans le siècle', 'image': 'https://img.lemde.fr/2023/11/24/8/0/1500/1000/110/73/60/0/3f18871_314488-3348851.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Les studios Rue Boyer, une audacieuse montée en gammes', 'image': 'https://img.lemde.fr/2023/11/24/375/0/1125/750/110/73/60/0/9a73ebb_314442-3348518.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Sur le service public, hommage fourni à Maria Callas pour le centenaire de sa naissance', 'image': 'https://img.lemde.fr/2023/11/28/491/467/1788/1192/110/73/60/0/a6b5acd_1701174515363-mariabycallas-9.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'La cuisine chinoise à feuilleter comme un vaste menu', 'image': 'https://img.lemde.fr/2023/11/22/0/0/1500/1000/110/73/60/0/6009f12_314099-3347678.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Maria Callas en Grèce, des années entre traumas et triomphes', 'image': 'https://img.lemde.fr/2023/11/30/1056/0/2598/1732/110/73/60/0/2ab1fbf_1701339207125-gno-callas-documentary-photo-chris-giatrakos.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Pour sa tournée, Etienne Daho revoit les choses en grand', 'image': 'https://img.lemde.fr/2023/11/28/572/0/3543/2362/110/73/60/0/1e88eef_1701191725655-rudy-waks-2023-bd.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': '« LuneXplorer » à la Cité de l’espace : un voyage vers la Lune, comme si vous y étiez', 'image': 'https://img.lemde.fr/2023/11/26/0/0/4999/3333/110/73/60/0/26a20b8_1701029463155-lunexplorer-citei-de-l-espace-photo-pierre-carton-pc002331-hdr.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Au Musée de l’Orangerie, à Paris, la couleur en action selon Hermann Nitsch', 'image': 'https://img.lemde.fr/2023/11/30/46/0/6228/4152/110/73/60/0/9a95533_1701352594158-2-hemann-nitsch-2021.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Quiz climat : êtes-vous chaud pour démêler le vrai du faux ?', 'image': 'https://img.lemde.fr/2021/10/22/106/415/1087/725/110/73/60/0/b4f32e6_999623847-bux7-hag.jpeg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'A Sintra, au Portugal, une auberge à deux pas de l’océan', 'image': 'https://img.lemde.fr/2023/11/10/207/0/1006/670/110/73/60/0/8cdf5a8_309978-3346588.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Les dirigeables pourraient-ils remplacer l’avion ? Comprendre en trois minutes', 'image': 'https://img.lemde.fr/2023/11/28/0/0/810/540/110/73/60/0/fbf0acb_1701168803580-tile-hori0.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Mon kiné superstar : « Je suis le seul influenceur avec qui on peut prendre un rendez-vous sur Doctolib »', 'image': 'https://img.lemde.fr/2023/11/29/1/0/4724/3149/110/73/60/0/559daf0_1701248142033-11-ezb-5543.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': '« Le Musée de la baleine (que vous ne verrez jamais) », d’A. Kendra Greene : roc collections islandaises', 'image': 'https://img.lemde.fr/2023/11/27/506/0/4414/2942/110/73/60/0/06a5e89_1701081820639-pns-6152257.jpeg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': '« Pétaouchnok(s). Du bout du monde au milieu de nulle part » : les trous d’horizon de Riccardo Ciavolella', 'image': 'https://img.lemde.fr/2023/11/27/3/0/5420/3613/110/73/60/0/9b63e8b_1701082309673-pns-1081916.jpeg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'A la redécouverte du Louvre, dans les pas de onze artistes', 'image': 'https://img.lemde.fr/2023/12/01/0/0/6799/4533/110/73/60/0/6ffca3c_1701428494154-louvre-portrait-de-simone-fattal-au-musei-e-du-louvre-salles-du-dept-antiquitei-s-orientales-a-olivier-ouadah.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Aurélie Saada, chanteuse et autrice : « La cuisine, c’est l’endroit où l’on se confie, où l’on fait ses devoirs »', 'image': 'https://img.lemde.fr/2023/11/23/153/0/1200/800/110/73/60/0/76642b7_314083-3348964.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'title': 'Les spaghettis aux merguez : la recette d’Aurélie Saada', 'image': 'https://img.lemde.fr/2023/11/23/213/174/1262/841/110/73/60/0/c1ea9a0_314085-3348964.jpg', 'description': None}
# 2023-12-05 13:43:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# ...
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/immigration-et-diversite/>
#
# {'title': 'Loi « immigration » : derrière le durcissement de l’article sur les métiers en tension, les divisions internes de la droite', 'image': 'https://img.lemde.fr/2023/11/08/3/0/5900/3933/110/73/60/0/b4ad135_1699461695641-jmug231106060.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/immigration-et-diversite/>
#
# {'title': 'Emmaüs, une fraternité au bord de la rupture', 'image': 'https://img.lemde.fr/2023/11/07/419/0/1071/714/110/73/60/0/653c44c_308856-3345985.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/immigration-et-diversite/>
#
# {'title': 'Projet de loi « immigration » : le Sénat durcit le droit du sol', 'image': 'https://img.lemde.fr/2023/11/07/0/0/7816/5210/110/73/60/0/b3aa862_1699369023781-905962.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/immigration-et-diversite/>
#
# {'title': 'Loi « immigration » : le Sénat supprime la mesure du gouvernement sur les métiers en tension', 'image': 'https://img.lemde.fr/2023/11/07/0/0/5452/3635/110/73/60/0/b9f560d_5812034-01-06.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/immigration-et-diversite/>
#
# {'title': 'Immigration : au Sénat, la droite se rallie à un compromis sur la régularisation des travailleurs sans papiers dans les métiers en tension', 'image': 'https://img.lemde.fr/2023/11/07/3/0/5900/3933/110/73/60/0/bb1d74c_1699343990867-jmug231106072.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/immigration-et-diversite/>
#
# {'title': 'Projet de loi « immigration » : les concessions de Darmanin à la droite', 'image': 'https://img.lemde.fr/2023/11/07/3/0/5900/3933/110/73/60/0/a42cd2c_1699343990824-jmug231106030.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/immigration-et-diversite/>
#
# {'title': 'Loi « immigration » : les sénateurs de droite et du centre s’accordent sur la suppression de l’article portant sur l’octroi d’un titre de séjour pour les travailleurs sans papiers', 'image': 'https://img.lemde.fr/2023/11/07/0/0/7414/4943/110/73/60/0/d654bfa_5812338-01-06.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/immigration-et-diversite/>
#
# {'title': 'Loi « immigration » : le Sénat adopte la suppression de l’aide médicale de l’Etat pour les sans-papiers', 'image': 'https://img.lemde.fr/2023/11/07/3/0/5900/3933/110/73/60/0/a42cd2c_1699343990824-jmug231106030.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/immigration-et-diversite/>
#
# {'title': 'Immigration : le risque d’un débat sans vision', 'image': 'https://img.lemde.fr/2023/11/07/0/0/5899/3933/110/73/60/0/9407538_1699346014202-jmug231106052.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/immigration-et-diversite/>
#
# {'title': '« Le projet de loi immigration, cet objet politique mutant révélateur des contraintes, des contradictions et des impasses du moment »', 'image': 'https://img.lemde.fr/2023/11/07/0/0/5899/3933/110/73/60/0/20394b5_1699316316370-jmug231106008.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/immigration-et-diversite/>
#
# {'title': 'Le Sénat poursuit le durcissement du projet de loi « immigration »', 'image': 'https://img.lemde.fr/2023/11/07/3/0/5900/3933/110/73/60/0/d461a7a_1699343996440-jmug231106074.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : ce que l’on sait des conditions de détention des otages israéliens libérés', 'image': 'https://img.lemde.fr/2023/11/26/804/0/7910/5273/110/73/60/0/9350eb7_1700959369898-ll-tel-aviv-otages-hd-18.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Israël-Hamas : « Le Monde » face à la guerre des images', 'image': 'https://img.lemde.fr/2023/11/28/0/0/7972/5315/110/73/60/0/8b494b3_1701178780683-ap23281394186613.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : « Les bombardements indiscriminés sont contraires au droit international »', 'image': 'https://img.lemde.fr/2023/11/28/0/0/5500/3666/110/73/60/0/d379cfe_1701186325947-240131.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : à Barcelone, l’Union pour la Méditerranée cherche à préserver les ponts entre le monde arabe et l’Europe', 'image': 'https://img.lemde.fr/2023/11/27/0/0/4878/3252/110/73/60/0/25a0a3b_5976437-01-06.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : à Gaza, une trêve fragile pour de nouvelles libérations d’otages', 'image': 'https://img.lemde.fr/2023/11/28/0/0/1599/1066/110/73/60/0/c42ee97_1701161202217-238715.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Trois jeunes otages franco-israéliens ont été libérés par le Hamas', 'image': 'https://img.lemde.fr/2023/11/28/0/0/5120/3413/110/73/60/0/7d2b1f8_2023-11-28t011646z-1524455906-rc2yl4a1kq9k-rtrmadp-3-israel-palestinians-hostages.JPG', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'L’Espagne se pose en critique contre Israël dans une Union européenne prudente', 'image': 'https://img.lemde.fr/2023/11/27/0/5/5253/3502/110/73/60/0/f87614d_1701070475963-987177.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Psychologie : à l’écoute des personnes traumatisées par les attaques terroristes du Hamas le 7 octobre', 'image': 'https://img.lemde.fr/2023/11/27/0/0/5047/3364/110/73/60/0/074d711_1701082439421-cbi1153054.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Pourquoi Yahya Sinouar, l’inflexible chef du Hamas, est le maître du jeu à Gaza', 'image': 'https://img.lemde.fr/2023/11/27/0/0/2109/1406/110/73/60/0/18c7780_1701075122707-2022-12-14t141531z-1671027326-dpaf221214x911x011091-rtrfipp-4-unrest-conflict-history-defence.JPG', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'La difficile équation de Benyamin Nétanyahou, entre la trêve pour les otages et la guerre contre le Hamas', 'image': 'https://img.lemde.fr/2023/11/27/0/0/5500/3666/110/73/60/0/224a1d9_1701076874631-220035.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : « Il faut une véritable offensive de paix au Proche-Orient »', 'image': 'https://img.lemde.fr/2023/11/24/1/0/7679/5119/110/73/60/0/8fbba82_1700818809846-075-zawrzel-streetar221228-nptkr.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Avec la libération d’otages au compte-gouttes, le Hamas poursuit la guerre contre Israël sur le terrain psychologique', 'image': 'https://img.lemde.fr/2023/11/26/527/0/7910/5273/110/73/60/0/6808c62_1700990603001-ll-tel-aviv-otages-hd-35.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': '« A Gaza, plus de cent employés des Nations unies sont morts, c’est sans précédent »', 'image': 'https://img.lemde.fr/2023/11/24/1/0/7679/5119/110/73/60/0/8fbba82_1700818809846-075-zawrzel-streetar221228-nptkr.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Jamais la Palestine n’a autant souffert', 'image': 'https://img.lemde.fr/2023/11/25/0/0/6000/4000/110/73/60/0/85739ab_5961204-01-06.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Maurice Lévy : « Jamais, depuis la Shoah, la communauté juive de France ne s’était sentie aussi isolée »', 'image': 'https://img.lemde.fr/2023/10/31/0/142/3546/2364/110/73/60/0/50429f9_1698756709501-maxbestof276211.jpeg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Le Quai d’Orsay ouvre une enquête administrative sur une ancienne collaboratrice après la diffusion d’une vidéo dans laquelle elle arrache des portraits d’otages israéliens', 'image': 'https://img.lemde.fr/2023/10/12/0/0/5313/3542/110/73/60/0/9c9f431_2023-10-12t185731z-641330607-rc26r3aeofon-rtrmadp-3-israel-palestinians-france-flight.JPG', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Antisémitisme : Gérard Larcher et Yaël Braun-Pivet appellent à une marche, le RN annonce sa participation et LFI réserve sa réponse', 'image': 'https://img.lemde.fr/2023/11/07/1/0/8192/5461/110/73/60/0/eddbc1f_1699378121526-000-33em994.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Etoiles de David taguées : un juge va enquêter sur un possible commanditaire étranger', 'image': 'https://img.lemde.fr/2023/10/31/1/0/8192/5461/110/73/60/0/c7b34b4_e204f899214b4bceb0b3fe4b2a58ab09-0-3d17f7597f4d459ebdf1b95f72c9a946.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Jordan Bardella nie l’antisémitisme de Jean-Marie Le Pen et rediabolise le Rassemblement national', 'image': 'https://img.lemde.fr/2023/11/06/0/0/6720/4480/110/73/60/0/58dd9f5_1699289967068-cbi1147002.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Refuser la banalisation de l’antisémitisme', 'image': 'https://img.lemde.fr/2023/11/05/0/0/3000/2000/110/73/60/0/44378b2_1699188423362-ad030marchesoutienisrael-dsc09883.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': '« Evénements et incidents » antisémites : chaque signalement « pris en compte » après les consignes de fermeté du ministère de l’intérieur', 'image': 'https://img.lemde.fr/2023/11/03/0/0/5875/3916/110/73/60/0/2e67f05_1699024351774-869857.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Chez les juifs français, la peur et le sentiment d’un grand isolement : « Il n’y a pas beaucoup de monde pour nous soutenir »', 'image': 'https://img.lemde.fr/2023/11/04/0/0/3000/2000/110/73/60/0/70f1546_1699095563418-ad032marchesoutienisrael-dsc09912.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Guerre Israël-Hamas : 1 040 actes antisémites et 486 interpellations en France depuis le début du conflit, selon Darmanin', 'image': 'https://img.lemde.fr/2023/10/31/0/71/4641/3094/110/73/60/0/9bf7050_5742196-01-06.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'A Strasbourg, des tags antisémites découverts ; une enquête ouverte', 'image': 'https://img.lemde.fr/2023/11/03/0/60/2250/1500/110/73/60/0/dab1f92_1699007390120-capture-da-ei-cran-2023-11-03-ai-11-29-42.png', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': '« Jean-Luc Mélenchon instaure explicitement un fossé entre le peuple français et Yaël Braun-Pivet »', 'image': 'https://img.lemde.fr/2023/10/10/0/0/4968/3312/110/73/60/0/3ec9c7d_2023-10-10t134919z-330392210-rc2pp3azmthx-rtrmadp-3-israel-palestinians-france.JPG', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Après la diffusion en ligne d’un chant antisémite dans le métro parisien, ouverture d’une enquête pour « apologie du terrorisme »', 'image': 'https://img.lemde.fr/2023/11/01/0/0/3829/2553/110/73/60/0/ff8a8ba_1698855443668-000-33yp6vu.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'L’Arcom saisie pour des propos tenus dans les médias autour de la guerre entre Israël et le Hamas', 'image': 'https://img.lemde.fr/2023/11/01/0/0/8640/5760/110/73/60/0/3d89baa_b61b364f9ea64efd86412b14d142c990-0-ee3efd52439a48f1b3797a0637cfd307.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Antisémitisme : aux origines du glissement de vocabulaire de « juif » à « sioniste »', 'image': 'https://img.lemde.fr/2019/02/19/0/4/4248/2832/110/73/60/0/e59e027_SkLC6mR54L-36VtEEIPuO-xI.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Des étoiles de David taguées en Ile-de-France : enquête ouverte, Elisabeth Borne dénonce des « agissements ignobles »', 'image': 'https://img.lemde.fr/2023/10/31/0/39/6418/4279/110/73/60/0/943e035_1698753367286-873033.jpg', 'description': None}
# 2023-12-05 13:43:24 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-05 13:43:24 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 12249,
#  'downloader/request_count': 31,
#  'downloader/request_method_count/GET': 31,
#  'downloader/response_bytes': 2576662,
#  'downloader/response_count': 31,
#  'downloader/response_status_count/200': 31,
#  'elapsed_time_seconds': 1.495018,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 5, 12, 43, 24, 175201, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 10236722,
#  'httpcompression/response_count': 31,
#  'item_scraped_count': 1530,
#  'log_count/DEBUG': 1562,
#  'log_count/ERROR': 3,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'request_depth_max': 1,
#  'response_received_count': 31,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 30,
#  'scheduler/dequeued/memory': 30,
#  'scheduler/enqueued': 30,
#  'scheduler/enqueued/memory': 30,
#  'spider_exceptions/IndexError': 3,
#  'start_time': datetime.datetime(2023, 12, 5, 12, 43, 22, 680183, tzinfo=datetime.timezone.utc)}
# 2023-12-05 13:43:24 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On peut exporter les résultats de ces retours dans différents formats de
# fichiers.
#
# -   CSV : `scrapy crawl lemonde -o lbc.csv`
# -   JSON : `scrapy crawl lemonde -o lbc.json`
# -   JSONLINE : `scrapy crawl lemonde -o lbc.jl`
# -   XML : `scrapy crawl lemonde -o lbc.xml`
#
# ### Exercice :
#
# Exécuter la spider avec les différents formats de stockage.
# Explorer ensuite le contenu des fichiers ainsi créés.

# %%
# CSV
# !cd newscrawler && scrapy crawl lemonde -o output.csv

# JSON
# !cd newscrawler && scrapy crawl lemonde -o output.json

# JSON Lines
# !cd newscrawler && scrapy crawl lemonde -o output.jl

# XML
# !cd newscrawler && scrapy crawl lemonde -o output.xml

# %% [markdown]
# ## Votre premier Item
#
# La classe `Item` permet de structurer les données que l'on souhaite
# récupérer sous la forme d'un modèle. Les items doivent être définis dans
# le fichier `items.py` créé par la commande `scrapy startproject`. Les
# `Item` héritent de la class `scrapy.Item`.
#
# On veut structurer les données avec deux champs : le titre et le prix de
# l'annonce. Scrapy utilise une classe `scrapy.Field` permettant de
# 'déclarer' ces champs. Dans notre cas :

# %%
# %load newscrawler/newscrawler/items.py

# Define here the models for your scraped items
#
# See documentation in:
# https://docs.scrapy.org/en/latest/topics/items.html

import scrapy

class ArticleItem(scrapy.Item):
    title = scrapy.Field()
    image = scrapy.Field()
    description = scrapy.Field()

# %% [markdown]
# Utiliser la classe `scrapy.Item` plutôt qu'un simple dictionnaire permet
# plus de contrôle sur la structure des données. En effet, on ne peut
# insérer dans les items que des données avec des clés 'déclarées'. Ce qui
# assure une plus grande cohérence au sein d'un projet.
#
# On peut instancier un item de plusieurs façons :

# %%
article_item = ArticleItem(title="Gilets Jaunes", image=None, description="Un samedi de manifestations")

# %%
print(article_item)
# Out:
# {'description': 'Un samedi de manifestations',
#  'image': None,
#  'title': 'Gilets Jaunes'}

# %%
article_item = ArticleItem()
article_item["title"] = 'Gilets Jaunes'
article_item["description"] = 'Un samedi de manifestations'

# %%
print(article_item)
# Out:
# {'description': 'Un samedi de manifestations', 'title': 'Gilets Jaunes'}

# %% [markdown]
# La définition d'un item permet de palier toutes les erreurs de typo dans
# les champs.

# %%
article_item = ArticleItem()
article_item["titelkjwnxvmnscbvmknxc"] = 'Gilets Jaunes'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\keren\Documents\ESIEE\E4\S1\P2\DSIA_4201C_DataEngineerTools\DataEngineerTools\2Scrapy\Introduction.ipynb Cell 119 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/keren/Documents/ESIEE/E4/S1/P2/DSIA_4201C_DataEngineerTools/DataEngineerTools/2Scrapy/Introduction.ipynb#Y224sZmlsZQ%3D%3D?line=0'>1</a> article_item = ArticleItem()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/keren/Documents/ESIEE/E4/S1/P2/DSIA_4201C_DataEngineerTools/DataEngineerTools/2Scrapy/Introduction.ipynb#Y224sZmlsZQ%3D%3D?line=1'>2</a> article_item["titelkjwnxvmnscbvmknxc"] = 'Gilets Jaunes'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\item.py:85, in Item.__setitem__(self, key, value)
#      83     self._values[key] = value
#      84 else:
# ---> 85     raise KeyError(f"{self.__class__.__name__} does not support field: {key}")
#
# KeyError: 'ArticleItem does not support field: titelkjwnxvmnscbvmknxc'

# %% [markdown]
# Les items héritent des dictionnaires Python, et possèdent donc toutes
# les méthodes de ceux-ci:

# %%
article_item = ArticleItem(title="Gilets Jaunes")
print(article_item["title"]) # Méthode __getitem__()
print(article_item.get("description", "no description provided")) # Méthode get()
# Out:
# Gilets Jaunes
# no description provided

# %% [markdown]
# On peut transformer un `Item` en dictionnaire très facilement, en le
# passant au constructeur:

# %%
article_item = ArticleItem(title="Drone DJI")
print(type(article_item))
dict_item = dict(article_item)
print(type(dict_item))
print(dict_item)
# Out:
# <class '__main__.ArticleItem'>
# <class 'dict'>
# {'title': 'Drone DJI'}

# %% [markdown]
# On intègre maintenant cet item dans notre spider.

# %%
# -*- coding: utf-8 -*-
import scrapy
from scrapy import Request
from ..items import ArticleItem
class LemondeSpider(scrapy.Spider):
    name = "lemonde"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name:response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        for link in all_links.values():
            yield Request(link, callback=self.parse_category)

    def parse_category(self, response):
        for article in response.css(".fleuve")[0].css("article"):
            title = self.clean_spaces(article.css("h3 a::text").extract_first())
            image = article.css("img::attr(data-src)").extract_first()
            description = article.css(".txt3::text").extract_first()

            yield ArticleItem(
                title=title,
                image=image,
                description=description
            )

    def clean_spaces(self, string):
        if string:
            return " ".join(string.split())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\keren\Documents\ESIEE\E4\S1\P2\DSIA_4201C_DataEngineerTools\DataEngineerTools\2Scrapy\Introduction.ipynb Cell 125 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/keren/Documents/ESIEE/E4/S1/P2/DSIA_4201C_DataEngineerTools/DataEngineerTools/2Scrapy/Introduction.ipynb#Y233sZmlsZQ%3D%3D?line=1'>2</a> import scrapy
#       <a href='vscode-notebook-cell:/c%3A/Users/keren/Documents/ESIEE/E4/S1/P2/DSIA_4201C_DataEngineerTools/DataEngineerTools/2Scrapy/Introduction.ipynb#Y233sZmlsZQ%3D%3D?line=2'>3</a> from scrapy import Request
# ----> <a href='vscode-notebook-cell:/c%3A/Users/keren/Documents/ESIEE/E4/S1/P2/DSIA_4201C_DataEngineerTools/DataEngineerTools/2Scrapy/Introduction.ipynb#Y233sZmlsZQ%3D%3D?line=3'>4</a> from ..items import ArticleItem
#       <a href='vscode-notebook-cell:/c%3A/Users/keren/Documents/ESIEE/E4/S1/P2/DSIA_4201C_DataEngineerTools/DataEngineerTools/2Scrapy/Introduction.ipynb#Y233sZmlsZQ%3D%3D?line=4'>5</a> class LemondeSpider(scrapy.Spider):
#       <a href='vscode-notebook-cell:/c%3A/Users/keren/Documents/ESIEE/E4/S1/P2/DSIA_4201C_DataEngineerTools/DataEngineerTools/2Scrapy/Introduction.ipynb#Y233sZmlsZQ%3D%3D?line=5'>6</a>     name = "lemonde"
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# On voit bien que le générateur retourne maintenant un `Item`.

# %% [markdown]
# ### Exercice :
#
# Relancer la spider pour vérifier le bon déroulement de l'extraction.

# %%
# !cd newscrawler/ && scrapy crawl lemondev4
# Out:
# 2023-12-05 13:45:27 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-12-05 13:45:28 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.6 (tags/v3.11.6:8b6ee5b, Oct  2 2023, 14:57:12) [MSC v.1935 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22631-SP0
# 2023-12-05 13:45:28 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-05 13:45:28 [py.warnings] WARNING: C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-05 13:45:28 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-05 13:45:28 [scrapy.extensions.telnet] INFO: Telnet Password: 28a2f2a3c0339b68
# 2023-12-05 13:45:28 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-05 13:45:28 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-12-05 13:45:28 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-05 13:45:28 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-05 13:45:28 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-05 13:45:28 [scrapy.core.engine] INFO: Spider opened
# 2023-12-05 13:45:28 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-05 13:45:28 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-05 13:45:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-05 13:45:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2023-12-05 13:45:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/pixels/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:45:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# 2023-12-05 13:45:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/campus/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:45:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-fil-good/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:45:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sciences/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:45:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sante/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:45:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/podcasts/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/1/0/8192/5461/110/73/60/0/4b5fac8_1701705510018-000-344c2ta.jpg',
#  'title': 'AI Act : « La meilleure protection c’est d’avoir des modèles '
#           'européens »'}
# 2023-12-05 13:45:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/intimites/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2021/12/22/0/0/4000/2666/110/73/60/0/bc06e1b_701885255-1k2a9249.jpg',
#  'title': '23andMe : les données de 6,9 millions d’utilisateurs de '
#           'l’entreprise de tests génétiques piratées'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/05/0/116/1155/770/110/73/60/0/6835e7f_1701756203963-capture.JPG',
#  'title': 'GTA VI : pourquoi la bande-annonce du nouveau jeu de Rockstar Games '
#           'était-elle si attendue ?'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/43/0/1024/682/110/73/60/0/dbf9ebd_1701728759755-europol-building-the-hague-the-netherlands-931.jpeg',
#  'title': 'Plus d’un millier d’arrestations dans le monde après une opération '
#           'antiblanchiment menée par les Pays-Bas'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2022/02/17/0/0/4822/3215/110/73/60/0/8078bfe_5564735-01-06.jpg',
#  'title': 'Les changements d’actionnaires et l’intelligence artificielle '
#           'bousculent le monde de l’édition'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/25/0/4660/3106/110/73/60/0/7fa3f82_2023-12-04t082847z-1344449415-rc27q4ajreh8-rtrmadp-3-spotify-strategy-jobs.JPG',
#  'title': 'Spotify licencie 1 500 personnes afin de « réduire » ses coûts'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/0/0/3000/2000/110/73/60/0/72cf84f_1701453037748-frame-413-1.jpg',
#  'title': 'Comment l’algorithme de la CAF prédit si vous êtes « à risque » de '
#           'frauder'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/0/0/3000/2000/110/73/60/0/931642d_1701452739725-frame-411.jpg',
#  'title': 'L’opacité des algorithmes favorise les dérives au sein des '
#           'établissements publics'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/03/0/0/3000/2000/110/73/60/0/d76514a_1701620994037-frame-401-1.jpg',
#  'title': 'Dans la vie de Juliette, mère isolée, précaire et cible de '
#           'l’algorithme des CAF'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/0/0/3000/2000/110/73/60/0/a09faf4_1701452989940-frame-428-1.jpg',
#  'title': 'Profilage et discriminations : enquête sur les dérives de '
#           'l’algorithme des caisses d’allocations familiales'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/1/0/8192/5461/110/73/60/0/fe454b9_1701427393351-043-dpa-pa-231114-99-935740-dpai.jpg',
#  'title': '« De nombreux déficients visuels n’osent pas se risquer sur '
#           'Internet » : l’accessibilité des sites Web, un chantier à peine '
#           'entamé'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/367/0/780/520/110/73/60/0/967df6a_1701264721095-forma-s-a-la-haine-des-femmes.png',
#  'title': '« Formés à la haine des femmes », de Pauline Ferrari : une '
#           'exploration méthodique et inquiétante du masculinisme en ligne'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/04/17/0/0/3000/2000/110/73/60/0/2a2ab28_1681721637938-rgnrgn.jpg',
#  'title': 'L’intelligence artificielle attise l’appétit des fonds '
#           'd’investissement'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/1/0/4724/3149/110/73/60/0/559daf0_1701248142033-11-ezb-5543.jpg',
#  'title': 'Mon kiné superstar : « Je suis le seul influenceur avec qui on peut '
#           'prendre un rendez-vous sur Doctolib »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/0/0/5568/3712/110/73/60/0/8f1ac00_1701439131982-000-1wi04b.jpg',
#  'title': 'Piratage de la plate-forme de cryptomonnaies Platypus : les deux '
#           'accusés relaxés par la justice'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/0/0/6487/4325/110/73/60/0/519e6ab_5995560-01-06.jpg',
#  'title': 'Les comptes Gmail inactifs pendant deux ans seront désormais fermés '
#           'par Google'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/0/0/3000/2000/110/73/60/0/88a8d54_4d0d350300d04c038e6f59a703d1408f-0-a3da083b1c2f43c69a51d25b308f3c20.jpg',
#  'title': 'TikTok : l’interdiction dans l’Etat du Montana bloquée par la '
#           'justice'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/0/5/5041/3361/110/73/60/0/ac2843a_1701420695220-messageries.jpg',
#  'title': 'Internet : « En matière de messagerie, le gouvernement monte d’un '
#           'cran ses exigences »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/15/1/0/3200/2133/110/73/60/0/f2fdf92_2023-11-15t120528z-841882810-rc2fd4a2qqv4-rtrmadp-3-usa-politics-violence.JPG',
#  'title': 'Des Etats-Unis à la France, comment la société s’imprègne de '
#           'l’imaginaire complotiste de QAnon'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/0/0/2912/1941/110/73/60/0/63da964_1701263719114-mosaique-2.png',
#  'title': 'Pour Noël, huit livres à offrir à un fan de jeux vidéo'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/0/0/2100/1400/110/73/60/0/c437b49_1701352893951-ia-amitie-artificielle.png',
#  'title': 'L’amitié artificielle, nouvelle frontière de l’intelligence '
#           'artificielle'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/110/0/7177/4784/110/73/60/0/d457213_2023-11-28t060046z-901593320-rc25m4aathh6-rtrmadp-3-eu-meta-platforms.JPG',
#  'title': 'Facebook et Instagram payants : des associations européennes de '
#           'consommateurs déposent une plainte contre Meta'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/110/0/7177/4784/110/73/60/0/d457213_2023-11-28t060046z-901593320-rc25m4aathh6-rtrmadp-3-eu-meta-platforms.JPG',
#  'title': 'Meta supprime de nouvelles pages liées à des opérations de '
#           'désinformation russes'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/22/0/2/5388/3592/110/73/60/0/3effe65_5941758-01-06.jpg',
#  'title': '« L’affaire Sam Altman a montré que les catastrophistes de '
#           'l’intelligence artificielle ont perdu une bataille »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/188/0/6959/4639/110/73/60/0/5a59694_2a7abfce630b4c1599bdf23990d01596-1-cff89ec940f94bb69f1997dfe78eabdc.jpg',
#  'title': 'Entre Google et le Canada, un accord « historique » pour '
#           'l’indemnisation des médias'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/0/5/5041/3361/110/73/60/0/4954f1a_1701289386470-000-8zc3rh.jpg',
#  'title': 'Les ministères sommés de « remplacer » leurs messageries '
#           'instantanées par l’application française Olvid'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/61/0/1200/800/110/73/60/0/0a1df50_1701103506465-abacanewsroy-857375-003.jpg',
#  'title': 'L’intelligence artificielle menace de nombreux métiers, notamment '
#           'les emplois administratifs et de bureau, ou les services comptables'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/06/0/2871/3975/2650/110/73/60/0/e3d6ed8_1699262625673-pns-6621945.jpg',
#  'title': 'Manager avec l’intelligence artificielle : les biais des recruteurs'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/17/0/312/3375/2250/110/73/60/0/2618d6e_1700232325662-063-1578580052.jpg',
#  'title': 'X, terrain d’enquête déserté des chercheurs'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/251/0/489/326/110/73/60/0/7aac4cd_1701071673178-9782330184339.jpg',
#  'title': '« Une brève histoire des hackeurs russes » : éclairage des '
#           'fantassins virtuels du Kremlin'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/86/16/1606/1071/110/73/60/0/5efa6a8_1701171619469-capture-da-ei-cran-2023-11-28-ai-12-40-04.png',
#  'title': 'L’influenceuse Poupette Kenza condamnée à une amende de 50 000 '
#           'euros'}
# 2023-12-05 13:45:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/afrique/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:45:28 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\ESIEE\E4\S1\P2\DSIA_4201C_DataEngineerTools\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde_v4.py", line 22, in parse_category
#     for article in response.css(".river")[0].css(".teaser"):
#                    ~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\keren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/0/0/5100/3400/110/73/60/0/aa6cbb7_3de8b461f19c457da58e1f6e2c9039fb-0-cf249c4a9a68482599bdfd35db8b2d07.jpg',
#  'title': 'Facebook et Instagram payants : une plainte pour infraction au '
#           'droit européen des données personnelles'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/25/33/0/2000/1333/110/73/60/0/4b582b6_1698248550584-ransomware-illu-ordi-bombe.png',
#  'title': 'Démantèlement d’un important groupe de rançongiciels en Ukraine'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/0/0/4999/3333/110/73/60/0/56f6b24_5975579-01-06.jpg',
#  'title': '« Renoncer à un encadrement juridique ambitieux de l’intelligence '
#           'artificielle affaiblirait la position historique de l’Europe »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/22/0/0/4999/3333/110/73/60/0/f230654_2023-11-22t185141z-2061880129-rc2ne4aqyil4-rtrmadp-3-openai-ceo-governance-analysis-pix.JPG',
#  'title': 'Intelligence artificielle : « Le fait de s’éloigner de l’idéalisme '
#           'académique et de se tourner vers le pragmatisme commercial a dû '
#           'créer le conflit chez OpenAI »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/8565c91_5941766-01-06.jpg',
#  'title': '« L’IA générative est une affaire trop sérieuse pour la laisser '
#           'dans les seules mains du capital »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/0/0/5100/3400/110/73/60/0/aa6cbb7_3de8b461f19c457da58e1f6e2c9039fb-0-cf249c4a9a68482599bdfd35db8b2d07.jpg',
#  'title': 'Meta accusé d’inaction face au nombre de mineurs âgés de moins de '
#           '13 ans sur Instagram et Facebook'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/0/13/504/336/110/73/60/0/bc4b28b_1701076062815-hidalgo-twitter.png',
#  'title': 'Anne Hidalgo : « Pour rester fidèle à mes convictions et à mon '
#           'engagement, je quitte aujourd’hui X »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/24/0/0/4744/3162/110/73/60/0/d0a551b_1700834676425-ap22269472416341.jpg',
#  'title': 'Rashid Ismailov, ancien ministre des télécoms en Russie : « Le '
#           'modèle actuel de la gouvernance d’Internet est désuet »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/23/1/0/4000/2666/110/73/60/0/b5f2d87_1700737916618-051-xxjpbee007172-20231108-pepfn0a001.jpg',
#  'title': 'Pourquoi la quête de souveraineté numérique sur Internet menace '
#           'l’hégémonie américaine'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/20/0/513/4765/3177/110/73/60/0/401c420_1700478991442-mac230090d00581.jpg',
#  'title': 'L’intelligence artificielle pour fouiller la mémoire de Notre-Dame '
#           'de Paris'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/22/121/0/2185/1456/110/73/60/0/db91a1e_1700693887533-illustration-sans-titre.jpg',
#  'title': 'Intelligence artificielle : le monde de la culture redoute une '
#           'spoliation massive'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/21/0/0/4246/2831/110/73/60/0/96ada93_2023-11-21t194510z-2122604007-rc2uh4ahmkt2-rtrmadp-3-fintech-crypto-ceos-regulators.JPG',
#  'title': 'La justice monténégrine approuve l’extradition du Sud-Coréen Do '
#           'Kwon, fondateur de la cryptomonnaie terra'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/06/21/0/102/726/484/110/73/60/0/1b936be_xaIOSHJ2DSCvws80fv-Nk-J4.PNG',
#  'title': '« L’industrie de la cybersurveillance s’est adaptée sur toute la '
#           'chaîne de valeur pour répondre au marché à la fois intérieur et à '
#           'l’export »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/24/0/0/3000/2000/110/73/60/0/161b91f_1700821575398-illu-anguilla.jpg',
#  'title': 'Intelligence artificielle : derrière la fortune de l’île d’Anguilla '
#           'et de son « .ai », une forme de « néocolonialisme numérique »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/24/25/0/7821/5214/110/73/60/0/8e447d0_1700834337999-000-32kc7mt.jpg',
#  'title': 'Gouvernance d’Internet : la Chine promeut sa propre norme pour '
#           'gagner en « maîtrise »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/23/0/0/5472/3648/110/73/60/0/50f138c_1700769051862-sipa-shutterstock40914534-000006.jpg',
#  'title': '« Black Friday sur les gosses » : l’étrange théorie du complot '
#           'd’enfants vendus sur Vinted'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/24/12/0/4837/3224/110/73/60/0/ad21f36_1700812400740-gettyimages-1257892751.jpg',
#  'title': 'OpenAI : aux sources de l’affaire Sam Altman'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2022/08/08/2/0/5600/3733/110/73/60/0/7791654_1659945658149-pns-703220575.jpg',
#  'title': 'Anthony Babkine, Diversidays : « Le secteur du numérique est '
#           'l’ascenseur social du XXIᵉ siècle »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2018/07/27/47/0/551/366/110/73/60/0/b28e0e4_4843-7fsgto.lzq3p.jpg',
#  'title': 'Vidéosurveillance algorithmique : une communauté de communes sommée '
#           'de supprimer des données personnelles'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/08/28/0/0/6720/4480/110/73/60/0/a79cf7e_1693229785206-1k2a3247.JPG',
#  'title': 'Cinq cadeaux de Noël électroniques et durables'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2022/11/29/0/0/6720/4480/110/73/60/0/e957a93_1669715824484-pns-6302071.jpg',
#  'title': 'Philippe Trotin, Microsoft : « La France est un élève moyen en '
#           'termes d’accessibilité numérique »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/07/11/0/18/2955/1970/110/73/60/0/dae0b1d_1689093747494-andia-abc-brpaphotos20201229-053.jpg',
#  'title': '« C’est comme mettre une caméra dans toutes les maisons » : le '
#           'patron de WhatsApp défend le chiffrement des messages face à un '
#           'projet de loi européen'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/21/0/0/4299/2866/110/73/60/0/cbadebf_2023-11-21t205617z-1328885767-rc2koz9pxcrm-rtrmadp-3-nvidia-results-etfs.JPG',
#  'title': '« Nvidia est aujourd’hui le seul à gagner de l’argent dans la ruée '
#           'vers l’intelligence artificielle »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/22/0/0/4999/3333/110/73/60/0/36b03f5_1700642890184-208760.jpg',
#  'title': 'Sam Altman revient à la tête d’OpenAI avec le soutien de Microsoft'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/21/0/0/2043/1362/110/73/60/0/17c16ac_5936784-01-06.jpg',
#  'title': 'Cryptomonnaies : une amende colossale pour Binance et son patron, '
#           'Changpeng Zhao'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/21/0/0/4999/3333/110/73/60/0/26ad00e_2023-11-21t235532z-1291111748-rc2ne4asgk1t-rtrmadp-3-openai-altman-legal.JPG',
#  'title': 'OpenAI annonce le retour à sa tête de Sam Altman'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/09/14/0/0/5599/3733/110/73/60/0/1f1ac73_1694706457924-pns-703223634.jpg',
#  'title': 'Luce Carevic, experte en accessibilité numérique : « Les sites et '
#           'logiciels ont un niveau d’accessibilité déplorable »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/21/0/5/5622/3748/110/73/60/0/a8670bc_1700565368053-000-33uh79j.jpg',
#  'title': '« Extimité » : dévoiler son espace intime sur les réseaux sociaux, '
#           'une affirmation de soi ?'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/21/93/87/498/332/110/73/60/0/3ca3ced_1700572483743-the-legend-of-zelda-ocarina-of-time-screenshot-097.jpg',
#  'title': '« The Legend of Zelda : Ocarina of Time » a 25 ans : quel héritage '
#           'pour l’un des meilleurs jeux vidéo de tous les temps ?'}
# 2023-12-05 13:45:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/education/> (referer: https://www.lemonde.fr)
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/05/0/0/5180/3453/110/73/60/0/1ce55d8_1701774362650-222727.jpg',
#  'title': 'Gabriel Attal annonce les mesures de son « choc des savoirs » aux '
#           'enseignants'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/181/0/7543/5028/110/73/60/0/a1a7aa9_1701678340988-jeunesase-clr.jpg',
#  'title': 'Le drame des enfants placés lâchés à leur majorité : « T’es qu’une '
#           'enfant de l’aide sociale à l’enfance, arrête de viser trop loin »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/11/603/3413/2275/110/73/60/0/d07eb02_1701721428111-000-9uf2tt.jpg',
#  'title': 'Sciences Po sous le choc après la garde à vue de son directeur pour '
#           'violences conjugales'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/0/0/3000/2000/110/73/60/0/a69c126_1701248481462-illu-final-vie-d-ado-2-zoevadim.jpg',
#  'title': 'Ma vie d’ado : « J’essaie d’éduquer mes parents, mais ils '
#           'n’écoutent pas »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/199/0/602/401/110/73/60/0/5dbdd96_1701092460393-9782226486523-j.jpg',
#  'title': '« Je me suis sentie si seule avec mes questionnements face au '
#           'trouble de l’attention »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/541/0/5700/3800/110/73/60/0/20b90aa_1701275860439-pns-703002124.jpg',
#  'title': '« Business schools » : « Les générations actuelles d’étudiants sont '
#           'en demande d’horizons élargis »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/0/0/5568/3712/110/73/60/0/e853834_1701428164364-000-8zy932.jpg',
#  'title': 'Logement étudiant : les pistes du gouvernement pour atteindre 35 '
#           '000 nouvelles constructions d’ici à 2027'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/0/0/2125/1417/110/73/60/0/73101fa_1701178258370-clubmed-def-ok.jpg',
#  'title': 'Les désillusions de certains élèves ingénieurs : « Les gens pensent '
#           'qu’à l’X on est une élite, mais c’est le Club Med »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/1/0/5256/3504/110/73/60/0/bdb7708_1701362725178-maxnewsworldfive587059.jpg',
#  'title': 'L’ombre de l’antisémitisme fracture la communauté étudiante dans '
#           'les universités'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/21/109/0/4567/3044/110/73/60/0/defd4e8_1700565543224-10-11.jpg',
#  'title': 'L’apprentissage en école de commerce, une formule gagnante et '
#           'opportuniste'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/181/0/7543/5028/110/73/60/0/96a9a0e_1701081415992-tdah-clr.jpg',
#  'title': 'Les difficultés des étudiants souffrant d’un trouble de l’attention '
#           ': « Pourquoi j’ai cette impression de ne pas fonctionner comme les '
#           'autres ? »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/57/0/7268/4845/110/73/60/0/afda881_1701097189279-000-33rb7jh.jpg',
#  'title': 'Pourquoi les groupes de niveau au collège pourraient accroître les '
#           'inégalités sans élever le niveau général'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/03/02/0/0/6000/4000/110/73/60/0/4656cf5_1677770202773-000-9m34fn.jpg',
#  'title': 'Education : « Pourquoi n’envisageons-nous pas que les élèves les '
#           'plus avancés puissent sauter la classe de CM2 ou la 6ᵉ ? »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/06/0/0/6000/4000/110/73/60/0/0b3ecbf_1699260481447-dsc08105.JPG',
#  'title': 'En écoles de commerce, ces « learning expeditions » qui allient '
#           'frisson et expérience de l’entrepreneuriat'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/26/0/0/3543/2362/110/73/60/0/d12e60a_1698331746805-premiei-re-fois-lemonde-01.jpg',
#  'title': '« Finale des championnats d’Europe. Arrivée au milieu, je déchire '
#           'mon dossard. Le début d’une descente aux enfers »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/16/0/0/3000/2000/110/73/60/0/da9a8c6_1700144377456-portrait-marie-pericard-service-civiquea-helene-jayet-pour-le-monde-07162.jpg',
#  'title': 'Des étudiants racontent comment une année de césure les a aidés à '
#           'choisir leur voie : « J’étais perdue, je me suis trouvée »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/23/1/0/6000/4000/110/73/60/0/b01418e_5945822-01-06.jpg',
#  'title': 'Dominique Méda, sociologue : « Cessons de répéter que les jeunes ne '
#           'veulent plus travailler »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/05/22/0/0/2125/1417/110/73/60/0/c9aa0cb_1684760189910-parcoursup-choix2-exe.jpg',
#  'title': 'Déçus par Parcoursup, comment avez-vous rebondi ?'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2013/07/29/6/0/1024/683/110/73/60/0/ill_3454886_e0a6_binge.jpg',
#  'title': 'L’alcool sur les campus, une problématique épineuse pour les écoles '
#           'et les universités'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/15/610/0/1890/1260/110/73/60/0/ce11491_1700044216768-115da50-1686048314389-v2.jpg',
#  'title': 'Les « Rich Kids of Instagram », ces fils et filles à papa vantards '
#           'et flambeurs'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/21/0/0/5568/3712/110/73/60/0/2bdfb3e_1700577830198-000-32fa4fz.jpg',
#  'title': 'Carole Grandjean, ministre déléguée chargée de l’enseignement '
#           'professionnel : « En terminale, nous proposerons des parcours '
#           'différenciés aux élèves selon leur projet »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/21/426/0/4423/2948/110/73/60/0/25b16da_1700559341065-2-3.jpg',
#  'title': 'En école de commerce, l’endettement des étudiants s’aggrave : « Je '
#           'n’ai pas le droit à l’erreur et plus vraiment de flexibilité dans '
#           'le choix de mon orientation »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/20/90/0/7543/5028/110/73/60/0/95c0deb_1700474360004-sobriei-tei-clr.jpg',
#  'title': 'Ces vingtenaires qui se détournent de l’alcool : « Tu as '
#           'l’impression que c’est un anxiolytique rapide, mais, le lendemain, '
#           'tu doubles ton angoisse »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/0/0/5568/3712/110/73/60/0/1668e9d_1701709306262-pns-712210121.jpg',
#  'title': 'Développer les quadriceps pour retarder l’arthrose du genou'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/17/15/0/1280/853/110/73/60/0/534f914_1700212209088-4-5-web.jpeg',
#  'title': 'Pour les écoles de commerce, la voie royale de la prépa n’est '
#           'devenue qu’une option parmi d’autres'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/26/0/0/3543/2362/110/73/60/0/d12e60a_1698331746805-premiei-re-fois-lemonde-01.jpg',
#  'title': '« Au lycée, tous les élèves qui ne sont pas originaires d’Europe '
#           'occidentale sont qualifiés de “blédards”. A Sciences Po, je suis '
#           'devenu “étudiant international” »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/16/0/0/3000/2000/110/73/60/0/1dae624_1700127947834-le-temps-des-ei-tudiants.jpg',
#  'title': 'L’année de césure, une parenthèse pour bien choisir : « C’est '
#           'tellement normal de ne pas bien savoir où l’on va quand on a 20 ans '
#           '»'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/08/64/0/2133/1422/110/73/60/0/f678bbf_1699438737671-zerocalcare-foto-di-rosdiana-ciaravolo.jpeg',
#  'title': 'Zerocalcare, bédéaste italien : « J’ai connu, d’un côté, la vie '
#           'dans un quartier populaire. De l’autre, un univers exclusif, '
#           'international et cultivé. Partout, j’étais en décalage »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/16/0/0/3000/2000/110/73/60/0/1dae624_1700127947834-le-temps-des-ei-tudiants.jpg',
#  'title': 'Participez à la conférence « A 20 ans, faut-il perdre du temps pour '
#           'en gagner ? », le 28 novembre au « Monde »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2022/12/13/0/0/6000/4000/110/73/60/0/bf819e9_5994694-01-06.jpg',
#  'title': 'Les frères et sœurs étudiants « aidants », une vie dans l’ombre de '
#           'la maladie'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/07/06/0/0/1024/682/110/73/60/0/acf71cc_1688644928939-adobestock-203857417-1024x683.jpeg',
#  'title': 'Parcoursup : étudiants, parents d’élèves, vous avez fait le choix '
#           'd’un établissement en dehors de la plate-forme, racontez-nous'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/04/0/0/6000/4000/110/73/60/0/c5cdbbe_1699096714235-bod2023133n-9162.jpg',
#  'title': 'L’essor des stages ouvriers dans les écoles de commerce pour se '
#           'frotter au réel : « J’apprends à travailler en équipe »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/13/0/0/2121/1414/110/73/60/0/00c9a72_1699874469436-istock-start-2023.jpg',
#  'title': '« Le Monde » organise le Salon des formations artistiques, les 9 et '
#           '10 décembre à Paris'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/09/0/4/7032/4688/110/73/60/0/0740ce8_5828333-01-06.jpg',
#  'title': 'Gabriel Attal fait état de « résultats inquiétants » des élèves de '
#           '4e en français et en mathématiques'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/13/0/0/6000/4000/110/73/60/0/d0c4e6f_1697197232571-000-33uc2g6.jpg',
#  'title': 'Bac 2024 : la lourdeur des programmes inquiète les professeurs de '
#           'terminale'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/13/90/0/7543/5028/110/73/60/0/a705866_1699871012358-aidants-clr.jpg',
#  'title': 'Le destin bousculé des étudiants aidants : « J’étais épuisée '
#           'physiquement et moralement, je me suis dit que je n’arriverais pas '
#           'à tout concilier »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2018/10/28/0/4/4920/3280/110/73/60/0/f876b36_9eDI6Qg600ZGSRyinoVU2prg.jpg',
#  'title': 'Jeune chercheuse ou chercheur, à quoi rêvez-vous ?'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/12/0/0/6000/4000/110/73/60/0/7fc12a5_1699827130150-080-hl-jmbarrere-2116205.jpg',
#  'title': 'Mon master : premier bilan mitigé pour la nouvelle plate-forme'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/07/0/0/3543/2362/110/73/60/0/f45fb73_1699383816451-premiei-re-fois-lemonde-02.jpg',
#  'title': '« Mes parents ont tout fait pour qu’on soit catholiques, vieille '
#           'France, et ça n’a pas vraiment pris »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/07/398/0/5272/3514/110/73/60/0/9920c4f_1699367165336-lon57116.jpeg',
#  'title': 'Face aux désordres sociaux ou environnementaux, les petits gestes '
#           'suffiront-ils à faire advenir les grands changements ?'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/09/0/0/2125/1417/110/73/60/0/73a393d_1699559763279-hd-copie.jpg',
#  'title': 'Aux arts et métiers, les traditions de l’école perpétuent l’esprit '
#           'de corps'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/08/27/0/2220/1480/110/73/60/0/67e221c_1699457290791-situationship-chiaradattola.jpg',
#  'title': 'La « situationship », un flou relationnel qui se répand chez les '
#           'jeunes : « C’est horrible, comme mot, l’engagement ! On dirait la '
#           'fin de quelque chose »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2021/03/04/0/0/4368/2912/110/73/60/0/e82c29f_5573836-pns-796543.jpg',
#  'title': 'En Californie, vingt ans après la fin de la discrimination '
#           'positive, les résultats à l’université déçoivent'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/06/90/0/7543/5028/110/73/60/0/d61a170_1699267236473-affirmativeaction-clr.jpg',
#  'title': 'Aux Etats-Unis, la rentrée signe la fin de la discrimination '
#           'positive à l’université : « Beaucoup de jeunes Noirs et Latinos se '
#           'demandent s’ils ont leur place »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/06/0/0/6192/4128/110/73/60/0/57671b8_1699258204165-000-336j8hq.jpg',
#  'title': '« L’université sera l’un des piliers autour duquel nous pourrons '
#           'remodeler notre cohésion sociale »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/26/0/0/3543/2362/110/73/60/0/d12e60a_1698331746805-premiei-re-fois-lemonde-01.jpg',
#  'title': '« Il naît chez moi une passion pour les fleurs que je n’avais '
#           'jamais ressentie dans l’ingénierie »'}
# 2023-12-05 13:45:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/26/735/0/2362/1574/110/73/60/0/f2953a4_1698309229071-37a3609.jpg',
# ...
#           'étend désormais son offensive'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/63/0/1425/950/110/73/60/0/47004b4_1701427056583-enfantsguerre1-1-1-1.jpg',
#  'title': 'Le cinéma de Jocelyne Saab, une certaine poésie du désastre'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/1/0/8192/5461/110/73/60/0/d32a1cb_77a529183a6548d292e627c1007ac772-1-bdb6a1aa58994ac4831dd3db325bfc03.jpg',
#  'title': 'A Gaza, les combats ont repris, Israël et le Hamas s’accusent '
#           'mutuellement d’avoir rompu la trêve'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/294/0/1161/774/110/73/60/0/0aedc87_314695-3349480.jpg',
#  'title': 'Hiam Abbass dans « Bye Bye Tibériade » : un déracinement et des '
#           'ailes'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/0/0/6148/4098/110/73/60/0/af97d0a_1701440807330-943498.jpg',
#  'title': 'Les images de la reprise des frappes israéliennes sur la bande de '
#           'Gaza'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/1/0/6115/4076/110/73/60/0/345200b_1701445986323-000-339v2mn.jpg',
#  'title': 'Des Malawites en quête de travail en Israël, « une chance », en '
#           'dépit de la guerre'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/0/319/3429/2286/110/73/60/0/ae4d18f_2023-11-30t223709z-524033159-rc2yn4a44mgw-rtrmadp-3-israel-palestinians-hostages.JPG',
#  'title': 'Guerre Israël-Hamas : « Les acquis de la trêve doivent ouvrir la '
#           'voie de l’humanité »'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/0/0/5472/3648/110/73/60/0/d0abec7_5975701-01-06.jpg',
#  'title': 'Le « New York Times » affirme que le renseignement israélien savait '
#           'que le Hamas préparait une attaque inédite'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/0/0/5808/3872/110/73/60/0/3f9ff48_1701419826865-006450.jpg',
#  'title': 'Guerre Israël-Hamas : le bruit des explosions résonne de nouveau à '
#           'Gaza, après sept jours de trêve gagnés un à un de haute lutte'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/1/0/8192/5461/110/73/60/0/f6326ca_1701328398491-20231129-lbn-diegoibarrasanchez-004.jpg',
#  'title': '« Au Liban du Sud, une simple erreur de jugement pourrait '
#           'déclencher une escalade »'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/0/0/3811/2540/110/73/60/0/26eb5e5_1701354578582-240289.jpg',
#  'title': 'Guerre Israël-Hamas : Emmanuel Macron à Dubaï pour rencontrer des '
#           'dirigeants arabes'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/0/0/5549/3699/110/73/60/0/3fac303_5001223-01-06.jpg',
#  'title': 'Rony Brauman, François Ruffin et Marine Tondelier : « La demande '
#           'par la France de l’entrée de la CPI à Gaza rendrait notre pays de '
#           'nouveau audible à l’international »'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/1/0/8192/5461/110/73/60/0/2b29fa2_1701400249908-002425.jpg',
#  'title': 'Guerre Israël-Hamas : « Jérusalem est en train de bouillir »'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/0/0/1023/682/110/73/60/0/dce80a7_2023-11-30t182328z-2076863590-rc2un4a3t8y3-rtrmadp-3-israel-palestinians-hostages.JPG',
#  'title': 'La Franco-Israélienne Mia Schem libérée de la bande de Gaza'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/0/0/7812/5208/110/73/60/0/052c7df_5999371-01-06.jpg',
#  'title': 'Les images de l’attaque revendiquée par le Hamas, à Jérusalem'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/0/0/1600/1066/110/73/60/0/4f3adc2_1701336437358-940115.jpg',
#  'title': 'La trêve entre le Hamas et Israël tient encore, malgré tout'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/1/0/8192/5461/110/73/60/0/64a8013_1701328406688-20231129-lbn-diegoibarrasanchez-006.jpg',
#  'title': 'Le Hezbollah promet d’indemniser les habitants du Liban sud'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/0/0/4723/3149/110/73/60/0/c865e2b_1701330589631-1z8a0461-a-11-23.jpg',
#  'title': 'Dans le désert du Néguev, la 460ᵉ brigade blindée israélienne '
#           'attend de reprendre les combats'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/30/0/6370/4246/110/73/60/0/b8445f1_1701275974784-988980.jpg',
#  'title': 'L’embarras de Washington face à la stratégie israélienne'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/0/0/6907/4605/110/73/60/0/d278508_5997426-01-06.jpg',
#  'title': 'Guerre Israël-Hamas : les médiateurs s’efforcent d’obtenir une '
#           'nouvelle prolongation de la trêve censée prendre fin jeudi'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/0/0/5500/3666/110/73/60/0/920ed0c_2023-11-29t160931z-1135107451-rc21n4ao57pg-rtrmadp-3-israel-palestinians-gaza.JPG',
#  'title': '« Pour l’après-guerre entre Israël et la Palestine, il n’y a pas '
#           'd’autre horizon réaliste que celui de la formule des deux Etats »'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/0/0/4252/2834/110/73/60/0/8344023_1701189029189-000-33xw4an.jpg',
#  'title': 'Avant la guerre, une filière d’émigration des Gazaouis vers '
#           'l’Europe en plein essor'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/0/0/6720/4480/110/73/60/0/9abbb28_1701245489026-935860.jpg',
#  'title': 'Guerre Israël-Hamas : la trêve, répit insuffisant face à l’ampleur '
#           'de la catastrophe à Gaza'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/0/0/6811/4541/110/73/60/0/dad7e63_1701189375043-000-33yu2n4.jpg',
#  'title': 'Guerre Israël-Hamas : les frustrations et la solidarité discrète de '
#           'la diaspora palestinienne aux Emirats arabes unis'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/29/0/0/8044/5363/110/73/60/0/30d4fcb_5989833-01-06.jpg',
#  'title': 'Israël-Hamas : les premiers témoignages des otages sur les '
#           'conditions de leur captivité'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/257/0/2858/1905/110/73/60/0/9500be9_1701168714894-tal-bruttmann-2.jpg',
#  'title': 'Tal Bruttmann, historien : « Le Hamas a conçu, en amont, une '
#           'politique de terreur visuelle destinée à être diffusée dans le '
#           'monde entier »'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/26/804/0/7910/5273/110/73/60/0/9350eb7_1700959369898-ll-tel-aviv-otages-hd-18.jpg',
#  'title': 'Guerre Israël-Hamas : ce que l’on sait des conditions de détention '
#           'des otages israéliens libérés'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/0/0/7972/5315/110/73/60/0/8b494b3_1701178780683-ap23281394186613.jpg',
#  'title': 'Israël-Hamas : « Le Monde » face à la guerre des images'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/0/0/5500/3666/110/73/60/0/d379cfe_1701186325947-240131.jpg',
#  'title': 'Guerre Israël-Hamas : « Les bombardements indiscriminés sont '
#           'contraires au droit international »'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/0/0/4878/3252/110/73/60/0/25a0a3b_5976437-01-06.jpg',
#  'title': 'Guerre Israël-Hamas : à Barcelone, l’Union pour la Méditerranée '
#           'cherche à préserver les ponts entre le monde arabe et l’Europe'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/0/0/1599/1066/110/73/60/0/c42ee97_1701161202217-238715.jpg',
#  'title': 'Guerre Israël-Hamas : à Gaza, une trêve fragile pour de nouvelles '
#           'libérations d’otages'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/0/0/5120/3413/110/73/60/0/7d2b1f8_2023-11-28t011646z-1524455906-rc2yl4a1kq9k-rtrmadp-3-israel-palestinians-hostages.JPG',
#  'title': 'Trois jeunes otages franco-israéliens ont été libérés par le Hamas'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/0/5/5253/3502/110/73/60/0/f87614d_1701070475963-987177.jpg',
#  'title': 'L’Espagne se pose en critique contre Israël dans une Union '
#           'européenne prudente'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/0/0/5047/3364/110/73/60/0/074d711_1701082439421-cbi1153054.jpg',
#  'title': 'Psychologie : à l’écoute des personnes traumatisées par les '
#           'attaques terroristes du Hamas le 7 octobre'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/0/0/2109/1406/110/73/60/0/18c7780_1701075122707-2022-12-14t141531z-1671027326-dpaf221214x911x011091-rtrfipp-4-unrest-conflict-history-defence.JPG',
#  'title': 'Pourquoi Yahya Sinouar, l’inflexible chef du Hamas, est le maître '
#           'du jeu à Gaza'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/27/0/0/5500/3666/110/73/60/0/224a1d9_1701076874631-220035.jpg',
#  'title': 'La difficile équation de Benyamin Nétanyahou, entre la trêve pour '
#           'les otages et la guerre contre le Hamas'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/24/1/0/7679/5119/110/73/60/0/8fbba82_1700818809846-075-zawrzel-streetar221228-nptkr.jpg',
#  'title': 'Guerre Israël-Hamas : « Il faut une véritable offensive de paix au '
#           'Proche-Orient »'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/26/527/0/7910/5273/110/73/60/0/6808c62_1700990603001-ll-tel-aviv-otages-hd-35.jpg',
#  'title': 'Avec la libération d’otages au compte-gouttes, le Hamas poursuit la '
#           'guerre contre Israël sur le terrain psychologique'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/24/1/0/7679/5119/110/73/60/0/8fbba82_1700818809846-075-zawrzel-streetar221228-nptkr.jpg',
#  'title': '« A Gaza, plus de cent employés des Nations unies sont morts, c’est '
#           'sans précédent »'}
# 2023-12-05 13:45:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/25/0/0/6000/4000/110/73/60/0/85739ab_5961204-01-06.jpg',
#  'title': 'Jamais la Palestine n’a autant souffert'}
# 2023-12-05 13:45:29 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-05 13:45:29 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 12249,
#  'downloader/request_count': 31,
#  'downloader/request_method_count/GET': 31,
#  'downloader/response_bytes': 2577322,
#  'downloader/response_count': 31,
#  'downloader/response_status_count/200': 31,
#  'elapsed_time_seconds': 1.402094,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 5, 12, 45, 29, 646932, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 10239880,
#  'httpcompression/response_count': 31,
#  'item_scraped_count': 1530,
#  'log_count/DEBUG': 1562,
#  'log_count/ERROR': 3,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'request_depth_max': 1,
#  'response_received_count': 31,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 30,
#  'scheduler/dequeued/memory': 30,
#  'scheduler/enqueued': 30,
#  'scheduler/enqueued/memory': 30,
#  'spider_exceptions/IndexError': 3,
#  'start_time': datetime.datetime(2023, 12, 5, 12, 45, 28, 244838, tzinfo=datetime.timezone.utc)}
# 2023-12-05 13:45:29 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Postprocessing
#
# Si l'on se réfère au diagramme d'architecture de Scrapy, on voit qu'il
# est possible d'insérer des composants supplémentaires dans le flux de
# traitement. Ces composants s'appellent `Pipelines`.
#
# Par défaut, tous les `Item` générés au sein d'un projet Scrapy passent
# par les `Pipelines`. Les pipelines sont utilisés la plupart du temps
# pour :
#
# -   Nettoyer du contenu HTML ;
# -   Valider les données scrapées ;
# -   Supprimer les items qu'on ne souhaite pas stocker ;
# -   Stocker ces objets dans des bases de données.
#
# Les pipelines doivent être définis dans le fichier `pipelines.py`.
#
# Dans notre cas on peut vouloir nettoyer le champ `title` pour enlever
# les caractères superflus.
#
# Nous allons alors transferer la fonction de nettoyage du code html dans
# une Pipeline.

# %%
# %load newscrawler/newscrawler/pipelines.py

# Define your item pipelines here
#
# Don't forget to add your pipeline to the ITEM_PIPELINES setting
# See: https://docs.scrapy.org/en/latest/topics/item-pipeline.html

from scrapy.exceptions import DropItem

class TextPipeline(object):

    def process_item(self, item, spider):
        if item['title']:
            item["title"] = clean_spaces(item["title"])
            return item
        else:
            raise DropItem("Missing title in %s" % item)


def clean_spaces(string):
    if string:
        return " ".join(string.split())

# %% [markdown]
# Pour dire au process Scrapy de faire transiter les items par ces
# pipelines. Il faut le spécifier dans le fichier de paramétrage
# `settings.py`.

# %%
ITEM_PIPELINES = {
     'newscrawler.pipelines.TextPipeline': 300,
 }

# %% [markdown]
# On peut maintenant supprimer la fonction `clean_spaces()` de
# l'extraction des données et laisser le Pipeline faire son travail. La
# valeur entière définie permet de déterminer l'ordre dans lequel les
# pipelines vont être appelés. Ces entiers peuvent être compris entre 0 et
# 1000.
#
# On relance notre spider :

# %%
scrapy crawl lemonde -o ../data/articles.json
# Out:
#   Cell In[55], line 1
#     scrapy crawl lemonde -o ../data/articles.json
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# On peut aussi utiliser les Pipelines pour stocker les données récupérées
# dans une base de données. Pour stocker les items dans des documents
# mongo :

# %%
import pymongo

class MongoPipeline(object):

    collection_name = 'scrapy_items'

    def open_spider(self, spider):
        self.client = pymongo.MongoClient()
        self.db = self.client["lemonde"]

    def close_spider(self, spider):
        self.client.close()

    def process_item(self, item, spider):
        self.db[self.collection_name].insert_one(dict(item))
        return item

# %% [markdown]
# Ici on redéfinit deux autres méthodes: `open_spider()`et
# `close_spider()`, ces méthodes sont appelées comme leur nom l'indique,
# lorsque la Spider est instanciée et fermée.
#
# Ces méthodes nous permettent d'ouvrir la connexion Mongo et de la fermer
# lorsque le scraping se termine. La méthode `process_item()` est appelé à
# chaque fois qu'un item passe dans le mécanisme interne de scrapy. Ici,
# la méthode permet d'insérer l'item en tant que document mongo.
#
# Pour que ce pipeline soit appelé il faut l'ajouter dans les settings du
# projet.

# %%
ITEM_PIPELINES = {
    'newscrawler.pipelines.TextPipeline': 100,
    'newscrawler.pipelines.MongoPipeline': 300
}

# %% [markdown]
# Le pipeline est ajoutée à la fin du process pour profiter des deux
# précédents.
#
# ## Settings
#
# Scrapy permet de gérer le comportement des spiders avec certains
# paramètres. Comme expliqué dans le premier cours, il est important de
# suivre des règles en respectant la structure des différents sites. Il
# existe énormément de paramètres mais nous allons (dans le cadre de ce
# cours) aborder les plus utilisés :
#
# -   DOWNLOAD\_DELAY : Le temps de téléchargement entre chaque requête
#     sur le même domaine ;
# -   CONCURRENT\_REQUESTS\_PER\_DOMAIN : Nombre de requêtes simultanées
#     par domaine ;
# -   CONCURRENT\_REQUESTS\_PER\_IP : Nombre de requêtes simultanées par
#     IP ;
# -   DEFAULT\_REQUEST\_HEADERS : Headers HTTP utilisés pour les requêtes
#     ;
# -   ROBOTSTXT\_OBEY : Scrapy récupère le robots.txt et adapte le
#     scraping en fonction des règles trouvées ;
# -   USER\_AGENT : UserAgent utilisé pour faire les requêtes ;
# -   BOT\_NAME : Nom du bot annoncé lors des requêtes
# -   HTTPCACHE\_ENABLED : Utilisation du cache HTTP, utile lors du
#     parcours multiple de la même page.
#
# Le fichiers `settings.py` permet de définir les paramètres globaux d'un
# projet. Si votre projet contient un grand nombre de spiders, il peut
# être intéressant d'avoir des paramètres distincts pour chaque spider. Un
# moyen simple est d'ajouter un attribut `custom_settings` à votre spider
# :

# %%
class LeMondeSpider(scrapy.Spider):
        name = "lemonde"
        allowed_domains = ["lemonde.fr"]
        start_urls = ['http://lemonde.fr/']
        custom_settings = {
            "HTTPCACHE_ENABLED":True, 
            "CONCURRENT_REQUESTS_PER_DOMAIN":100
        }
