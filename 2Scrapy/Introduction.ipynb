# %% [markdown]
# # Introduction
#
# [Scrapy](https://scrapy.org/) est un framework permettant de crawler des
# sites web et d'en extraire les données de façon structurée.
#
# ## Installation
#
# Nous travaillerons dans un environnement
# [Anaconda](https://www.anaconda.com/download/), déjà présent sur les
# machines de l'ESIEE. Sur vos machines personnelles, télécharger la
# distribution correspondant à la version la plus récente de Python.
#
# [Scrapy](https://scrapy.org/) ne fait pas partie de la distribution par
# défaut de Python et doit être installé manuellement. Ici, le package est
# déjà installé grâce à Pipenv.
#
# Si vous avez besoin d'installer dans un autre cadre.
#
# -   Avec **Pipenv** : `pipenv install scrapy`
# -   Avec **Anaconda** : `conda install -c conda-forge scrapy`
#
# Tester la réussite de l'opération dans un interpréteur Python. Avant
# installation:

# %%
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (2.11.0)
# Requirement already satisfied: Twisted<23.8.0,>=18.9.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (22.10.0)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (41.0.7)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (1.8.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (23.3.0)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: service-identity>=18.1.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (23.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (2.1.2)
# Requirement already satisfied: zope.interface>=5.1.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (6.1)
# Requirement already satisfied: protego>=0.1.15 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (0.8.0)
# Requirement already satisfied: setuptools in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (68.2.0)
# Requirement already satisfied: packaging in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (23.2)
# Requirement already satisfied: tldextract in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (5.1.1)
# Requirement already satisfied: lxml>=4.4.1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (4.9.3)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from cryptography>=36.0.0->scrapy) (1.16.0)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from service-identity>=18.1.0->scrapy) (23.1.0)
# Requirement already satisfied: pyasn1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.5.1)
# Requirement already satisfied: pyasn1-modules in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.3.0)
# Requirement already satisfied: constantly>=15.1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (23.10.4)
# Requirement already satisfied: incremental>=21.3.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: Automat>=0.8.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (4.8.0)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (1.0.4)
# Requirement already satisfied: idna in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from tldextract->scrapy) (3.6)
# Requirement already satisfied: requests>=2.1.0 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from tldextract->scrapy) (2.31.0)
# Requirement already satisfied: requests-file>=1.4 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from tldextract->scrapy) (3.13.1)
# Requirement already satisfied: six in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from Automat>=0.8.0->Twisted<23.8.0,>=18.9.0->scrapy) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\keren\documents\dsia4101\dsia_4101a\dataengineertools\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2023.11.17)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import scrapy

# %% [markdown]
# ## Architecture
#
# [Scrapy](https://scrapy.org/) est un framework comportant plusieurs
# composants.
#
# <img src="images/architecture.png" alt="image" class="align-center" />
#
# L'ensemble du processus est contrôlé par l'**engine** (les termes anglo
# saxons ont été retenus pour un meilleur référencement dans la
# [documentation officielle](https://docs.scrapy.org/en/latest/)).
#
# Le framework est articulé avec plusieurs composants qui gèrent chacun un
# rôle différent. Nous allons les détailler.
#
# -   Les **Spiders** : permettent de naviguer sur un site et de
#     référencer les règles d'extraction de la donnée.
# -   Les **Pipelines** : font le lien entre la donnée brute et des objets
#     structurés
# -   Les **Middlewares** : permettent d'effectuer des transformations sur
#     les objets ou sur les requêtes exécutées par l'engine.
# -   Le **Scheduler** : gère l'ordre et le timing des requêtes
#     effectuées.
#
# ## Fonctionnement
#
# [Scrapy](https://scrapy.org/) est entièrement organisé autour d'un
# composant central : l'*engine*.
#
# Le rôle de l'*engine* est de contrôler le flux de données entre les
# différents composants du système.
#
# 1.  En particulier, il est chargé de récupérer les *requests* définies
#     dans les *spiders*
# 2.  Ces *requests* sont ensuite fournies au *scheduler* qui se charge de
#     leur ordonnancement
# 3.  Les *requests* sont présentées selon cet ordonnancement à
#     l'*engine*...
# 4.  ... qui les transmet au *downloader*
# 5.  Le *downloader* effectue la *request* et transmet la *response* (le
#     contenu de la page web) à l'*engine*...
# 6.  ... puis l'envoie au *spider* pour traitement
# 7.  Le *spider* génére des *items* qui sont transmis à l'*engine*
# 8.  Les *items* sont ensuite poussés dans un pipeline pour nettoyage,
#     validation et stockage
#
# Ce processus est répété jusqu'à épuisement des requêtes.
#
# [Scrapy](https://scrapy.org/) est un [framework orienté
# événements](https://en.wikipedia.org/wiki/Event-driven_architecture)
# (basé sur [Twisted](https://twistedmatrix.com/)) permettant une
# programmation asynchrone (non bloquante). C'est particulièrement
# intéressant dans les opérations de scraping, puisque **le programme
# n'attend pas le résultat d'une requête pour en lancer une autre**.
#
# En effet, lorsque l'on sollicite une ressource (requête réseau, système
# de fichier, etc.) en mode bloquant, l'exécution du programme est
# suspendue le temps que la transaction avec la ressource se termine (par
# exemple le temps qu'une page web soit complètement téléchargée).
# L'intérêt de faire des appels non bloquants, c'est que l'on peut gérer
# de multiples téléchargements en parallèle, et que le programme peut
# continuer à tourner pendant ce temps.

# %% [markdown]
# # Un scraping élémentaire
#
# Avant de rentrer dans les détails du framework, nous allons mettre en
# oeuvre un premier script permettant de récupérer l'information présente
# sur [la page web](http://evene.lefigaro.fr/citations/winston-churchill)
# recensant les citations de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill).
#
# **Exercice**
#
# Examiner le code source de cette page avec l'inspecteur de votre
# navigateur. Identifier les éléments contenant l'information recherchée,
# ici la chaîne de caractères contenant la citation proprement dite.
#
# ## Le code source
#
# Le code utilisé est le suivant:

# %%
class ChurchillQuotesSpider(scrapy.Spider):
    name = "citations de Churchill"
    start_urls = ["http://evene.lefigaro.fr/citations/winston-churchill",]

    def parse(self, response):
        for cit in response.xpath('//div[@class="figsco__quote__text"]'):
            text_value = cit.xpath('a/text()').extract_first()
            
            cleaned_text = text_value.replace('“', '').replace('”', '')
            
            yield { 'text' : cleaned_text }

# %% [markdown]
# ## Le fonctionnement
#
# Le fonctionnement est le suivant:
#
# -   On importe le module [Scrapy](https://scrapy.org/) (3)
# -   et on définit une sous classe de `scrapy.Spider` (5)
# -   la variable `start_urls` contient la liste des pages à scraper (7)
# -   On redéfinit la méthode $parse$ dont la signature est définie dans
#     la classe mère (9)
# -   L'objet
#     [response](https://docs.scrapy.org/en/latest/topics/request-response.html#response-objects)
#     représente la réponse à la requête HTTP (l'attribut $text$ permet
#     d'accéder à son contenu). On recherche ensuite tous les containers
#     `<div>` identifiés dans l'exercice précédent. Ici la page est
#     particulièrement bien structurée et les citations disposent de leur
#     propre container, identifié par l'attribut `class` de valeur
#     `figsco__quote__text`. La sélection se fait par une expression
#     [XPath](https://en.wikipedia.org/wiki/XPath), un langage de
#     sélection de noeud dans un document XML (10). En langage naturel, la
#     requête pourrait se formuler : "On recherche tous les containers
#     `<div>` dont la valeur de l'attribut `class` est égal à
#     `figsco__quote__text`".
# -   Pour chaque résultat, on construit un dictionnaire dont la clé est
#     `text` et la valeur le contenu du lien `<a>`. Ce résultat est fourni
#     par un générateur ($yield$) (12).
#
# On lance le scraping depuis un terminal:

# %% [markdown]
# On y trouve des informations sur les paramètres
# utilisés:

# %%
# !scrapy runspider citations_churchill_spider1.py
# Out:
# 2023-12-20 13:20:21 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2023-12-20 13:20:21 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
# 2023-12-20 13:20:21 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-20 13:20:21 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-20 13:20:22 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-20 13:20:22 [scrapy.extensions.telnet] INFO: Telnet Password: 1f073998e0a0490f
# 2023-12-20 13:20:22 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-20 13:20:22 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2023-12-20 13:20:22 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-20 13:20:22 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-20 13:20:22 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-20 13:20:22 [scrapy.core.engine] INFO: Spider opened
# 2023-12-20 13:20:22 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-20 13:20:22 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-20 13:20:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.'}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "Un conciliateur c'est quelqu'un qui nourrit un crocodile en espérant qu'il sera le dernier à être mangé."}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'Il est une bonne chose de lire des livres de citations, car les citations lorsqu’elles sont gravées dans la mémoire vous donnent de bonnes pensées.'}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "Je suis toujours prêt à apprendre, bien que je n'aime pas toujours qu'on me donne des leçons."}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "C'est une belle chose d'être honnête, mais il est également important d'avoir raison."}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'J’ai retiré plus de choses de l’alcool que l’alcool ne m’en a retirées.'}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "Pour s'améliorer, il faut changer. Donc, pour être parfait, il faut avoir changé souvent."}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "On considère le chef d'entreprise comme un homme à abattre, ou une vache à traire. Peu voient en lui le cheval qui tire le char."}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'En Angleterre, tout est permis, sauf ce qui est interdit. En Allemagne, tout est interdit, sauf ce qui est permis. En France, tout est permis, même ce qui est interdit. En U.R.S.S., tout est interdit, même ce qui est permis.'}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'On vit de ce que l’on obtient.\rOn construit sa vie sur ce que l’on donne.'}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "Si deux hommes ont toujours la même opinion, l'un d'eux est de trop."}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'Plus vous saurez regarder loin dans le passé, plus vous verrez loin dans le futur.'}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'L’Angleterre s’écroule dans l’ordre, et la France se relève dans le désordre.'}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "En avalant les méchantes paroles qu'on ne profère pas, on ne s'est jamais abîmé l'estomac."}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': 'Comité : Un groupe de personnes incapables de faire quoi que ce soit par elles-mêmes qui décident collectivement que rien ne peut être fait !'}
# 2023-12-20 13:20:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'author': 'Winston Churchill a dit...', 'text': "Les baisers qu'on ne reçoit pas sont peut-être plus intéressants que ceux qu'on reçoit."}
# 2023-12-20 13:20:23 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-20 13:20:23 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 245,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 14851,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.266801,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 20, 12, 20, 23, 87404, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 85054,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 16,
#  'log_count/DEBUG': 18,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 12, 20, 12, 20, 22, 820603, tzinfo=datetime.timezone.utc)}
# 2023-12-20 13:20:23 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
2023-11-29 11:10:07 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
2023-11-29 11:10:07 [scrapy.crawler] INFO: Overridden settings: {'SPIDER_LOADER_WARN_ONLY': True}
# Out:
#   Cell In[7], line 1
#     2023-11-29 11:10:07 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
#                      ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# les
# [extensions](https://docs.scrapy.org/en/latest/topics/extensions.html)
# ...:

# %%
2023-11-29 11:10:08 [scrapy.middleware] INFO: Enabled extensions:
['scrapy.extensions.corestats.CoreStats',
'scrapy.extensions.telnet.TelnetConsole',
'scrapy.extensions.logstats.LogStats']

# %% [markdown]
# [Les composants middleware
# downloader](https://docs.scrapy.org/en/latest/topics/downloader-middleware.html)
# ... :

# %%
2023-11-29 11:48:20 [scrapy.middleware] INFO: Enabled downloader middlewares:
['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
 'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
 'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
 'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
 'scrapy.downloadermiddlewares.retry.RetryMiddleware',
 'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
 'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
 'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
 'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
 'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
 'scrapy.downloadermiddlewares.stats.DownloaderStats']

# %% [markdown]
# Idem pour [les composants middleware
# spider](https://docs.scrapy.org/en/latest/topics/spider-middleware.html)
# ...:

# %%
2023-11-29 11:48:20 [scrapy.middleware] INFO: Enabled spider middlewares:
['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
 'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
 'scrapy.spidermiddlewares.referer.RefererMiddleware',
 'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
 'scrapy.spidermiddlewares.depth.DepthMiddleware']

# %% [markdown]
# Aucun
# [pipeline](https://docs.scrapy.org/en/latest/topics/item-pipeline.html)
# n'est activé :

# %%
2023-11-29 11:48:20 [scrapy.middleware] INFO: Enabled item pipelines:
[]

# %% [markdown]
# **Exercice**
#
# Identifier la position des [composants middleware
# downloader](https://docs.scrapy.org/en/latest/topics/downloader-middleware.html),
# des [composants middleware
# spider](https://docs.scrapy.org/en/latest/topics/spider-middleware.html)
# et du
# [pipeline](https://docs.scrapy.org/en/latest/topics/item-pipeline.html)
# dans $l'architecture <Introduction>$
#
# L'exécution du scraping proprement dit débute :

# %%
2023-11-29 11:50:45 [scrapy.core.engine] INFO: Spider opened
2023-11-29 11:50:45 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
2023-11-29 11:50:45 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# Out:
#   File "C:\Users\keren\AppData\Local\Temp\ipykernel_23300\4224969182.py", line 1
#     2018-01-10 17:21:05 [scrapy.core.engine] INFO: Spider opened
#           ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# La première URL est poussée par le scheduler:

# %%
2023-11-29 11:50:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)

# %% [markdown]
# ## Les résultats
#
# Les résultats sont fournis par le générateur défini dans la méthode
# $parse$ dans un dictionnaire. Ils contiennent le texte des citations
# dans la valeur de la clé `text` :

# %%
2023-11-29 11:50:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>

{'text': 'Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.'}
2023-11-29 11:50:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>

{'text': "Un conciliateur c'est quelqu'un qui nourrit un crocodile en espérant qu'il sera le dernier à être mangé."}

# %% [markdown]
# ## Les statistiques
#
# Une fois le scraping effectué, quelques statistiques sont affichées sur
# le terminal:

# %%
2023-11-29 11:50:45 [scrapy.core.engine] INFO: Closing spider (finished)
2023-11-29 11:50:45 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
{'downloader/request_bytes': 248,
 'downloader/request_count': 1,
 'downloader/request_method_count/GET': 1,
 'downloader/response_bytes': 14812,
 'downloader/response_count': 1,
 'downloader/response_status_count/200': 1,
 'elapsed_time_seconds': 0.216067,
 'finish_reason': 'finished',
 'finish_time': datetime.datetime(2023, 11, 29, 10, 50, 45, 685437),
 'httpcompression/response_bytes': 84969,
 'httpcompression/response_count': 1,
 'item_scraped_count': 16,
 'log_count/DEBUG': 18,
 'log_count/INFO': 10,
 'response_received_count': 1,
 'scheduler/dequeued': 1,
 'scheduler/dequeued/memory': 1,
 'scheduler/enqueued': 1,
 'scheduler/enqueued/memory': 1,
 'start_time': datetime.datetime(2023, 11, 29, 10, 50, 45, 469370)}
2023-11-29 11:50:45 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On observe notamment que notre code permet de récupérer la taille de la
# page web (17435 bytes), le temps d'exécution à partir des valeurs
# `finish_time` et `start_time`, le nombre d'items scrapés (16), etc...
#
# **Exercice**
#
# Les citations extraites sont elles toutes de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill) ? Il sera
# peut être nécessaire de modifier le sélecteur XPath. Nous verrons ça
# lorsque il faudra récupérer les données relative à l'auteur.
#
# ## Modifier les données
#
# Il est parfois nécessaire de faire un traitement sur les données
# scrapées, pour ajouter ou retirer de l'information.
#
# **Exercice**
#
# Retirer les caractères `“` et `”` qui délimitent la citation. Ces
# caractères sont identifiés en Unicode comme [LEFT DOUBLE QUOTATION
# MARK](http://www.fileformat.info/info/unicode/char/201c/index.htm) et
# [RIGHT DOUBLE QUOTATION
# MARK](http://www.fileformat.info/info/unicode/char/201d/index.htm).
#
# ## Plus de données
#
# Il est souvent nécessaire de récupérer plusieurs informations relatives
# à un même item. Dans cet exemple, il est judicieux d'associer à la
# citation le nom de son auteur, en allant chercher cette information au
# plus près du texte lui même.
#
# **Exercice**
#
# Examiner le code source de la page web et identifier la structuration de
# la donnée associée à l'auteur. En déduire l'expression XPath permettant
# de la récupérer. S'assurer que seules les citations de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill) sont
# extraites. Ajouter une clé `author` au dictionnaire retourné par le
# $yield$ dont la valeur est précisément la chaîne de caractères contenant
# l'auteur.
#
# Un exemple de dictionnaire retourné:

# %%
import scrapy

class ChurchillQuotesSpider(scrapy.Spider):
    name = "citations de Churchill"
    start_urls = ["http://evene.lefigaro.fr/citations/winston-churchill",]

    def parse(self, response):
        # Trouver l'auteur sur la page
        author = response.css('a[href="/celebre/biographie/winston-churchill-675.php"]::text').extract_first()

        for cit in response.xpath('//div[@class="figsco__quote__text"]'):
            text_value = cit.xpath('a//text()').extract_first()

            # Supprimer les caractères “ et ” avec la méthode replace
            cleaned_text = text_value.replace('“', '').replace('”', '')

            yield {'author': author, 'text': cleaned_text}

# %%
{   'text': "“Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.”", 
    'author': 'Winston Churchill'}
# Out:
# {'text': "“Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.”",
#  'author': 'Winston Churchill'}

# %% [markdown]
# Pour lancer l'exécution de la spider :
#
# > \$ scrapy runspider spiders/citations\_churchill\_spider2.py
#
# On peut aussi vouloir stocker les données extraites :
#
# > \$ scrapy runspider spiders/citations\_churchill\_spider2.py -o
# > data/citation.json -t json

# %%
# Lancement de l'exécution de la spider :
# Commande : scrapy runspider citations_churchill_spider1.py
2023-12-20 13:31:57 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
2023-12-20 13:31:57 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
2023-12-20 13:31:57 [scrapy.addons] INFO: Enabled addons:
[]
2023-12-20 13:31:57 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.

It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.

See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
  return cls(crawler)

2023-12-20 13:31:57 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
2023-12-20 13:31:57 [scrapy.extensions.telnet] INFO: Telnet Password: c75924e966bb167e
2023-12-20 13:31:57 [scrapy.middleware] INFO: Enabled extensions:
['scrapy.extensions.corestats.CoreStats',
 'scrapy.extensions.telnet.TelnetConsole',
 'scrapy.extensions.logstats.LogStats']
2023-12-20 13:31:57 [scrapy.crawler] INFO: Overridden settings:
{'SPIDER_LOADER_WARN_ONLY': True}
2023-12-20 13:31:57 [scrapy.middleware] INFO: Enabled downloader middlewares:
['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
 'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
 'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
 'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
 'scrapy.downloadermiddlewares.retry.RetryMiddleware',
 'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
 'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
 'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
 'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
 'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
 'scrapy.downloadermiddlewares.stats.DownloaderStats']
2023-12-20 13:31:57 [scrapy.middleware] INFO: Enabled spider middlewares:
['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
 'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
 'scrapy.spidermiddlewares.referer.RefererMiddleware',
 'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
 'scrapy.spidermiddlewares.depth.DepthMiddleware']
2023-12-20 13:31:57 [scrapy.middleware] INFO: Enabled item pipelines:
[]
2023-12-20 13:31:57 [scrapy.core.engine] INFO: Spider opened
2023-12-20 13:31:57 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
2023-12-20 13:31:57 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
2023-12-20 13:31:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.'}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "Un conciliateur c'est quelqu'un qui nourrit un crocodile en espérant qu'il sera le dernier à être mangé."}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'Il est une bonne chose de lire des livres de citations, car les citations lorsqu’elles sont gravées dans la mémoire vous donnent de bonnes pensées.'}       
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "Je suis toujours prêt à apprendre, bien que je n'aime pas toujours qu'on me donne des leçons."}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "C'est une belle chose d'être honnête, mais il est également important d'avoir raison."}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'J’ai retiré plus de choses de l’alcool que l’alcool ne m’en a retirées.'}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "Pour s'améliorer, il faut changer. Donc, pour être parfait, il faut avoir changé souvent."}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "On considère le chef d'entreprise comme un homme à abattre, ou une vache à traire. Peu voient en lui le cheval qui tire le char."}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'En Angleterre, tout est permis, sauf ce qui est interdit. En Allemagne, tout est interdit, sauf ce qui est permis. En France, tout est permis, même ce qui est interdit. En U.R.S.S., tout est interdit, même ce qui est permis.'}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'On vit de ce que l’on obtient.\rOn construit sa vie sur ce que l’on donne.'}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "Si deux hommes ont toujours la même opinion, l'un d'eux est de trop."}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'Plus vous saurez regarder loin dans le passé, plus vous verrez loin dans le futur.'}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'L’Angleterre s’écroule dans l’ordre, et la France se relève dans le désordre.'}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "En avalant les méchantes paroles qu'on ne profère pas, on ne s'est jamais abîmé l'estomac."}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'Comité : Un groupe de personnes incapables de faire quoi que ce soit par elles-mêmes qui décident collectivement que rien ne peut être fait !'}
2023-12-20 13:31:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "Les baisers qu'on ne reçoit pas sont peut-être plus intéressants que ceux qu'on reçoit."}
2023-12-20 13:31:58 [scrapy.core.engine] INFO: Closing spider (finished)
2023-12-20 13:31:58 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
{'downloader/request_bytes': 245,
 'downloader/request_count': 1,
 'downloader/request_method_count/GET': 1,
 'downloader/response_bytes': 14851,
 'downloader/response_count': 1,
 'downloader/response_status_count/200': 1,
 'elapsed_time_seconds': 0.292117,
 'finish_reason': 'finished',
 'finish_time': datetime.datetime(2023, 12, 20, 12, 31, 58, 37732, tzinfo=datetime.timezone.utc),
 'httpcompression/response_bytes': 85054,
 'httpcompression/response_count': 1,
 'item_scraped_count': 16,
 'log_count/DEBUG': 18,
 'log_count/INFO': 10,
 'log_count/WARNING': 1,
 'response_received_count': 1,
 'scheduler/dequeued': 1,
 'scheduler/dequeued/memory': 1,
 'scheduler/enqueued': 1,
 'scheduler/enqueued/memory': 1,
 'start_time': datetime.datetime(2023, 12, 20, 12, 31, 57, 745615, tzinfo=datetime.timezone.utc)}
2023-12-20 13:31:58 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# Stocker les données extraites
# Commande :  scrapy runspider citations_churchill_spider1.py -o data\citation.json -t json

C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\commands\__init__.py:171: ScrapyDeprecationWarning: The -t/--output-format command line option is deprecated in favor 
of specifying the output format within the output URI using the -o/--output or the -O/--overwrite-output option (i.e. -o/-O <URI>:<FORMAT>). See the documentation of the -o or -O option or the following examples for more information. Examples working in the tutorial: scrapy crawl quotes -o quotes.csv:csv   or   scrapy crawl quotes -O quotes.json:json
  feeds = feed_process_params_from_cli(
2023-12-20 13:34:07 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
2023-12-20 13:34:07 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
2023-12-20 13:34:07 [scrapy.addons] INFO: Enabled addons:
[]
2023-12-20 13:34:07 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.

It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.

See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
  return cls(crawler)

2023-12-20 13:34:07 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
2023-12-20 13:34:07 [scrapy.extensions.telnet] INFO: Telnet Password: ca9b7c24c0a532e5
2023-12-20 13:34:07 [scrapy.middleware] INFO: Enabled extensions:
['scrapy.extensions.corestats.CoreStats',
 'scrapy.extensions.telnet.TelnetConsole',
 'scrapy.extensions.feedexport.FeedExporter',
 'scrapy.extensions.logstats.LogStats']
2023-12-20 13:34:07 [scrapy.crawler] INFO: Overridden settings:
{'SPIDER_LOADER_WARN_ONLY': True}
2023-12-20 13:34:07 [scrapy.middleware] INFO: Enabled downloader middlewares:
['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
 'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
 'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
 'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
 'scrapy.downloadermiddlewares.retry.RetryMiddleware',
 'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
 'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
 'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
 'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
 'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
 'scrapy.downloadermiddlewares.stats.DownloaderStats']
2023-12-20 13:34:07 [scrapy.middleware] INFO: Enabled spider middlewares:
['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
 'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
 'scrapy.spidermiddlewares.referer.RefererMiddleware',
 'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
 'scrapy.spidermiddlewares.depth.DepthMiddleware']
2023-12-20 13:34:07 [scrapy.middleware] INFO: Enabled item pipelines:
[]
2023-12-20 13:34:07 [scrapy.core.engine] INFO: Spider opened
2023-12-20 13:34:07 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
2023-12-20 13:34:07 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
2023-12-20 13:34:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.'}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "Un conciliateur c'est quelqu'un qui nourrit un crocodile en espérant qu'il sera le dernier à être mangé."}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'Il est une bonne chose de lire des livres de citations, car les citations lorsqu’elles sont gravées dans la mémoire vous donnent de bonnes pensées.'}       
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "Je suis toujours prêt à apprendre, bien que je n'aime pas toujours qu'on me donne des leçons."}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "C'est une belle chose d'être honnête, mais il est également important d'avoir raison."}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'J’ai retiré plus de choses de l’alcool que l’alcool ne m’en a retirées.'}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "Pour s'améliorer, il faut changer. Donc, pour être parfait, il faut avoir changé souvent."}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "On considère le chef d'entreprise comme un homme à abattre, ou une vache à traire. Peu voient en lui le cheval qui tire le char."}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'En Angleterre, tout est permis, sauf ce qui est interdit. En Allemagne, tout est interdit, sauf ce qui est permis. En France, tout est permis, même ce qui est interdit. En U.R.S.S., tout est interdit, même ce qui est permis.'}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'On vit de ce que l’on obtient.\rOn construit sa vie sur ce que l’on donne.'}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "Si deux hommes ont toujours la même opinion, l'un d'eux est de trop."}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'Plus vous saurez regarder loin dans le passé, plus vous verrez loin dans le futur.'}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'L’Angleterre s’écroule dans l’ordre, et la France se relève dans le désordre.'}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "En avalant les méchantes paroles qu'on ne profère pas, on ne s'est jamais abîmé l'estomac."}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': 'Comité : Un groupe de personnes incapables de faire quoi que ce soit par elles-mêmes qui décident collectivement que rien ne peut être fait !'}
2023-12-20 13:34:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'author': 'Winston Churchill a dit...', 'text': "Les baisers qu'on ne reçoit pas sont peut-être plus intéressants que ceux qu'on reçoit."}
2023-12-20 13:34:07 [scrapy.core.engine] INFO: Closing spider (finished)
2023-12-20 13:34:07 [scrapy.extensions.feedexport] INFO: Stored json feed (16 items) in: data\citation.json
2023-12-20 13:34:07 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
{'downloader/request_bytes': 245,
 'downloader/request_count': 1,
 'downloader/request_method_count/GET': 1,
 'downloader/response_bytes': 14852,
 'downloader/response_count': 1,
 'downloader/response_status_count/200': 1,
 'elapsed_time_seconds': 0.225028,
 'feedexport/success_count/FileFeedStorage': 1,
 'finish_reason': 'finished',
 'finish_time': datetime.datetime(2023, 12, 20, 12, 34, 7, 828092, tzinfo=datetime.timezone.utc),
 'httpcompression/response_bytes': 85054,
 'httpcompression/response_count': 1,
 'item_scraped_count': 16,
 'log_count/DEBUG': 18,
 'log_count/INFO': 11,
 'log_count/WARNING': 1,
 'response_received_count': 1,
 'scheduler/dequeued': 1,
 'scheduler/dequeued/memory': 1,
 'scheduler/enqueued': 1,
 'scheduler/enqueued/memory': 1,
 'start_time': datetime.datetime(2023, 12, 20, 12, 34, 7, 603064, tzinfo=datetime.timezone.utc)}
2023-12-20 13:34:07 [scrapy.core.engine] INFO: Spider closed (finished)
# Out:
#   Cell In[9], line 4
#     C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\commands\__init__.py:171: ScrapyDeprecationWarning: The -t/--output-format command line option is deprecated in favor
#        ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# # Votre premier projet
#
#
# Dans un premier temps vous devez créer un projet Scrapy avec la commande
# :

# %%
# !scrapy startproject newscrawler
# Out:
# Error: scrapy.cfg already exists in C:\Users\keren\Documents\ESIEE\E4\S1\P2\DSIA_4201C_DataEngineerTools\DataEngineerTools\2Scrapy\newscrawler

# %% [markdown]
# Cette commande va créer un dossier `monprojet` contenant les éléments
# suivants correspondant au squelette :

# %%
newscrawler/
    scrapy.cfg            # Options de déploiement

    newscrawler/             # Le module Python contenant les informations
        __init__.py

        items.py          # Fichier contenant les items

        middlewares.py    # Fichier contenant les middlewares

        pipelines.py      # Fichier contenant les pipelines

        settings.py       # Fichier contenant les paramètres du projet

        spiders/          # Dossier contenant toutes les spiders
            __init__.py
# Out:
#   Cell In[11], line 1
#     newscrawler/
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Votre première Spider
#
# Une Spider est une classe Scrapy qui permet de mettre en place toute
# l'architecture complexe vue dans l'introduction. Pour définir une
# spider, il vous faut hériter de la classe $scrapy.Spider$. La seule
# chose à faire est de définir la première requête à effectuer et comment
# suivre les liens. La Spider s'arrêtera lorsqu'elle aura parcouru tous
# les liens qu'on lui a demandé de suivre.
#
# Pour créer une Spider on utilise la syntaxe:

# %%
# !scrapy genspider <SPIDER_NAME> <DOMAIN_NAME>
# Out:
# < ‚tait inattendu.

# %% [markdown]
# Par exemple,

# %%
# !cd newscrawler && scrapy genspider lemonde lemonde.fr
# Out:
# Spider 'lemonde' already exists in module:
#   newscrawler.spiders.lemonde

# %% [markdown]
# Cette commande permet de créer une spider appelée `lemonde` pour scraper
# le domaine `lemonde.fr`. Cela crée le fichier Python
# `spiders/lemonde.py` suivant :

# %%
# %load newscrawler/newscrawler/spiders/lemonde.py
import scrapy


class LemondeSpider(scrapy.Spider):
    name = 'lemonde'
    allowed_domains = ['lemonde.fr']
    start_urls = ['http://lemonde.fr/']

    def parse(self, response):
        pass

# %% [markdown]
# Une bonne pratique pour commencer à développer une Spider est de passer
# par l'interface Shell proposée par Scrapy. Elle permet de récupérer un
# objet `Response` et de tester les méthodes de récupération des données.

# %% [markdown]
# # ATTENTION : Les commandes scrapy shell doivent être lancées dans un terminal

# %%
# !scrapy shell 'http://lemonde.fr'
# Out:
# 2023-12-20 13:36:25 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2023-12-20 13:36:25 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
# 2023-12-20 13:36:25 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-20 13:36:25 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-20 13:36:25 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-20 13:36:25 [scrapy.extensions.telnet] INFO: Telnet Password: b3a344a180f1d719
# 2023-12-20 13:36:25 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole']
# 2023-12-20 13:36:25 [scrapy.crawler] INFO: Overridden settings:
# {'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter',
#  'LOGSTATS_INTERVAL': 0}
# 2023-12-20 13:36:25 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-20 13:36:25 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-20 13:36:25 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-20 13:36:25 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-20 13:36:25 [scrapy.core.engine] INFO: Spider opened
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Scripts\scrapy.exe\__main__.py", line 7, in <module>
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\cmdline.py", line 161, in execute
#     _run_print_help(parser, _run_command, cmd, args, opts)
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\cmdline.py", line 114, in _run_print_help
#     func(*a, **kw)
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\cmdline.py", line 169, in _run_command
#     cmd.run(args, opts)
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\commands\shell.py", line 88, in run
#     shell.start(url=url, redirect=not opts.no_redirect)
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\shell.py", line 43, in start
#     self.fetch(url, spider, redirect=redirect)
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\shell.py", line 118, in fetch
#     response, spider = threads.blockingCallFromThread(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\twisted\internet\threads.py", line 120, in blockingCallFromThread
#     result.raiseException()
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\twisted\python\failure.py", line 504, in raiseException
#     raise self.value.with_traceback(self.tb)
# ValueError: invalid hostname: 'http

# %% [markdown]
# Pour les utilisateurs de windows il vous faut mettre des doubles quotes
# :

# %%
scrapy shell "http://lemonde.fr"
# Out:
#   Cell In[12], line 1
#     scrapy shell "http://lemonde.fr"
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# Scrapy lance un kernel Python

# %%
2018-12-02 16:05:50 [scrapy.utils.log] INFO: Scrapy 1.3.3 started (bot: newscrawler)
2018-12-02 16:05:50 [scrapy.utils.log] INFO: Overridden settings: {'BOT_NAME': 'newscrawler', 'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter', 'LOGSTATS_INTERVAL': 0, 'NEWSPIDER_MODULE': 'newscrawler.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['newscrawler.spiders']}
2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled extensions:
['scrapy.extensions.corestats.CoreStats',
'scrapy.extensions.telnet.TelnetConsole']
2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled downloader middlewares:
['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
'scrapy.downloadermiddlewares.retry.RetryMiddleware',
'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
'scrapy.downloadermiddlewares.stats.DownloaderStats']
2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled spider middlewares:
['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
'scrapy.spidermiddlewares.referer.RefererMiddleware',
'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
'scrapy.spidermiddlewares.depth.DepthMiddleware']
2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled item pipelines:
[]
2018-12-02 16:05:50 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
2018-12-02 16:05:50 [scrapy.core.engine] INFO: Spider opened
2018-12-02 16:05:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
2018-12-02 16:05:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/> (referer: None)
2018-12-02 16:05:54 [traitlets] DEBUG: Using default logger
2018-12-02 16:05:54 [traitlets] DEBUG: Using default logger
[s] Available Scrapy objects:
[s]   scrapy     scrapy module (contains scrapy.Request, scrapy.Selector, etc)
[s]   crawler    <scrapy.crawler.Crawler object at 0x10fc38c18>
[s]   item       {}
[s]   request    <GET https://www.lemonde.fr/>
[s]   response   <200 https://www.lemonde.fr/>
[s]   settings   <scrapy.settings.Settings object at 0x113bb0898>
[s]   spider     <DefaultSpider 'default' at 0x113e60cc0>
[s] Useful shortcuts:
[s]   fetch(url[, redirect=True]) Fetch URL and update local objects (by default, redirects are followed)
[s]   fetch(req)                  Fetch a scrapy.Request and update local objects
[s]   shelp()           Shell help (print this help)
[s]   view(response)    View response in a browser

# %%
# Lancement du kernel 
# Commmande Terminal : scrapy shell "http://lemonde.fr"
2023-12-20 13:44:05 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
2023-12-20 13:44:05 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
2023-12-20 13:44:05 [scrapy.addons] INFO: Enabled addons:
[]
2023-12-20 13:44:05 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.

It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.

See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
  return cls(crawler)

2023-12-20 13:44:05 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
2023-12-20 13:44:05 [scrapy.extensions.telnet] INFO: Telnet Password: 52955231a08a7da9
2023-12-20 13:44:05 [scrapy.middleware] INFO: Enabled extensions:
['scrapy.extensions.corestats.CoreStats',
 'scrapy.extensions.telnet.TelnetConsole']
2023-12-20 13:44:05 [scrapy.crawler] INFO: Overridden settings:
{'BOT_NAME': 'newscrawler',
 'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter',
 'LOGSTATS_INTERVAL': 0,
 'NEWSPIDER_MODULE': 'newscrawler.spiders',
 'ROBOTSTXT_OBEY': True,
 'SPIDER_MODULES': ['newscrawler.spiders']}
2023-12-20 13:44:05 [scrapy.middleware] INFO: Enabled downloader middlewares:
['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
 'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
 'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
 'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
 'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
 'scrapy.downloadermiddlewares.retry.RetryMiddleware',
 'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
 'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
 'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
 'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
 'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
 'scrapy.downloadermiddlewares.stats.DownloaderStats']
2023-12-20 13:44:05 [scrapy.middleware] INFO: Enabled spider middlewares:
['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
 'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
 'scrapy.spidermiddlewares.referer.RefererMiddleware',
 'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
 'scrapy.spidermiddlewares.depth.DepthMiddleware']
2023-12-20 13:44:05 [scrapy.middleware] INFO: Enabled item pipelines:
[]
2023-12-20 13:44:05 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
2023-12-20 13:44:05 [scrapy.core.engine] INFO: Spider opened
2023-12-20 13:44:05 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.lemonde.fr/robots.txt> from <GET http://lemonde.fr/robots.txt>
2023-12-20 13:44:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
2023-12-20 13:44:05 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.lemonde.fr/> from <GET http://lemonde.fr>
2023-12-20 13:44:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
2023-12-20 13:44:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/> (referer: None)
[s] Available Scrapy objects:
[s]   scrapy     scrapy module (contains scrapy.Request, scrapy.Selector, etc)
[s]   crawler    <scrapy.crawler.Crawler object at 0x000002104C450650>
[s]   item       {}
[s]   request    <GET http://lemonde.fr>
[s]   response   <200 https://www.lemonde.fr/>
[s]   settings   <scrapy.settings.Settings object at 0x000002104C413810>
[s]   spider     <LemondeSpider 'lemonde' at 0x2104cad44d0>
[s] Useful shortcuts:
[s]   fetch(url[, redirect=True]) Fetch URL and update local objects (by default, redirects are followed)
[s]   fetch(req)                  Fetch a scrapy.Request and update local objects
[s]   shelp()           Shell help (print this help)
[s]   view(response)    View response in a browser
2023-12-20 13:44:06 [asyncio] DEBUG: Using proactor: IocpProactor

# %% [markdown]
# Grâce à cette interface, vous avez accès à plusieurs objets comme la
# `Response`, la `Request`, la `Spider` par exemple. Vous pouvez aussi
# exécuter `view(response)` pour afficher ce que Scrapy récupère dans un
# navigateur.

# %%
In [2]: response
Out[2]: <200 https://www.lemonde.fr/>

In [3]: request
Out[3]: <GET http://lemonde.fr>

In [4]: type(request)
Out[4]: scrapy.http.request.Request

In [1]: spider
Out[1]: <LemondeSpider 'lemonde' at 0x2104cad44d0>

In [5]: type(spider)
Out[5]: newscrawler.spiders.lemonde.LemondeSpider

# %% [markdown]
# Ici on voit que la Spider est une instance de LemondeSpider. Lorsqu'on
# lance le $scrapy shell$ scrapy va chercher dans les spiders si une
# correspond au lien passé en paramètre, si oui , il l'utilise sinon une
# $DefaultSpider$ est instanciée.
#
# ## Vos premières requêtes
#
# On peut commencer à regarder comment extraire les données de la page web
# en utilisant le langage de requêtes proposé par Scrapy. Il existe deux
# types de requêtes : les requêtes `css` et `xpath`. Les requêtes `xpath`
# sont plus complexes mais plus puissantes que les requêtes `css`. Dans le
# cadre de ce tutorial, nous allons uniquement aborder les requêtes `css`,
# elles nous suffiront pour extraire les données dont nous avons besoin
# (en interne, Scrapy transforme les requêtes `css`en requêtes `xpath`.
#
# Que ce soit les requêtes `css` ou `xpath`, elles crééent des sélecteurs
# de différents types. Quelques exemples :
#
# Pour récupérer le titre d'une page :

# %%
In [6]: response.css('title')
Out[6]: [<Selector query='descendant-or-self::title' data='<title>Le Monde.fr - Actualités et In...'>]

# %% [markdown]
# On récupère une liste de sélecteurs correspondant à la requête `css`
# appelée. La requête précédente était unique, d'autres requêtes moins
# restrictives permettent de récupérer plusieurs résultats. Par exemple
# pour rechercher l'ensemble des liens présents sur la page, on va
# rechercher les balises HTML `<a></a>`

# %%
In [7]: response.css("a")[0:10]
Out[7]:
[<Selector query='descendant-or-self::a' data='<a href="https://www.lemonde.fr" clas...'>,
 <Selector query='descendant-or-self::a' data='<a href="https://www.lemonde.fr/en/" ...'>,
 <Selector query='descendant-or-self::a' data='<a rel="noopener" target="_blank" dat...'>,
 <Selector query='descendant-or-self::a' data='<a href="/">  <div class="logo__lemon...'>,
 <Selector query='descendant-or-self::a' data='<a class="Header__offer  Header__offe...'>,
 <Selector query='descendant-or-self::a' data='<a class="Header__connexion js-header...'>,
 <Selector query='descendant-or-self::a' data='<a href="https://abo.lemonde.fr/?lmd_...'>,
 <Selector query='descendant-or-self::a' data='<a href="/" class="Burger__right-arro...'>,
 <Selector query='descendant-or-self::a' data='<a id="js-home-tab-continu" href="htt...'>,
 <Selector query='descendant-or-self::a' data='<a href="https://www.lemonde.fr" clas...'>]

# %% [markdown]
# Pour récupérer le texte contenu dans les balises, on passe le paramètre
# `<TAG>::text`. Par exemple :

# %%
In [8]: response.css("title::text")
Out[8]: [<Selector query='descendant-or-self::title/text()' data='Le Monde.fr - Actualités et Infos en ...'>]

# %% [markdown]
# ### Exercice
#
#   Comparer les résultats des deux requêtes `response.css('title')` et
# `response.css('title::text')`.
#
# => La première requête (response.css("title::text")) cible le texte à l'intérieur de la balise <title>, alors que la deuxième requête (response.css('title')) cible directement la balise <title> elle-même.
#
# Maintenant pour extraire les données des selecteurs on utilise l'une des
# deux méthodes suivantes : - `extract()` permet de récupérer une liste
# des données extraites de tous les sélecteurs - `extract_first()` permet
# de récupérer une `String` provenant du premier sélecteur de la liste.

# %%
In [9]: response.css('title::text').extract_first()
Out[9]: 'Le Monde.fr - Actualités et Infos en France et dans le monde'

# %% [markdown]
# On peut récupérer un attribut d'une balise avec la syntaxe
# `<TAG>::attr(<ATTRIBUTE_NAME>)` :
#
# Par exemple, les liens sont contenus dans un attribut `href`.

# %%
In [10]: response.css('a::attr(href)')[0:10]
Out[10]:
[<Selector query='descendant-or-self::a/@href' data='https://www.lemonde.fr'>,
 <Selector query='descendant-or-self::a/@href' data='https://www.lemonde.fr/en/'>,
 <Selector query='descendant-or-self::a/@href' data='https://journal.lemonde.fr'>,
 <Selector query='descendant-or-self::a/@href' data='/'>,
 <Selector query='descendant-or-self::a/@href' data='https://abo.lemonde.fr/offre-offrir?l...'>,
 <Selector query='descendant-or-self::a/@href' data='https://secure.lemonde.fr/sfuser/conn...'>,
 <Selector query='descendant-or-self::a/@href' data='https://abo.lemonde.fr/?lmd_medium=BO...'>,
 <Selector query='descendant-or-self::a/@href' data='/'>,
 <Selector query='descendant-or-self::a/@href' data='https://www.lemonde.fr/'>,
 <Selector query='descendant-or-self::a/@href' data='https://www.lemonde.fr'>]

# %% [markdown]
# Comme vu précédemment, si on veut récupérer la liste des liens de la page on applique la méthode $extract()$

# %%
In [11]: response.css('a::attr(href)').extract()[0:10]
Out[11]:
['https://www.lemonde.fr',
 'https://www.lemonde.fr/en/',
 'https://journal.lemonde.fr',
 '/',
 'https://abo.lemonde.fr/offre-offrir?lmd_medium=display&lmd_campaign=cnv_offrir_lmfr&lmd_creation=gratuit_dec-2023&lmd_variant=cta&lmd_format=header&lmd_source=autopromo',
 'https://secure.lemonde.fr/sfuser/connexion',
 'https://abo.lemonde.fr/?lmd_medium=BOUTONS_LMFR&lmd_campaign=CTA_LMFR&lmd_position=HEADER&lmd_sequence=5&lmd_type_de_page=Home',
 '/',
 'https://www.lemonde.fr/',
 'https://www.lemonde.fr']

# %% [markdown]
# Les liens dans une page HTML sont souvent codés de manière relative par
# rapport à la page courante. La méthode de l'objet `Response` peut être
# utilisée pour recréer l'url complet.
#
# Un exemple sur le 4e élément :

# %%
In [14]: response.urljoin(response.css('a::attr(href)').extract()[8])
Out[14]: 'https://www.lemonde.fr/carlos-ghosn/'

# Fait
In [15]: response.urljoin(response.css('a::attr(href)').extract()[6])
Out[15]: 'https://abo.lemonde.fr/?lmd_medium=BOUTONS_LMFR&lmd_campaign=CTA_LMFR&lmd_position=HEADER&lmd_sequence=5&lmd_type_de_page=Home'

# %% [markdown]
# alors que

# %%
In [15]: response.css('a::attr(href)').extract()[8]
Out[15]: '/carlos-ghosn/'

# Fait
In [17]: response.css('a::attr(href)').extract()[6]
Out[17]: 'https://abo.lemonde.fr/?lmd_medium=BOUTONS_LMFR&lmd_campaign=CTA_LMFR&lmd_position=HEADER&lmd_sequence=5&lmd_type_de_page=Home'

# %% [markdown]
# ### Exercice :
#
# Utiliser une liste compréhension pour transformer les 10
# premiers liens relatifs récupérés par la méthode `extract()` en liens
# absolus.
#
# Le résultat doit ressembler à :

# %%
relative_links = response.css('a::attr(href)').extract()[0:10]

# Transforme les liens relatifs en liens absolus avec response.urljoin
absolute_links = [response.urljoin(link) for link in relative_links]

# Affiche les liens absolus
print(absolute_links)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 relative_links = response.css('a::attr(href)').extract()[0:10]
#       3 # Transforme les liens relatifs en liens absolus avec response.urljoin
#       4 absolute_links = [response.urljoin(link) for link in relative_links]
#
# NameError: name 'response' is not defined

# %%
Out[23]: 
['https://journal.lemonde.fr',
'https://www.lemonde.fr/',
'https://secure.lemonde.fr/sfuser/connexion',
'https://abo.lemonde.fr/#xtor=CS1-454[CTA_LMFR]-[HEADER]-5-[Home]',
'https://www.lemonde.fr/',
'https://www.lemonde.fr/',
'https://www.lemonde.fr/',
'https://www.lemonde.fr/mouvement-des-gilets-jaunes/',
'https://www.lemonde.fr/carlos-ghosn/',
'https://www.lemonde.fr/implant-files/']

# %%
 Obtenu : 
 ['https://www.lemonde.fr', 'https://www.lemonde.fr/en/', 'https://journal.lemonde.fr', 'https://www.lemonde.fr/', 'https://abo.lemonde.fr/offre-offrir?lmd_medium=display&lmd_campaign=cnv_offrir_lmfr&lmd_creation=gratuit_dec-2023&lmd_variant=cta&lmd_format=header&lmd_source=autopromo', 'https://secure.lemonde.fr/sfuser/connexion', 'https://abo.lemonde.fr/?lmd_medium=BOUTONS_LMFR&lmd_campaign=CTA_LMFR&lmd_position=HEADER&lmd_sequence=5&lmd_type_de_page=Home', 'https://www.lemonde.fr/', 'https://www.lemonde.fr/', 'https://www.lemonde.fr']

# %% [markdown]
# ## Des requêtes plus complexes
#
# On peut créer des requêtes plus complexes en utilisant à la fois la
# structuration HTML du document mais également la couche de présentation
# CSS. On utilise l'inspecteur de `Google Chrome` pour identifier le type
# et l'identifiant de la balise contenant les informations.
#
# Il y a au moins deux choses à savoir en `css` :
#
# -   Les `.` représentent les classes
# -   Les `#` représentent les id
#
# On se propose de récupérer toutes les sous-catégories de news dans la
# catégorie **Actualités**. On remarque en utilisant l'inspecteur
# d'élement de Chrome que toutes les catégories sont rangées dans une
# balise avec l'id $#nav-markup$ ensuite dans les classes $Nav__item$.
#
# A partir de cette structure HTML on peut construire la requête suivante
# pour récupérer la barre de navigation:

# %%
In [19]: response.css("#nav-markup")
Out[19]: [<Selector xpath="descendant-or-self::*[@id = 'nav-markup']" data='<ul id="nav-markup"> <li class="Nav__ite'>]

# %%
In [21]: response.css("#nav-markup")
Out[21]: [<Selector query="descendant-or-self::*[@id = 'nav-markup']" data='<ul id="nav-markup" class=""> <li cla...'>]

# %% [markdown]
# Ensuite pour récupérer les différentes catégories :

# %%
In [24]: response.css("#nav-markup .Nav__item")
Out[24]:
[<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item js-burger-to-show N'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--home Nav'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="/" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="/recherc'>]

# %%
In [22]: response.css("#nav-markup .Nav__item")
Out[22]:
[<Selector query="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item js-burger-to-sho...'>,
 <Selector query="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item-home N...'>,
 <Selector query="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item-en-con...'>,
 <Selector query="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--dropp...'>,
 <Selector query="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--dropp...'>,
 <Selector query="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--dropp...'>,
 <Selector query="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--dropp...'>,
 <Selector query="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--dropp...'>,
 <Selector query="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--dropp...'>,
 <Selector query="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--dropp...'>,
 <Selector query="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item-search...'>]

2023-12-20 13:55:00 [asyncio] DEBUG: Using proactor: IocpProactor

# %% [markdown]
# On veut maintenant retourner tous les liens présents dans cette
# catégorie. On remarque qu'elle apparait à la 4eme position.

# %%
In [34]: response.css("#nav-markup .Nav__item")[3]
Out[34]: <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>

# %%
In [23]: response.css("#nav-markup .Nav__item")[3]
Out[23]: <Selector query="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--dropp...'>

# %% [markdown]
# Maintenant pour récupérer tous les liens on peut chainer les requêtes.
# On accède alors à toutes les balises $a$.

# %%
In [35]: response.css("#nav-markup .Nav__item")[3].css("a")
Out[35]:
[<Selector xpath='descendant-or-self::a' data='<a href="#" class="js-dropdown Burger__r'>,
<Selector xpath='descendant-or-self::a' data='<a href="/mouvement-des-gilets-jaunes/" '>,
<Selector xpath='descendant-or-self::a' data='<a href="/carlos-ghosn/" data-suggestion'>,
<Selector xpath='descendant-or-self::a' data='<a href="/implant-files/" data-suggestio'>,
<Selector xpath='descendant-or-self::a' data='<a href="/climat/" data-suggestion>Clima'>,
<Selector xpath='descendant-or-self::a' data='<a href="/affaire-khashoggi/" data-sugge'>,
<Selector xpath='descendant-or-self::a' data='<a href="/emmanuel-macron/" data-suggest'>,
<Selector xpath='descendant-or-self::a' data='<a href="/ukraine/" data-suggestion>Ukra'>,
<Selector xpath='descendant-or-self::a' data='<a href="/russie/" data-suggestion>Russi'>,
<Selector xpath='descendant-or-self::a' data='<a href="/referendum-sur-le-brexit/" dat'>,
<Selector xpath='descendant-or-self::a' data='<a href="/harcelement-sexuel/" data-sugg'>,
<Selector xpath='descendant-or-self::a' data='<a href="/actualite-en-continu/" data-su'>,
<Selector xpath='descendant-or-self::a' data='<a href="/international/">International<'>,
<Selector xpath='descendant-or-self::a' data='<a href="/politique/">Politique</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/societe/">Société</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/les-decodeurs/">Les Décodeurs<'>,
<Selector xpath='descendant-or-self::a' data='<a href="/sport/">Sport</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/planete/">Planète</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/sciences/">Sciences</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/campus/">M Campus</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/afrique/">Le Monde Afrique</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/pixels/">Pixels</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/actualite-medias/">Médias</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/sante/">Santé</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/big-browser/">Big Browser</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/disparitions/">Disparitions</a'>]

# %%
In [24]: response.css("#nav-markup .Nav__item")[3].css("a")
Out[24]:
[<Selector query='descendant-or-self::a' data='<a href="#" class="Nav__item-link js-...'>,
 <Selector query='descendant-or-self::a' data='<a href="https://www.lemonde.fr/proje...'>,
 <Selector query='descendant-or-self::a' data='<a href="https://www.lemonde.fr/attaq...'>,
 <Selector query='descendant-or-self::a' data='<a href="https://www.lemonde.fr/crise...'>,
 <Selector query='descendant-or-self::a' data='<a href="https://www.lemonde.fr/antis...'>,
 <Selector query='descendant-or-self::a' data='<a href="https://www.lemonde.fr/infla...'>,
 <Selector query='descendant-or-self::a' data='<a href="https://www.lemonde.fr/jeux-...'>,
 <Selector query='descendant-or-self::a' data='<a href="https://www.lemonde.fr/cop28...'>,
 <Selector query='descendant-or-self::a' data='<a href="https://www.lemonde.fr/actua...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>,
 <Selector query='descendant-or-self::a' data='<a class="" href="https://www.lemonde...'>]

# %% [markdown]
# Et pour récupérer les titres :

# %%
In [37]: response.css("#nav-markup .Nav__item")[3].css("a::text").extract()
Out[37]:
['Actualités',
'Mouvement des "gilets jaunes"',
'Carlos Ghosn',
'Implant Files',
'Climat',
'Affaire Khashoggi',
'Emmanuel Macron',
'Ukraine',
'Russie',
'Brexit',
'Harcèlement sexuel',
'Toute l’actualité en continu',
'International',
'Politique',
'Société',
'Les Décodeurs',
'Sport',
'Planète',
'Sciences',
'M Campus',
'Le Monde Afrique',
'Pixels',
'Médias',
'Santé',
'Big Browser',
'Disparitions']

# %%
In [25]: response.css("#nav-markup .Nav__item")[3].css("a::text").extract()
Out[25]:
['Actualités',
 'Loi immigration',
 'Guerre Israël-Hamas',
 'Guerre en Ukraine',
 'Antisémitisme',
 'Inflation',
 'Jeux olympiques de Paris 2024',
 'COP28',
 'Toute l’actualité en continu',
 'International',
 'Politique',
 'Société',
 'Planète',
 'Climat',
 'Le Monde Afrique',
 'Les Décodeurs',
 'Sport',
 'Education',
 'M Campus',
 'Santé',
 'Intimités',
 'Sciences',
 'Pixels',
 'Disparitions',
 'Le Fil Good',
 'Podcasts',
 'Le Monde & Vous']

# %% [markdown]
# Le shell Scrapy permet de définir la structure des requêtes et de
# s'assurer de la pertinence du résultat retourné. Pour automatiser le
# processus, il faut intégrer cette syntaxe au code Python des modules de
# spider définis dans la structure du projet.
#
# ## Intégration des requêtes
#
# Le squelette de la classe `LeMondeSpider` généré lors de la création du
# projet doit maintenant être enrichi. Par défaut 3 attributs et une
# méthode `parse()` ont été créés :
#
# -   `name` permet d'identifier sans ambiguïté la spider dans le code.
# -   `allowed_domain` permet de filtrer les requêtes et forcer la spider
#     à rester sur une liste de domaines.
# -   `starts_urls` est la liste des urls d'où la spider va partir pour
#     commencer son scraping.
# -   `parse()` est une méthode héritée de la classe `scrapy.Spider`. Elle
#     doit être redéfinie selon les requêtes que l'on doit effectuer et
#     sera appelée sur l'ensemble des urls contenus dans la liste
#     `starts_urls`.
#
# `parse()` est une fonction `callback` qui sera appelée automatiquement
# sur chaque objet `Response` retourné par la requête. Cette fonction est
# appelée de manière asynchrone. Plusieurs requêtes peuvent ainsi être
# lancées en parallèles sans bloquer le thread principal. L'objet
# `Response` passé en paramètre est le même que celui mis à disposition
# lors de l'exécution du Scrapy Shell.

# %%
def parse(self, response):
    title = response.css('title::text').extract_first()
    all_links = {
        name:response.urljoin(url) for name, url in zip(
        response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
        response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
    }
    yield {
        "title":title,
        "all_links":all_links
    }

# %% [markdown]
# La fonction est un générateur (`yield`) et retourne un dictionnaire
# composé de deux éléments :
#
# -   Le titre de la page;
# -   La liste des liens sortants sous forme de String.
#
# Pour le moment cette spider ne parcourt que la page d'accueil, ce qui
# n'est pas très productif.
#
# ## Votre premier scraper
#
# Récupérer les données sur un ensemble de pages webs nécessite d'explorer
# en profondeur la structure du site en suivant tout ou partie des liens
# rencontrés.
#
# La spider peut se `balader` sur un site assez efficacement. Il suffit de
# lui indiquer comment faire. Il faut spécifier à Scrapy de générer une
# requête vers une nouvelle page en construisant l'objet `Request`
# correspondant. Ce nouvel objet `Request` est alors inséré dans le
# scheduler de Scrapy. On peut évidemment générer plusieurs `Request`
# simultanément, correspondant par exemple, à différents liens sur la page
# courante. Ils sont insérés séquentiellement dans le scheduler.
#
# Pour cela on modifie la méthode `parse()` de façon à ce qu'elle retourne
# un objet `Request` pour chaque nouveau lien rencontré. On associe
# également à cet objet une fonction de callback qui déterminera la
# manière dont cette nouvelle page doit être extraite.
#
# Par exemple, pour que la spider continue dans les liens des différentes
# régions (pour l'instant la fonction de callback ne fait rien) :

# %%
# %load newscrawler/newscrawler/spiders/lemonde_v2.py
import scrapy
from scrapy import Request


class LemondeSpider(scrapy.Spider):
    name = "lemondev2"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name:response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        yield {
            "title":title,
            "all_links":all_links
        }

# %% [markdown]
# Pour lancer la spider

# %%
# !cd newscrawler && scrapy crawl lemondev2
# Out:
# 2023-12-20 13:57:20 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-12-20 13:57:20 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
# 2023-12-20 13:57:20 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-20 13:57:20 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-20 13:57:20 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-20 13:57:20 [scrapy.extensions.telnet] INFO: Telnet Password: 22bd75291ca83eba
# 2023-12-20 13:57:20 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-20 13:57:20 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-12-20 13:57:20 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-20 13:57:20 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-20 13:57:20 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-20 13:57:20 [scrapy.core.engine] INFO: Spider opened
# 2023-12-20 13:57:20 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-20 13:57:20 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-20 13:57:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-20 13:57:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2023-12-20 13:57:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr>
#
# {'title': 'Le Monde.fr - Actualités et Infos en France et dans le monde', 'all_links': {'Actualités': 'https://www.lemonde.fr', 'Loi immigration': 'https://www.lemonde.fr/projet-de-loi-immigration/', 'Guerre Israël-Hamas': 'https://www.lemonde.fr/attaque-du-hamas-contre-israel/', 'Guerre en Ukraine': 'https://www.lemonde.fr/crise-ukrainienne/', 'Antisémitisme': 'https://www.lemonde.fr/antisemitisme/', 'Inflation': 'https://www.lemonde.fr/inflation/', 'Jeux olympiques de Paris 2024': 'https://www.lemonde.fr/jeux-olympiques-2024/', 'COP28': 'https://www.lemonde.fr/cop28/', 'Toute l’actualité en continu': 'https://www.lemonde.fr/actualite-en-continu/', 'International': 'https://www.lemonde.fr/international/', 'Politique': 'https://www.lemonde.fr/politique/', 'Société': 'https://www.lemonde.fr/societe/', 'Planète': 'https://www.lemonde.fr/planete/', 'Climat': 'https://www.lemonde.fr/climat/', 'Le Monde Afrique': 'https://www.lemonde.fr/afrique/', 'Les Décodeurs': 'https://www.lemonde.fr/les-decodeurs/', 'Sport': 'https://www.lemonde.fr/sport/', 'Education': 'https://www.lemonde.fr/education/', 'M Campus': 'https://www.lemonde.fr/campus/', 'Santé': 'https://www.lemonde.fr/sante/', 'Intimités': 'https://www.lemonde.fr/intimites/', 'Sciences': 'https://www.lemonde.fr/sciences/', 'Pixels': 'https://www.lemonde.fr/pixels/', 'Disparitions': 'https://www.lemonde.fr/disparitions/', 'Le Fil Good': 'https://www.lemonde.fr/le-fil-good/', 'Podcasts': 'https://www.lemonde.fr/podcasts/', 'Le Monde & Vous': 'https://www.lemonde.fr/le-monde-et-vous/'}}
# 2023-12-20 13:57:20 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-20 13:57:20 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 440,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 81487,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 0.244398,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 20, 12, 57, 20, 970774, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 301988,
#  'httpcompression/response_count': 2,
#  'item_scraped_count': 1,
#  'log_count/DEBUG': 4,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 12, 20, 12, 57, 20, 726376, tzinfo=datetime.timezone.utc)}
# 2023-12-20 13:57:20 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On veut ensuite *entrer* dans les liens des différentes sous-catégories
# pour récupérer les articles. Pour cela, nous créons une méthode
# `parse_category()` prend en argument un objet `Response` qui sera la
# réponse correspondant aux liens des régions. On peut comme ceci
# traverser un site en définissant des méthodes différentes en fonction du
# type de contenu.
#
# Si la structure du site est plus profonde, on peut empiler autant de
# couches que souhaité.
#
# Quand on arrive sur une page d'une sous-catégorie, on peut vouloir
# récupérer tous les éléments de la page. Pour cela, on réutilise le
# scrapy Shell pour commencer le développement de la nouvelle méthode
# d'extraction.
#
# Par exemple pour la page `https://www.lemonde.fr/international/` :

# %%
scrapy shell 'https://www.lemonde.fr/international/'

# %% [markdown]
# Le fil des articles est stocké dans une balise avec la classe
# `class=river`.

# %%
In [3]: response.css(".river")
Out[3]:
[<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' fleuve ')]" data='<div class="fleuve">\n   <section>\n      '>,
<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' fleuve ')]" data='<div class="fleuve">\n</div>'>]

# %%
In [1]: response.css(".river")
Out[1]: [<Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' river ')]" data='<section id="river" class="page__cont...'>]

# %% [markdown]
# Pour récupérer chacun des articles, il faut adresser les balises
# `<article>` contenues dans le sélecteur:

# %%
In [4]: response.css(".river")[0].css(".teaser")
Out[4]:
[<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi mg'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>]

# %%
In [2]: response.css(".river")[0].css(".teaser")
Out[2]:
[<Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>,
 <Selector query="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' teaser ')]" data='<section class="teaser teaser--inline...'>]

# %% [markdown]
# Comme précédemment, on peut empiler les sélecteurs `css` pour créer des
# requêtes plus complexes.
#
# Par exemple, pour récupérer tous les titres des différents articles :

# %%
In [8]: response.css(".river")[0].css(".teaser h3::text").extract()
Out[8]:
['Des dizaines de milliers de Géorgiens contestent dans la rue l’élection de Salomé Zourabichvili\r\n\r\n\r\n',
'A Budapest en Hongrie, un îlot décroissant pour favoriser la transition\r\n\r\n\r\n',
'En Israël, la police recommande l’inculpation de Nétanyahou dans une troisième enquête\r\n\r\n\r\n',
'Donald Trump veut «\xa0mettre fin\xa0» à l’Aléna rapidement\r\n\r\n\r\n',
'Le cauchemar de la «\xa0rééducation\xa0» des musulmans en Chine\r\n\r\n',
'\r\n',
'«\xa0AMLO\xa0» lance sa transformation du Mexique\r\n\r\n\r\n',
'«\xa0Paris brûle\xa0»\xa0: les médias étrangers relatent le «\xa0chaos\xa0» en marge des défilés des «\xa0gilets jaunes\xa0»\r\n\r\n\r\n',
'Andrés Manuel Lopez Obrador intronisé président du Mexique\r\n\r\n\r\n']

# %%
In [3]: response.css(".river")[0].css(".teaser h3::text").extract()
Out[3]:
['Pologne\xa0: le nouveau gouvernement licencie les dirigeants des médias d’Etat',
 'Quel héritage pour Paris 2024\xa0? Des lendemains de fête difficiles après Athènes 2004',
 'En direct, guerre Israël-Hamas\xa0: le point sur la situation à la mi-journée',
 'En direct, guerre en\xa0Ukraine\xa0: les dernières informations',
 'DGSE\xa0: Nicolas Lerner va remplacer Bernard Emié à la tête du renseignement extérieur',
 'Quel héritage pour Paris 2024\xa0? La reconversion exemplaire du parc olympique de Londres 2012',
 'A court d’argent, Deutsche Bahn met en vente sa filiale logistique DB Schenker',
 'Quel héritage pour Paris\xa02024\xa0? Les métamorphoses de Barcelone lors des JO de 1992',
 'Guerre Israël-Hamas\xa0: à Gaza, le ciblage meurtrier des hôpitaux',
 'Des ONG appellent la Banque centrale européenne à favoriser les investissements verts',
 'Loi sur l’immigration\xa0: une rupture politique et morale',
 '«\xa0Avec l’élection de Javier Milei en Argentine, le futur disparaît de la politique »',
 'Mexique\xa0: les disparus de Lagos de Moreno',
 '«\xa0La Révolution Garo\xa0»\xa0: l’art de la contestation par le manga',
 'Aux origines de la «\xa0Terre sainte\xa0», ou la lente construction d’une Palestine «\xa0mythifiée\xa0»',
 'Donald Trump, écarté de la primaire du Colorado pour son rôle dans l’insurrection du 6\xa0janvier, remet son avenir présidentiel entre les mains de la Cour suprême',
 'La Vieille Ville de Jérusalem sous cloche',
 'Emin Özmen, le photographe qui documente les soubresauts de la Turquie',
 '«\xa0Influent et disrupteur, le Sud global défend ses intérêts, mais n’offre pas de modèle alternatif à l’ordre occidental\xa0»',
 'Hongkong atteint le taux de fécondité le plus bas du monde',
 'Pacte de stabilité\xa0: l’Union européenne proche d’un accord sur la réforme de ses règles budgétaires',
 'Présidentielle américaine 2024\xa0: Donald Trump déclaré inéligible dans le Colorado\xa0en raison de son rôle dans l’attaque du Capitole',
 'Decathlon a continué à approvisionner la Russie via une société-écran',
 'Guerre Israël-Hamas\xa0: le chef du Hamas se rend en Egypte mercredi pour discuter d’un cessez-le-feu',
 'L’hommage d’Etienne Balibar à Toni Negri\xa0: «\xa0Il aura été un lecteur et continuateur de Karl Marx, dans une étonnante combinaison de littéralité et de liberté\xa0»',
 'Grand remue-ménage dans les rangs des diplomates chargés de la politique africaine de la France',
 'En République démocratique du Congo, Félix Tshisekedi joue sa réélection',
 'MSF dénonce «\xa0des violences sans fin\xa0» dans les centres de détention de migrants à Tripoli',
 'En Suède, la justice confirme la condamnation à perpétuité de l’ex-procureur iranien Hamid Nouri',
 'Ukraine\xa0: ce que les images disent de la stratégie d’attaque russe des bâtiments civils d’Avdiïvka',
 'Guerre Israël-Hamas\xa0: «\xa0Les références aux lois sont une puissante source de légitimation de la violence à Gaza\xa0»',
 '«\xa0Qatargate\xa0» au Parlement européen\xa0: Gianni Infantino, le président de la FIFA, en eaux troubles',
 'L’Union européenne n’est pas en ligne avec ses objectifs de réduction des émissions de CO2',
 'Les attaques des houthistes en mer Rouge désorganisent le fret maritime mondial',
 'En Iran, une cyberattaque perturbe la\xa0distribution d’essence dans plus de\xa0la\xa0moitié des stations-service du\xa0pays',
 'Contrôles renforcés sur les anciens chefs de l’Armée de libération du Kosovo jugés à La\xa0Haye',
 'Islande\xa0: l’éruption volcanique en images',
 'L’Europe se crispe contre les opérations militaires d’Israël dans la bande de Gaza',
 'Bénédiction des couples homosexuels\xa0: le\xa0pragmatisme audacieux du\xa0pape François',
 'En mer Rouge, les défis de la nouvelle coalition anti-houthistes',
 'Monsanto condamné à 857\xa0millions de dollars d’amende pour avoir exposé une école à des «\xa0polluants éternels\xa0»',
 'Bénédiction des couples de même sexe\xa0: «\xa0Le pape François marche sur une ligne de crête\xa0»',
 'Etats-Unis\xa0: le gouverneur du Texas signe une loi criminalisant l’entrée illégale de migrants',
 'La Corée du Sud, les Etats-Unis et le Japon lancent un système de partage de données pour faire face à la Corée du Nord',
 'Guerre Israël-Hamas\xa0: «\xa0Le gouvernement israélien poursuit résolument son projet nationaliste et annexionniste\xa0»',
 'En Ukraine, les prises de risque extrêmes des pilotes d’hélicoptère',
 'Olaf Scholz et la stratégie gagnante de «\xa0la pause-café\xa0» avec Viktor Orban',
 'En Chine, un séisme fait plus de 131\xa0morts dans le\xa0nord-ouest du\xa0pays',
 'Couples de même sexe\xa0: le pape François change la pratique de l’Eglise catholique, mais pas sa doctrine',
 'Jack Lang prolongé mais pas encore reconduit à la tête de l’Institut du monde arabe',
 'Serbie\xa0: des premiers résultats officiels confirment la victoire du camp présidentiel, l’opposition manifeste',
 'A Dnipro, pendant la fête de Hanoukka, le rapprochement des identités juive et ukrainienne',
 'Jean Pisani-Ferry, économiste\xa0: «\xa0L’accord franco-allemand sur le pacte de stabilité est une occasion manquée\xa0»',
 'Transport maritime en mer Rouge\xa0: les Etats-Unis annoncent une coalition contre les attaques des houthistes',
 'En Egypte, le président Al-Sissi réélu sans surprise',
 '«\xa0Je me suis dit qu’on ne s’en sortirait pas\xa0»\xa0: dans le nord-est de la Thaïlande, d’anciens otages du Hamas témoignent',
 'Au Moyen-Orient, le risque de l’instabilité s’accroît dangereusement',
 'Le Royaume-Uni annonce une taxe carbone aux frontières, dans la foulée de\xa0l’Union européenne',
 'En Israël, la double peine des habitants du kibboutz Kfar Aza',
 'Taïwan\xa0: la Chine promet des représailles après une vente d’armes américaines']

# %% [markdown]
# En HTML les données sont souvent de très mauvaise qualité. Il faut
# définir des méthodes permettant de les nettoyer pour être intégrées dans
# des bases de données.
#
# Par exemple, pour supprimer tous les espaces superflus :

# %%
def clean_spaces(string_):
    if string_ is not None: 
        return " ".join(string_.split())

# %% [markdown]
# Pour l'appliquer à tous les titres récupérés, on peut faire une list
# comprehension :

# %%
In [11]: [clean_spaces(article) for article in response.css(".river")[0].css(".teaser h3::text").extract()]  

Out[11]: ['Des dizaines de milliers de Géorgiens contestent dans la rue l’élection de Salomé Zourabichvili',
          'A Budapest en Hongrie, un îlot décroissant pour favoriser la transition', 
          'En Israël, la police recommande l’inculpation de Nétanyahou dans une troisième enquête',
          'Donald Trump veut « mettre fin » à l’Aléna rapidement', 
          'Le cauchemar de la « rééducation » des musulmans en Chine',
          '',
          '« AMLO » lance sa transformation du Mexique', 
          '« Paris brûle » : les médias étrangers relatent le « chaos » en marge des défilés des « gilets jaunes »',
          'Andrés Manuel Lopez Obrador intronisé président du Mexique'
         ]

# %%
2023-12-20 14:01:21 [asyncio] DEBUG: Using proactor: IocpProactor
In [8]: def clean_spaces(string_):
   ...:     if string_ is not None:
   ...:         return " ".join(string_.split())
   ...:
   ...: [clean_spaces(article) for article in response.css(".river")[0].css(".teaser h3::text").extract()]
   ...:
Out[8]:
['Pologne : le nouveau gouvernement licencie les dirigeants des médias d’Etat',
 'Quel héritage pour Paris 2024 ? Des lendemains de fête difficiles après Athènes 2004',
 'En direct, guerre Israël-Hamas : le point sur la situation à la mi-journée',
 'En direct, guerre en Ukraine : les dernières informations',
 'DGSE : Nicolas Lerner va remplacer Bernard Emié à la tête du renseignement extérieur',
 'Quel héritage pour Paris 2024 ? La reconversion exemplaire du parc olympique de Londres 2012',
 'A court d’argent, Deutsche Bahn met en vente sa filiale logistique DB Schenker',
 'Quel héritage pour Paris 2024 ? Les métamorphoses de Barcelone lors des JO de 1992',
 'Guerre Israël-Hamas : à Gaza, le ciblage meurtrier des hôpitaux',
 'Des ONG appellent la Banque centrale européenne à favoriser les investissements verts',
 'Loi sur l’immigration : une rupture politique et morale',
 '« Avec l’élection de Javier Milei en Argentine, le futur disparaît de la politique »',
 'Mexique : les disparus de Lagos de Moreno',
 '« La Révolution Garo » : l’art de la contestation par le manga',
 'Aux origines de la « Terre sainte », ou la lente construction d’une Palestine « mythifiée »',
 'Donald Trump, écarté de la primaire du Colorado pour son rôle dans l’insurrection du 6 janvier, remet son avenir présidentiel entre les mains de la Cour suprême',
 'La Vieille Ville de Jérusalem sous cloche',
 'Emin Özmen, le photographe qui documente les soubresauts de la Turquie',
 '« Influent et disrupteur, le Sud global défend ses intérêts, mais n’offre pas de modèle alternatif à l’ordre occidental »',
 'Hongkong atteint le taux de fécondité le plus bas du monde',
 'Pacte de stabilité : l’Union européenne proche d’un accord sur la réforme de ses règles budgétaires',
 'Présidentielle américaine 2024 : Donald Trump déclaré inéligible dans le Colorado en raison de son rôle dans l’attaque du Capitole',
 'Decathlon a continué à approvisionner la Russie via une société-écran',
 'Guerre Israël-Hamas : le chef du Hamas se rend en Egypte mercredi pour discuter d’un cessez-le-feu',
 'L’hommage d’Etienne Balibar à Toni Negri : « Il aura été un lecteur et continuateur de Karl Marx, dans une étonnante combinaison de littéralité et de liberté »',
 'Grand remue-ménage dans les rangs des diplomates chargés de la politique africaine de la France',
 'En République démocratique du Congo, Félix Tshisekedi joue sa réélection',
 'MSF dénonce « des violences sans fin » dans les centres de détention de migrants à Tripoli',
 'En Suède, la justice confirme la condamnation à perpétuité de l’ex-procureur iranien Hamid Nouri',
 'Ukraine : ce que les images disent de la stratégie d’attaque russe des bâtiments civils d’Avdiïvka',
 'Guerre Israël-Hamas : « Les références aux lois sont une puissante source de légitimation de la violence à Gaza »',
 '« Qatargate » au Parlement européen : Gianni Infantino, le président de la FIFA, en eaux troubles',
 'L’Union européenne n’est pas en ligne avec ses objectifs de réduction des émissions de CO2',
 'Les attaques des houthistes en mer Rouge désorganisent le fret maritime mondial',
 'En Iran, une cyberattaque perturbe la distribution d’essence dans plus de la moitié des stations-service du pays',
 'Contrôles renforcés sur les anciens chefs de l’Armée de libération du Kosovo jugés à La Haye',
 'Islande : l’éruption volcanique en images',
 'L’Europe se crispe contre les opérations militaires d’Israël dans la bande de Gaza',
 'Bénédiction des couples homosexuels : le pragmatisme audacieux du pape François',
 'En mer Rouge, les défis de la nouvelle coalition anti-houthistes',
 'Monsanto condamné à 857 millions de dollars d’amende pour avoir exposé une école à des « polluants éternels »',
 'Bénédiction des couples de même sexe : « Le pape François marche sur une ligne de crête »',
 'Etats-Unis : le gouverneur du Texas signe une loi criminalisant l’entrée illégale de migrants',
 'La Corée du Sud, les Etats-Unis et le Japon lancent un système de partage de données pour faire face à la Corée du Nord',
 'Guerre Israël-Hamas : « Le gouvernement israélien poursuit résolument son projet nationaliste et annexionniste »',
 'En Ukraine, les prises de risque extrêmes des pilotes d’hélicoptère',
 'Olaf Scholz et la stratégie gagnante de « la pause-café » avec Viktor Orban',
 'En Chine, un séisme fait plus de 131 morts dans le nord-ouest du pays',
 'Couples de même sexe : le pape François change la pratique de l’Eglise catholique, mais pas sa doctrine',
 'Jack Lang prolongé mais pas encore reconduit à la tête de l’Institut du monde arabe',
 'Serbie : des premiers résultats officiels confirment la victoire du camp présidentiel, l’opposition manifeste',
 'A Dnipro, pendant la fête de Hanoukka, le rapprochement des identités juive et ukrainienne',
 'Jean Pisani-Ferry, économiste : « L’accord franco-allemand sur le pacte de stabilité est une occasion manquée »',
 'Transport maritime en mer Rouge : les Etats-Unis annoncent une coalition contre les attaques des houthistes',
 'En Egypte, le président Al-Sissi réélu sans surprise',
 '« Je me suis dit qu’on ne s’en sortirait pas » : dans le nord-est de la Thaïlande, d’anciens otages du Hamas témoignent',
 'Au Moyen-Orient, le risque de l’instabilité s’accroît dangereusement',
 'Le Royaume-Uni annonce une taxe carbone aux frontières, dans la foulée de l’Union européenne',
 'En Israël, la double peine des habitants du kibboutz Kfar Aza',
 'Taïwan : la Chine promet des représailles après une vente d’armes américaines']

# %% [markdown]
# La méthode précédente est intéressante si l'on ne recherche qu'une seule
# information par article.
#
# Par contre si l'on veut récupérer d'autres caractéristiques comme
# l'image ou la description par exemple, il est plus intéressant et plus
# efficace de récupérer l'objet et d'effectuer plusieurs traitements sur
# ce dernier.
#
# Chaque objet retourné par les requêtes `css` est un selecteur avec
# lequel on peut interagir.
#
# Par exemple pour récupérer le titre et le prix

# %%
In [25]: for article in response.css(".fleuve")[0].css("article"):
...:     title = clean_spaces(article.css("h3 a::text").extract_first())
...:     image = article.css("img::attr(data-src)").extract_first()
...:     description = article.css(".txt3::text").extract_first()
...:     print(f"Title {title} \nImage {image}\nDescription {description}\n ----")

# %%
Title Des dizaines de milliers de Géorgiens contestent dans la rue l’élection de Salomé Zourabichvili
Image https://s1.lemde.fr/image/2018/12/02/147x97/5391641_7_5874_les-partisans-de-l-opposant-grigol-vashadze_20d2e8693a49b83fd3c5578f7799ae9c.jpg
Description Elue présidente (un rôle essentiellement symbolique en Géorgie), l’ex-diplomate française, candidate du pouvoir, est contestée par l’opposition.
----
Title A Budapest en Hongrie, un îlot décroissant pour favoriser la transition
Image https://img.lemde.fr/2018/12/01/10/0/4214/2809/147/97/60/0/15b32ca_1EY4qISQ_BP4kPAh1fozJdXZ.jpg
Description Le centre logistique Cargonomia sert de matrice aux coopératives de l’économie durable et solidaire hongroise.
----
Title En Israël, la police recommande l’inculpation de Nétanyahou dans une troisième enquête
Image https://img.lemde.fr/2018/12/02/167/0/4207/2804/147/97/60/0/9e02c9b_3580d043ebc94b48b0f2cfef4e9a21e7-3580d043ebc94b48b0f2cfef4e9a21e7-0.jpg
Description Le premier ministre est soupçonné de corruption, fraude et abus de pouvoir, dans une affaire impliquant le groupe de télécoms israélien Bezeq.
----
Title Donald Trump veut « mettre fin » à l’Aléna rapidement
Image https://img.lemde.fr/2018/11/30/0/0/4861/3240/147/97/60/0/8b87184_5826023-01-06.jpg
Description Le président américain souhaite voir disparaître l’accord de libre-échange remontant à 1994 avec le Mexique et le Canada, qu’il qualifie régulièrement de « pire accord jamais signé », en faveur du nouveau traité négocié difficilement avec ses voisins nord-américains ces derniers mois.
----
Title Le cauchemar de la « rééducation » des musulmans en Chine
Image https://img.lemde.fr/2018/11/15/151/0/5000/3333/147/97/60/0/118c78f_248b226e6b91450aa8a68bd0ea5525a8-248b226e6b91450aa8a68bd0ea5525a8-0.jpg
Description Ouïgours et Kazakhs du Xinjiang... C’est toute une population musulmane que Pékin veut « rééduquer » en internant des centaines de milliers d’entre eux dans des camps.
----
Title « AMLO » lance sa transformation du Mexique
Image https://img.lemde.fr/2018/12/02/45/0/1497/998/147/97/60/0/a33c174_GGGTBR84_MEXICO-POLITICS-_1202_11.JPG
Description Education et santé gratuites, hausse du salaire minimum, bourses scolaires : à peine investi, le président Andres Manuel Lopez Obrador a listé les mesures qu’il entend prendre pour redresser le pays.
----
Title « Paris brûle » : les médias étrangers relatent le « chaos » en marge des défilés des « gilets jaunes »
Image https://img.lemde.fr/2018/12/02/361/0/598/396/147/97/60/0/ba46a6e_XVIt1Ffwm50iYBheccVieUQQ.jpg
Description Les images de destructions, d’échauffourées ou de voitures enflammées s’affichaient samedi soir en « une » de nombreux sites d’actualité internationaux.
----
Title Andrés Manuel Lopez Obrador intronisé président du Mexique
Image https://img.lemde.fr/2018/12/02/91/145/1346/897/147/97/60/0/877cd51_a4618baa8da2414bb62bab28a6d4c745-a4618baa8da2414bb62bab28a6d4c745-0.jpg
Description Le nouveau chef d’Etat a promis de lutter contre la corruption en menant une transformation « profonde et radicale » du pays.
----

# %%
2023-12-20 14:02:40 [asyncio] DEBUG: Using proactor: IocpProactor
    ...: if fleuve_articles:
    ...:     for article in fleuve_articles.css("article"):
    ...:         title = clean_spaces(article.css("h3 a::text").extract_first())
    ...:         image = article.css("img::attr(data-src)").extract_first()
    ...:         description = article.css(".txt3::text").extract_first()
    ...:         print(f"Title {title} \nImage {image}\nDescription {description}\n ----")
    ...: else:
    ...:     print("No elements found with class '.fleuve'")
    ...:
No elements found with class '.fleuve'

# %% [markdown]
# ## Persistence des données
#
# Pour pouvoir stocker les informations que l'on récupère en parcourant un
# site il faut pouvoir les stocker. On utilise soit de simples
# dictionnaires Python, ou mieux des `scrapy.Item` qui sont des
# dictionnaires améliorés.
#
# Nous allons voir les deux façons de faire. On peut réécrire la méthode
# `parse_category()` pour lui faire retourner un dictionnaire
# correspondant à chaque offre rencontrée.

# %%
def parse_category(self, response):
    for article in response.css(".fleuve")[0].css("article"):
        title = self.clean_spaces(article.css("h3 a::text").extract_first())
        image = article.css("img::attr(data-src)").extract_first()
        description = article.css(".txt3::text").extract_first()
        yield {
            "title":title,
            "image":image,
            "description":description
        }

# %% [markdown]
# Si on combine tout dans la spider :

# %%
# %load newscrawler/newscrawler/spiders/lemonde_v3.py
import scrapy
from scrapy import Request


class LemondeSpider(scrapy.Spider):
    name = "lemondev3"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name:response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        for link in all_links.values():
            yield Request(link, callback=self.parse_category)
            
    def parse_category(self, response):
        for article in response.css(".river")[0].css(".teaser"):
            title = self.clean_spaces(article.css("h3::text").extract_first())
            image = article.css("img::attr(data-src)").extract_first()
            description = article.css(".txt3::text").extract_first()
            yield {
                "title":title,
                "image":image,
                "description":description
            }

    def clean_spaces(self, string):
        if string:
            return " ".join(string.split())

# %% [markdown]
# On peut maintenant lancer notre spider avec la commande suivante :

# %%
scrapy crawl <NAME> # lemondev3

# %% [markdown]
# `scrapy crawl` permet de démarrer le processus en allant chercher la
# classe `scrapy.Spider` dont l'attribut `name` = &lt;NAME&gt;.
#
# Par exemple, pour la spider `LeMondeSpider` :

# %%
# !cd newscrawler && scrapy crawl lemondev3
# Out:
# 2023-12-20 14:09:42 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-12-20 14:09:42 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
# 2023-12-20 14:09:42 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-20 14:09:42 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-20 14:09:42 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-20 14:09:42 [scrapy.extensions.telnet] INFO: Telnet Password: a16652674225b556
# 2023-12-20 14:09:42 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-20 14:09:42 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-12-20 14:09:42 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-20 14:09:42 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-20 14:09:42 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-20 14:09:42 [scrapy.core.engine] INFO: Spider opened
# 2023-12-20 14:09:42 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-20 14:09:42 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-20 14:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-20 14:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2023-12-20 14:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/politique/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/attaque-du-hamas-contre-israel/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/actualite-en-continu/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/cop28/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/inflation/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/international/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/crise-ukrainienne/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/jeux-olympiques-2024/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/antisemitisme/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': '« Il y a urgence à préciser que les crèches municipales et associatives, à but non lucratif, sont bien la priorité du gouvernement »', 'image': 'https://img.lemde.fr/2023/12/20/0/0/5760/3840/110/73/60/0/bf5675a_1703066172074-pns-6738132.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Le projet de loi « immigration » a bien été adopté avec les voix du Rassemblement national', 'image': 'https://img.lemde.fr/2023/12/20/0/0/1920/1280/110/73/60/0/72b6905_1703067235861-imagedappel.png', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/projet-de-loi-immigration/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'DGSE : Nicolas Lerner va remplacer Bernard Emié à la tête du renseignement extérieur', 'image': 'https://img.lemde.fr/2023/12/20/0/0/7612/5074/110/73/60/0/5447d01_1703070160363-000-33jj9tn.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'En direct, loi « immigration » : le texte transmis au Conseil constitutionnel dès ce soir ; Agnès Firmin Le Bodo assurera l’intérim au ministère de la santé', 'image': 'https://img.lemde.fr/2023/12/20/1/0/2500/1666/110/73/60/0/50bfc28_1703073003542-unnamed-7.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Loi « immigration » : « une déflagration », le récit d’une soirée de vote houleuse à l’Assemblée nationale', 'image': 'https://img.lemde.fr/2023/12/20/3/0/5900/3933/110/73/60/0/7c35b45_1703036965767-jmug231219061.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Loi sur l’immigration : une rupture politique et morale', 'image': 'https://img.lemde.fr/2023/12/20/3/0/5900/3933/110/73/60/0/cdab139_1703036979178-jmug231219071.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Adoption de la loi « immigration » : le résumé de la soirée en images', 'image': 'https://img.lemde.fr/2023/12/20/3/0/5900/3933/110/73/60/0/3b6bb18_1703036968532-jmug231219063.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Dominique Rousseau : « Avant la disparition complète l’Etat de droit sous les coups de l’extrême droite, un juriste doit parler pour défendre celui-ci »', 'image': 'https://img.lemde.fr/2023/03/17/3/0/8192/5461/110/73/60/0/e9bcb87_5768080-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Projet de loi « immigration » : tout ce qui a changé entre le projet initial, la version du Sénat et de l’Assemblée et celle de la CMP', 'image': 'https://img.lemde.fr/2023/12/19/0/0/5902/3934/110/73/60/0/2d90fa1_2023-12-19t152543z-514990329-rc2e05aj783d-rtrmadp-3-france-migration.JPG', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Politique de la recherche : « La pyramide est “la” forme par laquelle toute connaissance se structure, se transmet et progresse »', 'image': 'https://img.lemde.fr/2023/04/27/0/0/4253/2835/110/73/60/0/a40be1e_1682585330590-2d85c17-1680106845701-le-monde-tribune-def-01.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': '« C’est une honte absolue » : les réactions en images après l’accord de la CMP sur la loi « immigration »', 'image': 'https://img.lemde.fr/2023/12/19/1/0/8192/5461/110/73/60/0/82370b1_5156893-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Projet de loi « immigration » : les APL aux étrangers, la nouvelle ligne rouge de la droite', 'image': 'https://img.lemde.fr/2023/12/19/42/0/4723/3148/110/73/60/0/5d79e33_1702976009650-280984.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': '« La crise politique autour du projet de loi “immigration” est un moment de vérité où toutes les fragilités du mandat d’Emmanuel Macron se conjuguent »', 'image': 'https://img.lemde.fr/2023/12/13/0/0/4770/3180/110/73/60/0/ca2eee9_5108692-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Projet de loi « immigration » : le camp Macron flirte avec l’idéologie de la « préférence nationale » sur les aides sociales aux étrangers', 'image': 'https://img.lemde.fr/2023/12/18/3/0/5900/3933/110/73/60/0/ddbf58b_1702915280110-jmug231211031.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'La création de RER métropolitains définitivement entérinée au Parlement', 'image': 'https://img.lemde.fr/2019/12/09/0/0/3000/2000/110/73/60/0/27d0ab7_b8092e69323c495a916922605409a518-b8092e69323c495a916922605409a518-0.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Titres-restaurant : le Parlement confirme l’extension à tous les produits alimentaires jusqu’à la fin de 2024', 'image': 'https://img.lemde.fr/2023/11/14/0/36/4903/3269/110/73/60/0/0bc74da_1699983620685-000-par7847718.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Le budget 2024 adopté en nouvelle lecture à l’Assemblée nationale', 'image': 'https://img.lemde.fr/2023/12/16/0/0/4275/2850/110/73/60/0/4913753_5135893-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Le Parlement français adopte une loi sur la restitution de restes humains à des Etats étrangers', 'image': 'https://img.lemde.fr/2023/12/18/41/0/2152/1434/110/73/60/0/7197657_1702931742612-000-app2002042992837.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Jack Lang prolongé mais pas encore reconduit à la tête de l’Institut du monde arabe', 'image': 'https://img.lemde.fr/2023/12/18/1/0/7591/5060/110/73/60/0/f92e393_1702923571976-000-32h63f8.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Immigration : « Plutôt que de creuser le sillon de la division, faisons confiance aux citoyens »', 'image': 'https://img.lemde.fr/2023/12/13/3/0/5900/3933/110/73/60/0/41cdd18_1702427966995-jmug231212068.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Des départements font face à une baisse des recettes et sont en difficulté pour boucler leur budget 2024', 'image': 'https://img.lemde.fr/2023/12/17/0/4/4920/3280/110/73/60/0/8563ead_1702827811917-maxnewsworldfive556649.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Eric Dupond-Moretti veut montrer un nouveau visage après sa relaxe devant la Cour de justice de la République', 'image': 'https://img.lemde.fr/2023/12/17/3/0/5900/3933/110/73/60/0/dd470a7_1702835062950-jmug231212082.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Le député écologiste Benjamin Lucas défend la motion de rejet : « Le processus de durcissement du texte immigration était engagé »', 'image': 'https://img.lemde.fr/2023/12/16/1637/0/3939/2626/110/73/60/0/0587c65_1702722288088-jmug231211007.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Sur son projet de loi immigration, le gouvernement oppose le Parlement aux Français', 'image': 'https://img.lemde.fr/2023/12/20/3/0/5900/3933/110/73/60/0/c71bd15_1703036975446-jmug231219069.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'A l’Assemblée, la majorité face au risque de rupture sur le texte immigration', 'image': 'https://img.lemde.fr/2023/12/18/3/0/5900/3933/110/73/60/0/fb9c2ef_1702888803954-jmug231212085.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'La mort du philosophe Antonio Negri, figure intellectuelle des gauches altermondialistes', 'image': 'https://img.lemde.fr/2023/12/16/28/0/2631/1754/110/73/60/0/d0b92c6_1702726069536-gettyimages-639522350.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Projet de loi « immigration » : Emmanuel Macron entre la menace d’une droitisation et le risque de paralysie', 'image': 'https://img.lemde.fr/2023/12/17/0/0/8160/5440/110/73/60/0/f28ce64_1702834888475-060379.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Gérald Darmanin, un ministre affaibli par la crise politique autour du projet de loi sur l’immigration', 'image': 'https://img.lemde.fr/2023/12/17/0/0/5749/3832/110/73/60/0/b6899f1_1702831704957-paloma-laudet-40.JPG', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Projet de loi « immigration » : la présidente de l’Assemblée nationale, Yaël Braun-Pivet, « confiante » sur un accord avant la CMP', 'image': 'https://img.lemde.fr/2023/12/11/0/0/7693/5129/110/73/60/0/f1945b2_5092842-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Projet de loi « immigration » : tout savoir sur les enjeux et le rapport des forces au sein de la CMP', 'image': 'https://img.lemde.fr/2023/12/12/3/0/5900/3933/110/73/60/0/82a734a_1702419350910-jmug231212028.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Laurent Fabius dans « Questions politiques » : « On a un vrai malaise démocratique, de la base et du sommet »', 'image': 'https://img.lemde.fr/2023/10/04/0/0/6240/4160/110/73/60/0/e26564d_1696433805361-cbi1148024.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Paris 2024 : la guerre des trois a déjà lieu', 'image': 'https://img.lemde.fr/2023/12/14/0/0/3600/2400/110/73/60/0/405b6e9_1702558074614-000-sh0rr.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': '« L’immigration n’est pas seulement une question de police »', 'image': 'https://img.lemde.fr/2023/12/11/3/0/5900/3933/110/73/60/0/a6311c5_1702338431328-jmug231211051.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Elisabeth Borne déclenche un nouveau 49.3, pour faire adopter le projet de budget en nouvelle lecture', 'image': 'https://img.lemde.fr/2023/12/12/3/0/5900/3933/110/73/60/0/1eec3f2_1702419382254-jmug231212046.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Les pistes d’Olivier Dussopt pour le plein-emploi', 'image': 'https://img.lemde.fr/2023/12/16/3/0/5900/3933/110/73/60/0/128cba3_1702713934846-jmug231212061.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Voiture électrique : une démocratisation difficile', 'image': 'https://img.lemde.fr/2023/12/16/0/0/5610/3740/110/73/60/0/202c3d8_1702713755698-000-33v28wr.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Immigration : « Après la motion de rejet de l’Assemblée nationale, ce projet de loi est-il nécessaire ? »', 'image': 'https://img.lemde.fr/2023/12/12/0/0/6884/4589/110/73/60/0/b7cd11c_5100262-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Conflit entre Israël et le Hamas : comment La France insoumise se distingue du reste de la gauche', 'image': 'https://img.lemde.fr/2023/12/15/114/291/4568/3045/110/73/60/0/ac88924_1702656123980-000-347y49u.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Elections européennes 2024 : l’extrême droite gagne du terrain', 'image': 'https://img.lemde.fr/2023/12/15/0/0/5875/3916/110/73/60/0/1bf19cf_1702653584365-cbi1155048.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Elections européennes : le conflit israélo-palestinien n’affecte pas la dynamique électorale du RN', 'image': 'https://img.lemde.fr/2023/12/15/0/0/4350/2900/110/73/60/0/93779f3_1702657157160-cbi1155020.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Bruno Le Maire sort du rang, face à une première ministre fragilisée', 'image': 'https://img.lemde.fr/2023/12/16/824/1066/6887/4591/110/73/60/0/25e23f2_1702685223276-080-hl-xbouzas-2230277.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Serge Klarsfeld, le chasseur de nazis qui n’a plus peur du RN', 'image': 'https://img.lemde.fr/2023/12/11/219/15/1107/738/110/73/60/0/bf36800_316488-3350666.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Sur la fin de vie, la grande hésitation d’Emmanuel Macron', 'image': 'https://img.lemde.fr/2023/12/15/0/0/7807/5205/110/73/60/0/e6d2d6f_1702657490975-000-3482632.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'En Martinique, l’invitation par un béké du président béninois Patrice Talon crée la polémique', 'image': 'https://img.lemde.fr/2023/12/15/1/0/8192/5461/110/73/60/0/3d5c59f_1702657334665-000-32fk34p.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Améliorer le référendum pour le rendre enfin « démocratiquement correct »', 'image': 'https://img.lemde.fr/2023/12/14/500/0/2674/1782/110/73/60/0/960348f_1702558257972-referendum.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': '« En Irlande, associer une convention citoyenne au référendum contribue à une décision éclairée »', 'image': 'https://img.lemde.fr/2023/12/14/22/0/525/350/110/73/60/0/3f0d5be_1702568848709-pour-appui.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'A LFI, l’instauration d’une démocratie interne considérée comme « une bataille perdue »', 'image': 'https://img.lemde.fr/2023/12/05/3/0/5900/3933/110/73/60/0/a7c4b61_1701818308043-jmug231205022.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/podcasts/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Projet de loi immigration : Emmanuel Macron appelle à un « compromis intelligent »', 'image': 'https://img.lemde.fr/2023/12/15/0/0/7807/5205/110/73/60/0/e6d2d6f_1702657490975-000-3482632.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': '« Féminicide politique » : le dérapage de Renaud Muselier enflamme le conseil municipal de Marseille', 'image': 'https://img.lemde.fr/2023/12/15/0/0/5368/3579/110/73/60/0/c56d50b_1702653337485-000-344k9lz.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': '« Dans la pensée présidentielle, il n’est pas envisagé d’évaluer les résultats des réformes de la recherche scientifique qui ont précédé »', 'image': 'https://img.lemde.fr/2023/04/27/0/0/4253/2835/110/73/60/0/a40be1e_1682585330590-2d85c17-1680106845701-le-monde-tribune-def-01.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'La Nouvelle-Calédonie aux prises avec de violents incendies', 'image': 'https://img.lemde.fr/2023/12/15/58/0/1400/933/110/73/60/0/4faefdb_1702628996789-nouvelle-caledonie-brule.jpeg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Eric Ciotti épinglé par la chambre régionale des comptes pour les cumuls d’emplois de son entourage', 'image': 'https://img.lemde.fr/2023/12/14/0/0/4945/3296/110/73/60/0/fc41063_1702583617470-000-33xw2rh.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Retraite complémentaire : que change la fin du bonus-malus ?', 'image': 'https://img.lemde.fr/2023/12/14/113/0/2732/1821/110/73/60/0/39618d5_1702566291871-image0.jpeg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Projet de loi sur l’immigration : les délicates tractations d’Elisabeth Borne pour sauver le texte', 'image': 'https://img.lemde.fr/2023/12/12/3/0/5900/3933/110/73/60/0/15a4073_1702419348982-jmug231212027.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Frédéric Michel, conseiller communication d’Emmanuel Macron, quitte l’Elysée', 'image': 'https://img.lemde.fr/2023/11/18/0/0/6180/4120/110/73/60/0/57de77c_1700297552622-000-337l4ee.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Le Conseil constitutionnel fait planer une incertitude autour du recours à l’article 49.3', 'image': 'https://img.lemde.fr/2023/04/06/493/598/4445/2963/110/73/60/0/753406b_1680775694866-pns-3741789.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Le projet de loi pour le plein-emploi validé pour l’essentiel par le Conseil constitutionnel, après le recours de la gauche', 'image': 'https://img.lemde.fr/2020/06/05/0/0/5472/3648/110/73/60/0/268fb9e_2NEuvuWm9xNI3dL2DKJVjKgT.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Elisabeth Borne déclenche un nouveau 49.3 pour faire adopter la partie recettes du budget de l’Etat', 'image': 'https://img.lemde.fr/2023/12/12/11/0/4229/2819/110/73/60/0/a71274e_5100239-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Le régime de garantie des salaires se dote d’un nouveau directeur après une crise interne', 'image': 'https://img.lemde.fr/2023/12/14/0/213/2797/1865/110/73/60/0/2328099_1702565920411-000-1oj40b.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/politique/>
#
# {'title': 'Conseil présidentiel de la science : « La multiplication de ce type d’instances affaiblit les structures traditionnelles du régime »', 'image': 'https://img.lemde.fr/2023/12/07/0/0/7224/4816/110/73/60/0/c8c05e7_2023-12-07t122311z-1589337989-rc2cs4aofduh-rtrmadp-3-france-politics.JPG', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sciences/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/disparitions/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/pixels/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-fil-good/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/intimites/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'En direct, guerre Israël-Hamas : le point sur la situation à la mi-journée', 'image': 'https://img.lemde.fr/2023/12/20/0/0/1599/1066/110/73/60/0/33e2ab0_1703061946011-305814.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : à Gaza, le ciblage meurtrier des hôpitaux', 'image': 'https://img.lemde.fr/2023/12/20/0/315/3402/2268/110/73/60/0/f3cbb0f_1703058847958-068-aa-16122023-1456433.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Transférer les chefs militaires du Hamas vers Alger : un plan saoudien soumis au Quai d’Orsay', 'image': 'https://img.lemde.fr/2023/12/20/0/0/5533/3689/110/73/60/0/78dd273_1703060566385-000-344z79a.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Aux origines de la « Terre sainte », ou la lente construction d’une Palestine « mythifiée »', 'image': 'https://img.lemde.fr/2023/12/13/0/0/3189/2126/110/73/60/0/2e1ad32_1702486649109-142.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'La Vieille Ville de Jérusalem sous cloche', 'image': 'https://img.lemde.fr/2023/11/29/0/0/6000/4000/110/73/60/0/3952543_1701264861223-asurp-israel-vieilleville-100465.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': '« Influent et disrupteur, le Sud global défend ses intérêts, mais n’offre pas de modèle alternatif à l’ordre occidental »', 'image': 'https://img.lemde.fr/2023/12/06/0/0/4200/2800/110/73/60/0/5a66851_2023-12-06t142950z-1965996668-rc2mr4a6e43h-rtrmadp-3-emirates-russia.JPG', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : le chef du Hamas se rend en Egypte mercredi pour discuter d’un cessez-le-feu', 'image': 'https://img.lemde.fr/2023/12/19/0/0/6000/4000/110/73/60/0/49476cc_5156296-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : « Les références aux lois sont une puissante source de légitimation de la violence à Gaza »', 'image': 'https://img.lemde.fr/2023/10/18/0/0/5479/3653/110/73/60/0/3d19bf9_5615985-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Les attaques des houthistes en mer Rouge désorganisent le fret maritime mondial', 'image': 'https://img.lemde.fr/2023/12/19/0/100/1080/720/110/73/60/0/305dbdb_1702979136079-301755.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'L’Europe se crispe contre les opérations militaires d’Israël dans la bande de Gaza', 'image': 'https://img.lemde.fr/2023/12/19/1/0/8192/5461/110/73/60/0/c45ac30_1702972797571-045219.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'En mer Rouge, les défis de la nouvelle coalition anti-houthistes', 'image': 'https://img.lemde.fr/2023/12/19/0/100/1080/720/110/73/60/0/c2463fc_1702979097018-302356.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : « Le gouvernement israélien poursuit résolument son projet nationaliste et annexionniste »', 'image': 'https://img.lemde.fr/2023/12/10/0/0/4723/3149/110/73/60/0/242c6d6_1702242100934-vdsc2260-a-12-23.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Dnipro, pendant la fête de Hanoukka, le rapprochement des identités juive et ukrainienne', 'image': 'https://img.lemde.fr/2023/12/17/455/0/6830/4553/110/73/60/0/1dd9fb4_1702835119341-raf-001.JPG', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': '« Je me suis dit qu’on ne s’en sortirait pas » : dans le nord-est de la Thaïlande, d’anciens otages du Hamas témoignent', 'image': 'https://img.lemde.fr/2023/12/17/1/0/8192/5461/110/73/60/0/2929dff_1702833531919-am2023-lemonde-th-9.JPG', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Au Moyen-Orient, le risque de l’instabilité s’accroît dangereusement', 'image': 'https://img.lemde.fr/2023/12/18/0/0/5472/3648/110/73/60/0/c48b2f9_1702884357486-060857.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'En Israël, la double peine des habitants du kibboutz Kfar Aza', 'image': 'https://img.lemde.fr/2023/12/18/0/0/6000/4000/110/73/60/0/a8e2c37_1702886251103-asurp-isr-pal-lm-100921.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Israël-Palestine : que veut vraiment le Hamas ?', 'image': 'https://img.lemde.fr/2023/12/15/0/0/5439/3626/110/73/60/0/c7ca6a9_5124923-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'La France en attente d’explications après la mort d’un agent du Quai d’Orsay dans un bombardement israélien à Rafah', 'image': 'https://img.lemde.fr/2023/12/18/0/4/7032/4688/110/73/60/0/cb05b0c_1702883849391-066965.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'En images : en visite en Israël, Catherine Colonna appelle à une « une nouvelle trêve immédiate et durable »', 'image': 'https://img.lemde.fr/2023/12/17/0/0/8256/5504/110/73/60/0/5241b59_5140000-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Détruire le Hamas ou détruire Gaza', 'image': 'https://img.lemde.fr/2023/12/14/1/0/8192/5461/110/73/60/0/85b670f_1702558116633-056501.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'En Cisjordanie, des prisonniers palestiniens libérés reconnaissants mais pas inféodés au Hamas', 'image': 'https://img.lemde.fr/2023/12/13/1495/0/4724/3149/110/73/60/0/2c48a46_1702432939221-vdsc2971-a-12-23.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Comment la guerre Israël-Hamas a déchiré Harvard', 'image': 'https://img.lemde.fr/2023/12/16/0/0/5206/3470/110/73/60/0/8156533_1702713614255-021625.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Un agent du Quai d’Orsay tué dans un bombardement israélien à Rafah, dans la bande de Gaza', 'image': 'https://img.lemde.fr/2023/12/13/0/0/5751/3834/110/73/60/0/a795780_5107936-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'En images : les familles d’otages capturés par le Hamas manifestent à Tel-Aviv', 'image': 'https://img.lemde.fr/2023/12/16/0/0/6000/4000/110/73/60/0/6b7607c_1702712341186-asurp-isr-pal-lm-102625.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': '« Pallywood » : en plein carnage à Gaza, le mythe des fausses morts palestiniennes', 'image': 'https://img.lemde.fr/2023/12/14/0/66/954/636/110/73/60/0/ca4b2fc_1702545282423-screenshot-2023-12-14t101427-568.png', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Les arrêtés à répétition du préfet des Alpes-Maritimes contre les manifestations propalestiniennes', 'image': 'https://img.lemde.fr/2023/12/15/0/7/8260/5507/110/73/60/0/5f02f4b_1702651959163-000-346d4n9.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Gaza, la mort de trois otages du Hamas tués par erreur par l’armée israélienne ravive la crainte des familles', 'image': 'https://img.lemde.fr/2023/12/16/0/0/6000/4000/110/73/60/0/538d3ee_1702698791599-asurp-isr-pal-lm-102666.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Carmela, Sigal, Valentin… Les destins brisés des Français tués dans l’attaque du Hamas le 7 octobre', 'image': 'https://img.lemde.fr/2023/12/15/0/0/1200/800/110/73/60/0/265dfdf_1702631662789-d05f8d39-98b6-4bee-bef5-022734a0af9f-1.JPG', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Conflit entre Israël et le Hamas : comment La France insoumise se distingue du reste de la gauche', 'image': 'https://img.lemde.fr/2023/12/15/114/291/4568/3045/110/73/60/0/ac88924_1702656123980-000-347y49u.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'L’armée israélienne reconnaît avoir tué par accident trois otages lors d’une opération dans la bande de Gaza', 'image': 'https://img.lemde.fr/2023/12/16/0/0/6000/4000/110/73/60/0/538d3ee_1702698791599-asurp-isr-pal-lm-102666.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Une fiction douce-amère de l’écrivain israélien Etgar Keret sur le 7 octobre : « Le jour de la Joie de la Torah, quelque chose se brisa dans le cœur de Yihiel-Nahman »', 'image': 'https://img.lemde.fr/2014/10/08/876/0/3840/2554/110/73/60/0/c6b70fe_4225-2wqjiz.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : la diplomatie française au Liban pour éviter l’escalade', 'image': 'https://img.lemde.fr/2023/12/15/0/0/3417/2278/110/73/60/0/e70a320_5126044-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : le débat européen sur le cessez-le-feu tourne court', 'image': 'https://img.lemde.fr/2023/12/15/1/0/8192/5461/110/73/60/0/05ef96e_1702654576834-043000.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : comment l’économie de toute la région est affectée par le conflit', 'image': 'https://img.lemde.fr/2023/12/13/1/0/8192/5461/110/73/60/0/e87cb59_1702487114935-lbn-hamas-saida-diegoibarrasanchez-007.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Dans le cabinet de guerre israélien, le jeu d’équilibre du général Gadi Eisenkot', 'image': 'https://img.lemde.fr/2023/12/14/0/0/8640/5760/110/73/60/0/6795d66_1702571671775-958441.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Hamas-Israël : « En appeler à la mémoire de la Shoah, c’est donner un faux tableau, dangereux, des causes de la violence »', 'image': 'https://img.lemde.fr/2023/12/11/0/0/4311/2874/110/73/60/0/cff4c0d_5093538-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Le char Merkava, pivot des opérations urbaines de l’armée israélienne', 'image': 'https://img.lemde.fr/2023/12/07/0/0/1599/1066/110/73/60/0/d652db3_1701936497096-267701.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'La guerre Israël-Hamas donne l’occasion à l’Egypte de retrouver une influence diplomatique', 'image': 'https://img.lemde.fr/2023/12/14/0/0/6000/4000/110/73/60/0/07b90f6_1702560221576-047080.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Le trafic maritime en mer Rouge sous la pression des houthistes yéménites', 'image': 'https://img.lemde.fr/2023/12/14/0/100/1080/720/110/73/60/0/379e5fb_1702575718779-264791.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : l’otage franco-israélien Elya Toledano a été retrouvé mort par l’armée israélienne dans la bande de Gaza', 'image': 'https://img.lemde.fr/2023/12/15/170/0/1080/720/110/73/60/0/cb21e1e_1702617848537-screenshot-20231215-062249-x.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'En Israël, ces juifs ultraorthodoxes qui s’enrôlent dans l’armée pour défendre leur pays', 'image': 'https://img.lemde.fr/2023/11/22/81/0/4693/3128/110/73/60/0/0571165_1700627058330-15112023-l3150978.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Israël-Hamas : la guerre « durera plus que quelques mois », prévient le ministre de la défense israélien', 'image': 'https://img.lemde.fr/2023/12/11/0/0/3000/2000/110/73/60/0/48d3027_2b08863ff52d4c1daab406fb077142fc-0-81944e328747438a830d6c118c73897b.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas, Hollywood tourne à la désunion', 'image': 'https://img.lemde.fr/2023/12/13/0/0/1500/1000/110/73/60/0/b8fc72c_316482-3351190.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Entre Biden et Nétanyahou, une alliance de plus en plus inconfortable', 'image': 'https://img.lemde.fr/2023/12/14/0/0/4279/2852/110/73/60/0/5b07d0a_1702543661944-000-33yl3cy.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': '« La France doit demander à Israël de permettre aux journalistes palestiniens travaillant pour les médias français de pouvoir quitter Gaza et y revenir »', 'image': 'https://img.lemde.fr/2023/12/11/0/0/5374/3582/110/73/60/0/aae5e7d_5092070-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Paris, consultations minimales sur le financement du Hamas', 'image': 'https://img.lemde.fr/2023/12/14/1/0/8192/5461/110/73/60/0/bf799b9_1702542386027-045174.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : l’économie de la Cisjordanie au bord de l’asphyxie', 'image': 'https://img.lemde.fr/2023/12/13/0/0/6000/4000/110/73/60/0/72c6ae3_1702484038529-asurp-israel-cisjordanie-economie-104959.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'L’utilisation de l’intelligence artificielle par l’armée israélienne questionne le droit de la guerre', 'image': 'https://img.lemde.fr/2023/12/12/0/0/5545/3697/110/73/60/0/99ef3f4_5102003-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Les derniers vers du poète de Gaza', 'image': 'https://img.lemde.fr/2023/12/13/0/0/1500/1000/110/73/60/0/b4189b4_316531-3351675.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Rafah, déplacement inattendu d’une délégation de diplomates de l’ONU', 'image': 'https://img.lemde.fr/2023/12/13/0/0/5442/3628/110/73/60/0/ffc4a58_1702454476063-047087.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Gaza, une guerre des images', 'image': 'https://img.lemde.fr/2023/12/12/0/88/2784/1856/110/73/60/0/15f0fc5_1702372141033-271599.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Hadas Kalderon, mère de deux enfants libérés par le Hamas : « La nuit, les angoisses remontent »', 'image': 'https://img.lemde.fr/2023/12/11/380/0/5707/3804/110/73/60/0/64c1f86_1702316194344-ll-kalderon-22.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Comment la guerre entre Israël et le Hamas menace la paix des cercles familiaux et amicaux', 'image': 'https://img.lemde.fr/2023/12/06/0/0/1897/1264/110/73/60/0/21636bb_1701874676661-epoque.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sante/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/education/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/actualite-en-continu/>
#
# {'title': 'Loi « immigration » : « une déflagration », le récit d’une soirée de vote houleuse à l’Assemblée nationale', 'image': 'https://img.lemde.fr/2023/12/20/3/0/5900/3933/110/73/60/0/7c35b45_1703036965767-jmug231219061.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/actualite-en-continu/>
#
# {'title': 'Pologne : le nouveau gouvernement licencie les dirigeants des médias d’Etat', 'image': 'https://img.lemde.fr/2023/12/14/0/0/5500/3666/110/73/60/0/d532beb_2023-12-14t171744z-393612351-rc28w4ax58h9-rtrmadp-3-poland-politics-media.JPG', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/actualite-en-continu/>
#
# {'title': 'En direct, loi « immigration » : le texte transmis au Conseil constitutionnel dès ce soir ; Agnès Firmin Le Bodo assurera l’intérim au ministère de la santé', 'image': 'https://img.lemde.fr/2023/12/20/1/0/2500/1666/110/73/60/0/50bfc28_1703073003542-unnamed-7.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/actualite-en-continu/>
#
# {'title': 'En direct, guerre Israël-Hamas : le point sur la situation à la mi-journée', 'image': 'https://img.lemde.fr/2023/12/20/0/0/1599/1066/110/73/60/0/33e2ab0_1703061946011-305814.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/actualite-en-continu/>
#
# {'title': 'En direct, guerre en Ukraine : comment le pays va-t-il passer l’hiver ? Posez vos questions à notre journaliste', 'image': 'https://img.lemde.fr/2023/12/20/0/13/4300/2867/110/73/60/0/2cfc71d_2023-12-20t092233z-1989745807-rc2w05a7d51c-rtrmadp-3-christmas-season-ukraine.JPG', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/actualite-en-continu/>
#
# ...
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Projet de loi « immigration » : les APL aux étrangers, la nouvelle ligne rouge de la droite', 'image': 'https://img.lemde.fr/2023/12/19/42/0/4723/3148/110/73/60/0/5d79e33_1702976009650-280984.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Bénédiction des couples de même sexe : « Le pape François marche sur une ligne de crête »', 'image': 'https://img.lemde.fr/2023/12/19/13/0/2280/1520/110/73/60/0/0a64a01_1702972412196-979216.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': '« La crise politique autour du projet de loi “immigration” est un moment de vérité où toutes les fragilités du mandat d’Emmanuel Macron se conjuguent »', 'image': 'https://img.lemde.fr/2023/12/13/0/0/4770/3180/110/73/60/0/ca2eee9_5108692-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Etats-Unis : le gouverneur du Texas signe une loi criminalisant l’entrée illégale de migrants', 'image': 'https://img.lemde.fr/2023/12/19/0/0/1620/1080/110/73/60/0/ea7c353_9c28f586c06c41a5b275370e6f33b856-0-2c9e700c319542a3b4320e4483ad1c4a.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Marvel exclut l’acteur Jonathan Majors, reconnu coupable d’agression sur son ex-compagne', 'image': 'https://img.lemde.fr/2023/12/18/1/0/4773/3182/110/73/60/0/4b02f74_5152508-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Alain Supiot, juriste : « Les familles doivent être soutenues et non entravées dans l’accomplissement de leurs tâches essentielles »', 'image': 'https://img.lemde.fr/2023/12/11/0/0/7327/4885/110/73/60/0/0578e12_5093990-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Complémentaires santé : les fortes hausses de tarifs se confirment', 'image': 'https://img.lemde.fr/2023/06/20/0/0/6720/4480/110/73/60/0/537ad13_1687250696977-pns-6298943.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Mathématiques : les dessous de la « méthode de Singapour » que Gabriel Attal veut généraliser à l’école primaire', 'image': 'https://img.lemde.fr/2023/12/18/3/0/5900/3933/110/73/60/0/3d5fce2_1702913325502-jmug231212012.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Pour protéger son cœur, manger à la bonne heure', 'image': 'https://img.lemde.fr/2023/12/18/0/0/5314/3543/110/73/60/0/a07d66e_1702918956816-gettyimages-496655509.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Violences envers les soignants : une campagne de communication pour « changer les comportements »', 'image': 'https://img.lemde.fr/2023/12/18/0/0/5625/3750/110/73/60/0/0c89c7d_1702919981975-sipa-01114420-000022.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': '« Les Entreprises et l’égalité femmes-hommes » : pourquoi les écarts de salaires ne baissent plus', 'image': 'https://img.lemde.fr/2023/12/18/263/0/612/408/110/73/60/0/24e3ec5_1702891065544-27246100935260l.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Pierre Merle, spécialiste des questions scolaires : « Loin de créer un “choc des savoirs”, Gabriel Attal va produire un choc d’ignorance »', 'image': 'https://img.lemde.fr/2023/11/27/57/0/7268/4845/110/73/60/0/afda881_1701097189279-000-33rb7jh.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Projet de loi « immigration » : le camp Macron flirte avec l’idéologie de la « préférence nationale » sur les aides sociales aux étrangers', 'image': 'https://img.lemde.fr/2023/12/18/3/0/5900/3933/110/73/60/0/ddbf58b_1702915280110-jmug231211031.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Projet de loi « immigration » : du Palais-Bourbon à Matignon, en passant par l’Elysée, une journée de tractations inédite autour d’un introuvable accord', 'image': 'https://img.lemde.fr/2023/12/18/0/0/8256/5504/110/73/60/0/72b692f_5150219-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': '« Les sciences sociales proposent des outils pour comprendre le monde dans sa complexité et œuvrer au progrès social »', 'image': 'https://img.lemde.fr/2023/12/15/1/0/7915/5276/110/73/60/0/0bce0ff_1702655936750-000-34789ul.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': '« L’acharnement mis à fermer des classes préparatoires interpelle »', 'image': 'https://img.lemde.fr/2023/12/18/0/360/3084/2056/110/73/60/0/6e3116b_1702904192538-000-par2013459.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Au procès de l’assassinat de Narumi Kurosaki, l’inatteignable Nicolas Zepeda', 'image': 'https://img.lemde.fr/2023/12/19/0/2/4719/3146/110/73/60/0/5dfb411_1702953748442-maxbestof281936.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Couples de même sexe : le pape François change la pratique de l’Eglise catholique, mais pas sa doctrine', 'image': 'https://img.lemde.fr/2023/12/18/0/0/5976/3984/110/73/60/0/e6e7d74_1702922466400-982348.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'A Sciences Po, la direction veut redonner confiance et rassurer les donateurs après le retrait de Mathias Vicherat', 'image': 'https://img.lemde.fr/2023/12/18/0/0/5341/3561/110/73/60/0/d15f4fc_1702913134455-028179.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Immigration : « Plutôt que de creuser le sillon de la division, faisons confiance aux citoyens »', 'image': 'https://img.lemde.fr/2023/12/13/3/0/5900/3933/110/73/60/0/41cdd18_1702427966995-jmug231212068.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Culture financière : où en sont les Français ?', 'image': 'https://img.lemde.fr/2023/04/18/0/0/3000/2000/110/73/60/0/402e09c_1681830091356-hjyjrt.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Le Vatican autorise la bénédiction hors liturgie des couples de même sexe', 'image': 'https://img.lemde.fr/2023/12/17/2/0/2337/1558/110/73/60/0/99097f2_2023-12-17t111654z-656040140-rc2yy4a91l30-rtrmadp-3-pope-angelus.JPG', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Eric Dupond-Moretti veut montrer un nouveau visage après sa relaxe devant la Cour de justice de la République', 'image': 'https://img.lemde.fr/2023/12/17/3/0/5900/3933/110/73/60/0/dd470a7_1702835062950-jmug231212082.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Le député écologiste Benjamin Lucas défend la motion de rejet : « Le processus de durcissement du texte immigration était engagé »', 'image': 'https://img.lemde.fr/2023/12/16/1637/0/3939/2626/110/73/60/0/0587c65_1702722288088-jmug231211007.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Sur son projet de loi immigration, le gouvernement oppose le Parlement aux Français', 'image': 'https://img.lemde.fr/2023/12/20/3/0/5900/3933/110/73/60/0/c71bd15_1703036975446-jmug231219069.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Procès de Monique Olivier : la perpétuité requise pour complicité dans trois crimes contre l’ex-épouse de Michel Fourniret', 'image': 'https://img.lemde.fr/2023/12/16/148/0/6066/4044/110/73/60/0/c17c8f4_5132867-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
#
# {'title': 'Covoiturage : la prime de 100 euros sera reconduite en 2024, mais réservée aux trajets courts', 'image': 'https://img.lemde.fr/2015/06/14/30/0/3520/2343/110/73/60/0/26896eb_17075-cle4dp.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
#
# {'title': 'La Colombie, premier grand pays à rejoindre la coalition de non-prolifération des énergies fossiles', 'image': 'https://img.lemde.fr/2023/12/13/0/0/6325/4217/110/73/60/0/48d42ac_1702457361675-943160.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
#
# {'title': 'COP28 : après l’accord de Dubaï, les réponses de nos journalistes à vos questions', 'image': 'https://img.lemde.fr/2023/12/13/0/0/7816/5211/110/73/60/0/e2ac6fb_1702456764338-969479.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
#
# {'title': 'COP28 : une issue décevante sur la question cruciale de l’adaptation au changement climatique', 'image': 'https://img.lemde.fr/2023/12/13/155/0/5500/3666/110/73/60/0/73f6027_1702456325621-285787.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
#
# {'title': 'Niger : première commercialisation de pétrole brut en janvier', 'image': 'https://img.lemde.fr/2023/12/12/275/394/3075/2050/110/73/60/0/bb191f1_1702372151794-000-32l82pm.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
#
# {'title': 'En Côte d’Ivoire, l’ancien banquier Tidjane Thiam en route pour prendre la tête de l’ancien parti unique', 'image': 'https://img.lemde.fr/2023/12/11/0/0/3999/2666/110/73/60/0/439e2d8_1702311818926-000-347e43j.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
#
# {'title': 'Comment les services de renseignement russes ont repris en main les opérations de Wagner en Afrique', 'image': 'https://img.lemde.fr/2023/12/11/0/0/6602/4401/110/73/60/0/d99f40c_1702302152013-000-323g3vk-1.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
#
# {'title': 'Lupita Nyong’o, première présidente noire du jury du festival du film de Berlin', 'image': 'https://img.lemde.fr/2023/12/11/0/0/2316/1544/110/73/60/0/e7cedd4_1702311226815-000-347p2f8.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
#
# {'title': 'CAN 2024 : le calendrier, les classements et les résultats des matchs', 'image': 'https://img.lemde.fr/2023/12/08/0/0/3631/2421/110/73/60/0/0a0537d_5066919-01-06.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
#
# {'title': 'Après la Guinée équatoriale, le président de la Biélorussie en visite au Kenya', 'image': 'https://img.lemde.fr/2023/12/11/0/0/4269/2846/110/73/60/0/d5108bf_1702304153135-000-347e7r6.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
#
# {'title': 'En manque de perspective, la jeunesse égyptienne se détourne de la politique', 'image': 'https://img.lemde.fr/2023/12/11/0/0/5943/3962/110/73/60/0/84454f4_1702302580864-028698.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
#
# {'title': 'Elections en RDC : à Goma, Félix Tshisekedi promet qu’« il ne manque plus grand-chose pour vaincre » les rebelles du M23', 'image': 'https://img.lemde.fr/2023/12/10/0/28/4944/3296/110/73/60/0/e06096a_2023-12-10t192743z-1214426023-rc2gu4ahgpe0-rtrmadp-3-congo-election.JPG', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Damien Carême, ancien maire de Grande-Synthe : « Le pacte migratoire européen en voie d’adoption est une réforme de la honte »', 'image': None, 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Projet de loi « immigration » : les tractations se poursuivent avant la commission mixte paritaire', 'image': 'https://img.lemde.fr/2023/12/13/3/0/5900/3933/110/73/60/0/6c30687_1702483938618-jmug231212063.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'A l’Assemblée, la majorité face au risque de rupture sur le texte immigration', 'image': 'https://img.lemde.fr/2023/12/18/3/0/5900/3933/110/73/60/0/fb9c2ef_1702888803954-jmug231212085.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': '« L’horizon fuyant de la santé au travail »', 'image': 'https://img.lemde.fr/2023/11/02/0/37/2245/1497/110/73/60/0/21ff923_1698934786161-couv-1-4-quesait-ondutravail.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/societe/>
#
# {'title': 'Quand des cadeaux de Noël permettent de déshériter un enfant', 'image': 'https://img.lemde.fr/2023/04/17/0/0/3000/2000/110/73/60/0/9b5f2ef_1681721636273-poiuyt.jpg', 'description': None}
# 2023-12-20 14:09:43 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-20 14:09:43 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 7458,
#  'downloader/request_count': 29,
#  'downloader/request_method_count/GET': 29,
#  'downloader/response_bytes': 2404119,
#  'downloader/response_count': 29,
#  'downloader/response_status_count/200': 29,
#  'elapsed_time_seconds': 0.988829,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 20, 13, 9, 43, 669019, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 9612281,
#  'httpcompression/response_count': 29,
#  'item_scraped_count': 1440,
#  'log_count/DEBUG': 1470,
#  'log_count/ERROR': 3,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'request_depth_max': 1,
#  'response_received_count': 29,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 28,
#  'scheduler/dequeued/memory': 28,
#  'scheduler/enqueued': 28,
#  'scheduler/enqueued/memory': 28,
#  'spider_exceptions/IndexError': 3,
#  'start_time': datetime.datetime(2023, 12, 20, 13, 9, 42, 680190, tzinfo=datetime.timezone.utc)}
# 2023-12-20 14:09:43 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On peut exporter les résultats de ces retours dans différents formats de
# fichiers.
#
# -   CSV : `scrapy crawl lemonde -o lbc.csv`
# -   JSON : `scrapy crawl lemonde -o lbc.json`
# -   JSONLINE : `scrapy crawl lemonde -o lbc.jl`
# -   XML : `scrapy crawl lemonde -o lbc.xml`
#
# ### Exercice :
#
# Exécuter la spider avec les différents formats de stockage.
# Explorer ensuite le contenu des fichiers ainsi créés.

# %%
# CSV
# !cd newscrawler && scrapy crawl lemonde -o output.csv

# JSON
# !cd newscrawler && scrapy crawl lemonde -o output.json

# JSON Lines
# !cd newscrawler && scrapy crawl lemonde -o output.jl

# XML
# !cd newscrawler && scrapy crawl lemonde -o output.xml
# Out:
# 2023-12-20 14:10:11 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-12-20 14:10:11 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
# 2023-12-20 14:10:11 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-20 14:10:11 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-20 14:10:11 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-20 14:10:11 [scrapy.extensions.telnet] INFO: Telnet Password: 77a3f85c33666024
# 2023-12-20 14:10:11 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-20 14:10:11 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-12-20 14:10:12 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-20 14:10:12 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-20 14:10:12 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-20 14:10:12 [scrapy.core.engine] INFO: Spider opened
# 2023-12-20 14:10:12 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-20 14:10:12 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-20 14:10:12 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.lemonde.fr/robots.txt> from <GET http://lemonde.fr/robots.txt>
# 2023-12-20 14:10:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-20 14:10:12 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.lemonde.fr/> from <GET http://lemonde.fr/>
# 2023-12-20 14:10:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-20 14:10:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/> (referer: None)
# 2023-12-20 14:10:12 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-20 14:10:12 [scrapy.extensions.feedexport] INFO: Stored csv feed (0 items) in: output.csv
# 2023-12-20 14:10:12 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1097,
#  'downloader/request_count': 5,
#  'downloader/request_method_count/GET': 5,
#  'downloader/response_bytes': 84090,
#  'downloader/response_count': 5,
#  'downloader/response_status_count/200': 3,
#  'downloader/response_status_count/301': 2,
#  'elapsed_time_seconds': 0.322798,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 20, 13, 10, 12, 377764, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 305440,
#  'httpcompression/response_count': 3,
#  'log_count/DEBUG': 6,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'response_received_count': 3,
#  'robotstxt/request_count': 2,
#  'robotstxt/response_count': 2,
#  'robotstxt/response_status_count/200': 2,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2023, 12, 20, 13, 10, 12, 54966, tzinfo=datetime.timezone.utc)}
# 2023-12-20 14:10:12 [scrapy.core.engine] INFO: Spider closed (finished)
# 2023-12-20 14:10:13 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-12-20 14:10:13 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
# 2023-12-20 14:10:13 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-20 14:10:13 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-20 14:10:13 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-20 14:10:13 [scrapy.extensions.telnet] INFO: Telnet Password: 8797ebbdbe2b5384
# 2023-12-20 14:10:14 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-20 14:10:14 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-12-20 14:10:14 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-20 14:10:14 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-20 14:10:14 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-20 14:10:14 [scrapy.core.engine] INFO: Spider opened
# 2023-12-20 14:10:14 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-20 14:10:14 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-20 14:10:14 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.lemonde.fr/robots.txt> from <GET http://lemonde.fr/robots.txt>
# 2023-12-20 14:10:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-20 14:10:14 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.lemonde.fr/> from <GET http://lemonde.fr/>
# 2023-12-20 14:10:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-20 14:10:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/> (referer: None)
# 2023-12-20 14:10:14 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-20 14:10:14 [scrapy.extensions.feedexport] INFO: Stored json feed (0 items) in: output.json
# 2023-12-20 14:10:14 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1097,
#  'downloader/request_count': 5,
#  'downloader/request_method_count/GET': 5,
#  'downloader/response_bytes': 84090,
#  'downloader/response_count': 5,
#  'downloader/response_status_count/200': 3,
#  'downloader/response_status_count/301': 2,
#  'elapsed_time_seconds': 0.259622,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 20, 13, 10, 14, 413117, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 305440,
#  'httpcompression/response_count': 3,
#  'log_count/DEBUG': 6,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'response_received_count': 3,
#  'robotstxt/request_count': 2,
#  'robotstxt/response_count': 2,
#  'robotstxt/response_status_count/200': 2,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2023, 12, 20, 13, 10, 14, 153495, tzinfo=datetime.timezone.utc)}
# 2023-12-20 14:10:14 [scrapy.core.engine] INFO: Spider closed (finished)
# 2023-12-20 14:10:16 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-12-20 14:10:16 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
# 2023-12-20 14:10:16 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-20 14:10:16 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-20 14:10:16 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-20 14:10:16 [scrapy.extensions.telnet] INFO: Telnet Password: 75242e6e7484cb40
# 2023-12-20 14:10:16 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-20 14:10:16 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-12-20 14:10:16 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-20 14:10:16 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-20 14:10:16 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-20 14:10:16 [scrapy.core.engine] INFO: Spider opened
# 2023-12-20 14:10:16 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-20 14:10:16 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-20 14:10:16 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.lemonde.fr/robots.txt> from <GET http://lemonde.fr/robots.txt>
# 2023-12-20 14:10:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-20 14:10:16 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.lemonde.fr/> from <GET http://lemonde.fr/>
# 2023-12-20 14:10:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-20 14:10:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/> (referer: None)
# 2023-12-20 14:10:16 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-20 14:10:16 [scrapy.extensions.feedexport] INFO: Stored jl feed (0 items) in: output.jl
# 2023-12-20 14:10:16 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1097,
#  'downloader/request_count': 5,
#  'downloader/request_method_count/GET': 5,
#  'downloader/response_bytes': 84090,
#  'downloader/response_count': 5,
#  'downloader/response_status_count/200': 3,
#  'downloader/response_status_count/301': 2,
#  'elapsed_time_seconds': 0.259638,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 20, 13, 10, 16, 516602, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 305440,
#  'httpcompression/response_count': 3,
#  'log_count/DEBUG': 6,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'response_received_count': 3,
#  'robotstxt/request_count': 2,
#  'robotstxt/response_count': 2,
#  'robotstxt/response_status_count/200': 2,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2023, 12, 20, 13, 10, 16, 256964, tzinfo=datetime.timezone.utc)}
# 2023-12-20 14:10:16 [scrapy.core.engine] INFO: Spider closed (finished)
# 2023-12-20 14:10:18 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-12-20 14:10:18 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
# 2023-12-20 14:10:18 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-20 14:10:18 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-20 14:10:18 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-20 14:10:18 [scrapy.extensions.telnet] INFO: Telnet Password: 1492389b4ba31a34
# 2023-12-20 14:10:18 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-20 14:10:18 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-12-20 14:10:18 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-20 14:10:18 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-20 14:10:18 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-20 14:10:18 [scrapy.core.engine] INFO: Spider opened
# 2023-12-20 14:10:18 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-20 14:10:18 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-20 14:10:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.lemonde.fr/robots.txt> from <GET http://lemonde.fr/robots.txt>
# 2023-12-20 14:10:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-20 14:10:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.lemonde.fr/> from <GET http://lemonde.fr/>
# 2023-12-20 14:10:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-20 14:10:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/> (referer: None)
# 2023-12-20 14:10:18 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-20 14:10:18 [scrapy.extensions.feedexport] INFO: Stored xml feed (0 items) in: output.xml
# 2023-12-20 14:10:18 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1097,
#  'downloader/request_count': 5,
#  'downloader/request_method_count/GET': 5,
#  'downloader/response_bytes': 84090,
#  'downloader/response_count': 5,
#  'downloader/response_status_count/200': 3,
#  'downloader/response_status_count/301': 2,
#  'elapsed_time_seconds': 0.239041,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 20, 13, 10, 18, 557810, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 305440,
#  'httpcompression/response_count': 3,
#  'log_count/DEBUG': 6,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'response_received_count': 3,
#  'robotstxt/request_count': 2,
#  'robotstxt/response_count': 2,
#  'robotstxt/response_status_count/200': 2,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2023, 12, 20, 13, 10, 18, 318769, tzinfo=datetime.timezone.utc)}
# 2023-12-20 14:10:18 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Votre premier Item
#
# La classe `Item` permet de structurer les données que l'on souhaite
# récupérer sous la forme d'un modèle. Les items doivent être définis dans
# le fichier `items.py` créé par la commande `scrapy startproject`. Les
# `Item` héritent de la class `scrapy.Item`.
#
# On veut structurer les données avec deux champs : le titre et le prix de
# l'annonce. Scrapy utilise une classe `scrapy.Field` permettant de
# 'déclarer' ces champs. Dans notre cas :

# %%
# %load newscrawler/newscrawler/items.py

# Define here the models for your scraped items
#
# See documentation in:
# https://docs.scrapy.org/en/latest/topics/items.html

import scrapy

class ArticleItem(scrapy.Item):
    title = scrapy.Field()
    image = scrapy.Field()
    description = scrapy.Field()

# %% [markdown]
# Utiliser la classe `scrapy.Item` plutôt qu'un simple dictionnaire permet
# plus de contrôle sur la structure des données. En effet, on ne peut
# insérer dans les items que des données avec des clés 'déclarées'. Ce qui
# assure une plus grande cohérence au sein d'un projet.
#
# On peut instancier un item de plusieurs façons :

# %%
article_item = ArticleItem(title="Gilets Jaunes", image=None, description="Un samedi de manifestations")

# %%
print(article_item)
# Out:
# {'description': 'Un samedi de manifestations',
#  'image': None,
#  'title': 'Gilets Jaunes'}

# %%
article_item = ArticleItem()
article_item["title"] = 'Gilets Jaunes'
article_item["description"] = 'Un samedi de manifestations'

# %%
print(article_item)
# Out:
# {'description': 'Un samedi de manifestations', 'title': 'Gilets Jaunes'}

# %% [markdown]
# La définition d'un item permet de palier toutes les erreurs de typo dans
# les champs.

# %%
article_item = ArticleItem()
article_item["titelkjwnxvmnscbvmknxc"] = 'Gilets Jaunes'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
#       1 article_item = ArticleItem()
# ----> 2 article_item["titelkjwnxvmnscbvmknxc"] = 'Gilets Jaunes'
#
# File ~\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\item.py:85, in Item.__setitem__(self, key, value)
#      83     self._values[key] = value
#      84 else:
# ---> 85     raise KeyError(f"{self.__class__.__name__} does not support field: {key}")
#
# KeyError: 'ArticleItem does not support field: titelkjwnxvmnscbvmknxc'

# %% [markdown]
# Les items héritent des dictionnaires Python, et possèdent donc toutes
# les méthodes de ceux-ci:

# %%
article_item = ArticleItem(title="Gilets Jaunes")
print(article_item["title"]) # Méthode __getitem__()
print(article_item.get("description", "no description provided")) # Méthode get()
# Out:
# Gilets Jaunes
# no description provided

# %% [markdown]
# On peut transformer un `Item` en dictionnaire très facilement, en le
# passant au constructeur:

# %%
article_item = ArticleItem(title="Drone DJI")
print(type(article_item))
dict_item = dict(article_item)
print(type(dict_item))
print(dict_item)
# Out:
# <class '__main__.ArticleItem'>
# <class 'dict'>
# {'title': 'Drone DJI'}

# %% [markdown]
# On intègre maintenant cet item dans notre spider.

# %%
# -*- coding: utf-8 -*-
import scrapy
from scrapy import Request
from ..items import ArticleItem
class LemondeSpider(scrapy.Spider):
    name = "lemonde"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name:response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        for link in all_links.values():
            yield Request(link, callback=self.parse_category)

    def parse_category(self, response):
        for article in response.css(".fleuve")[0].css("article"):
            title = self.clean_spaces(article.css("h3 a::text").extract_first())
            image = article.css("img::attr(data-src)").extract_first()
            description = article.css(".txt3::text").extract_first()

            yield ArticleItem(
                title=title,
                image=image,
                description=description
            )

    def clean_spaces(self, string):
        if string:
            return " ".join(string.split())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 4
#       2 import scrapy
#       3 from scrapy import Request
# ----> 4 from ..items import ArticleItem
#       5 class LemondeSpider(scrapy.Spider):
#       6     name = "lemonde"
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# On voit bien que le générateur retourne maintenant un `Item`.

# %% [markdown]
# ### Exercice :
#
# Relancer la spider pour vérifier le bon déroulement de l'extraction.

# %%
# !cd newscrawler/ && scrapy crawl lemondev4
# Out:
# 2023-12-20 14:13:50 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-12-20 14:13:50 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22631-SP0
# 2023-12-20 14:13:50 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-20 14:13:50 [py.warnings] WARNING: C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-12-20 14:13:50 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-12-20 14:13:50 [scrapy.extensions.telnet] INFO: Telnet Password: c4527c9d2908eecf
# 2023-12-20 14:13:50 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-20 14:13:50 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-12-20 14:13:50 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-20 14:13:50 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-20 14:13:50 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-20 14:13:50 [scrapy.core.engine] INFO: Spider opened
# 2023-12-20 14:13:50 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-20 14:13:50 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-20 14:13:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-12-20 14:13:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2023-12-20 14:13:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\ESIEE\E4\S1\P2\DSIA_4201C_DataEngineerTools\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde_v4.py", line 22, in parse_category
#     for article in response.css(".river")[0].css(".teaser"):
#                    ~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sante/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-fil-good/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/campus/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/pixels/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sciences/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/disparitions/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/intimites/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sport/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2020/11/03/154/0/2400/1599/110/73/60/0/89e42e9_649155279-pns-707015746.jpg',
#  'title': 'Plus de 6 700 lits d’hospitalisation complète fermés en 2022 en '
#           'France'}
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/planete/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/0/0/6000/4000/110/73/60/0/16726ac_1702913862366-000-347t68q.jpg',
#  'title': 'IVG instrumentales : désaccord sur les modalités de l’élargissement '
#           'des compétences des sages-femmes'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/19/0/5/5605/3737/110/73/60/0/b54a946_1703000786243-pns-3546052.jpg',
#  'title': 'IVG : « Jamais la parution d’aucune loi ni d’aucun décret depuis '
#           '1979 n’avait autant inquiété les professionnels que nous sommes »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/04/27/0/0/4253/2835/110/73/60/0/a40be1e_1682585330590-2d85c17-1680106845701-le-monde-tribune-def-01.jpg',
#  'title': '« La PMA est une médecine hasardeuse en l’absence de diagnostic '
#           'préimplantatoire »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/19/1/0/6832/4554/110/73/60/0/047368a_1702973521311-059057.jpg',
#  'title': 'Projet de loi sur la fin de vie : les relations se tendent encore '
#           'plus entre le gouvernement et une partie des soignants'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/01/24/0/0/2400/1600/110/73/60/0/24e8e8d_1674545541094-pns-3853691.jpg',
#  'title': 'La mutuelle, le salaire et les négociations annuelles obligatoires'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/06/20/0/0/6720/4480/110/73/60/0/537ad13_1687250696977-pns-6298943.jpg',
#  'title': 'Complémentaires santé : les fortes hausses de tarifs se confirment'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/0/0/5314/3543/110/73/60/0/a07d66e_1702918956816-gettyimages-496655509.jpg',
#  'title': 'Pour protéger son cœur, manger à la bonne heure'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/0/0/5625/3750/110/73/60/0/0c89c7d_1702919981975-sipa-01114420-000022.jpg',
#  'title': 'Violences envers les soignants : une campagne de communication pour '
#           '« changer les comportements »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/02/0/37/2245/1497/110/73/60/0/21ff923_1698934786161-couv-1-4-quesait-ondutravail.jpg',
#  'title': '« L’horizon fuyant de la santé au travail »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/15/118/63/4603/3069/110/73/60/0/c4c901c_1702653006531-process-encrochat-leo-quievreux.jpg',
#  'title': 'Gros poissons et petites mains de la cocaïne dans un maxi-procès en '
#           'Belgique'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/17/0/0/4896/3264/110/73/60/0/b711a97_1702847961035-000-par6148198.jpg',
#  'title': 'Le parquet de Bordeaux requiert un non-lieu pour l’ancien chef de '
#           'la lutte antistupéfiants'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/11/0/0/5239/3493/110/73/60/0/fc94cee_5092298-01-06.jpg',
#  'title': 'Transport sanitaire : « L’absence de dialogue avec les artisans '
#           'taxis et de mesures d’accompagnement témoigne d’une gestion '
#           'technocratique et centralisée »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/01/1000/0/3001/2000/110/73/60/0/4c9bd3f_1698835819240-7.jpg',
#  'title': 'Pourquoi le don d’ovule et spermatozoïde peut-il être une solution '
#           'pour avoir un enfant ?'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/15/0/0/7807/5205/110/73/60/0/e6d2d6f_1702657490975-000-3482632.jpg',
#  'title': 'Sur la fin de vie, la grande hésitation d’Emmanuel Macron'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/15/0/0/5500/3666/110/73/60/0/cdc7e2a_1702663632370-2022-10-03t000000z-1097002969-rc2ptw9avzga-rtrmadp-3-health-monkeypox-africa.JPG',
#  'title': 'Variole du singe : l’OMS craint que l’épidémie ne se propage dans '
#           'le monde depuis la RDC'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/12/0/1/5482/3655/110/73/60/0/92f6867_1702401123273-000-1wa48p.jpg',
#  'title': 'La sédentarité augmente la peur des chutes et les sensations de '
#           'vertige chez les nonagénaires'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/14/0/0/5304/3536/110/73/60/0/096c03d_1702580010438-000-33xx7nf.jpg',
#  'title': 'Trafic de drogue : les acteurs du « début de la guerre à Pissevin » '
#           'devant le tribunal'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/06/23/0/0/5568/3712/110/73/60/0/396994d_5610970-01-06.jpg',
#  'title': '« Il est urgent de repenser la structuration de la recherche '
#           'biomédicale en France »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/14/3/0/3728/2485/110/73/60/0/62700e2_1702562661886-000-33ny3zp.jpg',
#  'title': 'Fin de vie : le préprojet de loi suscite la « colère » du collectif '
#           'des soignants opposés à l’aide active à mourir'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/13/0/0/6000/4000/110/73/60/0/0982bbd_1702474896294-000-347t68q.jpg',
#  'title': 'Les sages-femmes autorisées à pratiquer l’IVG instrumentale en '
#           'milieu hospitalier'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/09/411/851/4798/3199/110/73/60/0/528dcd4_1702142299671-pns-6740989.jpg',
#  'title': 'La double peine des salariés atteints de maladie chronique'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/13/0/0/4876/3251/110/73/60/0/4d09232_1702477108339-000-93f93y.jpg',
#  'title': 'Dry January : le ministère de la santé botte en touche sur le mois '
#           'sans alcool'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/06/06/610/0/1890/1260/110/73/60/0/115da50_1686048314389-v2.jpg',
#  'title': 'L’« almond mom », cette mère qui complexe ses filles à propos de '
#           'leur poids'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/12/0/0/1279/853/110/73/60/0/3d74b2a_1702342226289-1280px-pap-smear-showing-clamydia-in-the-vacuoles-500x-h-e.jpg',
#  'title': 'Une hausse marquée des IST bactériennes en France entre 2020 et '
#           '2022'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/11/27/0/4989/3326/110/73/60/0/66e6932_1702309071494-000-1cz6f3-1.jpg',
#  'title': 'L’acteur Dylan Robert mis en examen pour assassinat'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/04/17/0/0/3000/2000/110/73/60/0/241aeda_1681718660066-pppppp.jpg',
#  'title': 'Mediator : les victimes ont plus de temps pour demander leur '
#           'indemnisation'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/07/0/0/7678/5118/110/73/60/0/4f18610_5060698-01-06.jpg',
#  'title': 'Le Téléthon 2023 s’achève avec plus de 80 millions d’euros de '
#           'promesses de dons'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2022/06/03/0/0/3543/2362/110/73/60/0/fd6d539_1654262936192-le-monde-campus-v03.jpg',
#  'title': '« Ça me rend fou toutes ces vies qui pourraient être sauvées si '
#           'plus de Français étaient formés aux premiers secours »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/08/0/0/5568/3712/110/73/60/0/53e5794_1702048008127-000-33ch7ph.jpg',
#  'title': 'Fin de vie : « Monsieur le Président, votre avis sur les soins '
#           'palliatifs et l’aide active à mourir ne saurait être l’unique '
#           'boussole »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/08/0/0/1658/1105/110/73/60/0/3be608e_1702079669785-severin-millet-fin-de-vie.jpg',
#  'title': 'Fin de vie : un plan pour les soins palliatifs en attendant une loi '
#           'sur l’aide à mourir'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/01/199/0/3001/2000/110/73/60/0/e4b10b7_1698832440539-6.jpg',
#  'title': 'Comment les embryons deviennent-ils des bébés ?'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/05/0/0/5592/3728/110/73/60/0/ee58b89_2023-12-05t145317z-1041136784-rc22r4apm3wg-rtrmadp-3-france-politics.JPG',
#  'title': 'Le projet de loi sur la fin de vie sera présenté « courant février '
#           '», selon la ministre Agnès Firmin Le Bodo'}
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/societe/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/politique/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/education/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\keren\Documents\ESIEE\E4\S1\P2\DSIA_4201C_DataEngineerTools\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde_v4.py", line 22, in parse_category
#     for article in response.css(".river")[0].css(".teaser"):
#                    ~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\keren\Documents\DSIA4101\DSIA_4101A\DataEngineerTools\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2022/12/04/0/0/7411/4941/110/73/60/0/bc07315_1670125077979-000-8wj6eu.jpg',
#  'title': 'Pour sa 37\u1d49 édition, le Téléthon veut garder une forme olympique'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/0/169/1620/1080/110/73/60/0/9b5089e_1701705135502-narcobusiness-ep3-wip-v9-00-15-10-07-still009.jpg',
#  'title': 'Des montagnes du Sinaloa aux gratte-ciel de Dubaï, l’art de '
#           'blanchir l’argent du fentanyl'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/0/0/5359/3572/110/73/60/0/8c3a644_1701688844802-638-seminstituteimagine-012.jpg',
#  'title': 'Imagine, l’institut en pointe contre les maladies génétiques'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/07/0/0/1800/1200/110/73/60/0/b85f6e5_1701951685924-fentanyl.jpeg',
#  'title': 'Fentanyl, le business lucratif d’une drogue mortelle'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/0/270/2892/1928/110/73/60/0/a8b5932_1701699445093-capture-da-ei-cran-2023-12-04-ai-13-01-59.png',
#  'title': 'Overdose de fentanyl dans les rues de New York'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/06/0/0/6000/4000/110/73/60/0/e8cac59_1701873608026-000-33wp2fc.jpg',
#  'title': 'L’attrait croissant pour l’intérim chez les infirmiers, un '
#           'phénomène qui inquiète les hôpitaux'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/05/0/94/2835/1890/110/73/60/0/c24e896_1701770780546-narco-04.png',
#  'title': 'Comment les labos mexicains « cuisinent » le fentanyl, l’opioïde '
#           'trente fois plus puissant que l’héroïne'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/05/0/56/5178/3452/110/73/60/0/b823ac5_1701796907023-maxnewsworldsix049544.jpg',
#  'title': 'Botulisme à Bordeaux : le patron du Tchin Tchin Wine Bar mis en '
#           'examen'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/12/1/0/8192/5461/110/73/60/0/872152e_c7f1ff24402f439d8631b9f17bce2062-1-cbe0af7306794c13be50d19a2cd60db3.jpg',
#  'title': 'A Mayotte, l’eau interdite à la consommation sur une partie de '
#           'l’archipel en raison de la présence de métaux lourds'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2017/11/19/0/4/4164/2776/110/73/60/0/a7e3bee_913-u2ibi.6e9fs3v7vi.jpg',
#  'title': '« Avec cette nouvelle loi, les Français auront d’immenses '
#           'difficultés à accéder à une alimentation sans OGM »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/05/0/56/5178/3452/110/73/60/0/b823ac5_1701796907023-maxnewsworldsix049544.jpg',
#  'title': 'Botulisme à Bordeaux : le patron du Tchin-Tchin Wine Bar en garde à '
#           'vue'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/0/26/3679/2453/110/73/60/0/8957c7b_1701704179641-000-33va3zu.jpg',
#  'title': 'Quand, en entreprise, les outils « de productivité » comme Slack et '
#           'Teams donnent l’illusion de l’efficacité'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/03/14/0/90/4332/2888/110/73/60/0/a05c39b_1678764628563-000-par8222367.jpg',
#  'title': 'Punaises de lit, cafards… : un insecticide interdit depuis dix ans '
#           'reste utilisé et provoque des intoxications, alerte l’Anses'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/0/6/5788/3859/110/73/60/0/dfa571f_1701690434521-000-1r17cf.jpg',
#  'title': 'Un rapport conforte l’aide médicale d’Etat, tout en préconisant son '
#           'resserrement'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/03/0/0/8640/5760/110/73/60/0/6c276fe_a72b5b3b7ab445e9b555fd9f5bd80c00-0-b827b28a17874270bb90c0180ce8bbe5.jpg',
#  'title': 'Après l’attentat à Paris, le suivi psychiatrique des personnes '
#           'radicalisées rentre dans le débat politique'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/0/0/6000/4000/110/73/60/0/41ca1cd_53bb740973a4487c91bece907fcfc636-0-eb94db98db5b46248f070e937d8f4a01.jpg',
#  'title': 'L’Assemblée nationale vote l’interdiction des puffs'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/03/0/0/6781/4521/110/73/60/0/126be0e_5027717-01-06.jpg',
#  'title': 'Attentat à Paris : des psychiatres s’émeuvent des accusations de « '
#           'ratage » formulées par Gérald Darmanin'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': None,
#  'title': 'Respirateurs : nouveaux risques d’interférence entre des masques et '
#           'des implants médicaux'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/0/0/6570/4380/110/73/60/0/0ed5034_5033825-01-06.jpg',
#  'title': 'Le budget de la Sécurité sociale définitivement adopté par le '
#           'Parlement après le rejet d’une motion de censure'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/04/1/0/6000/4000/110/73/60/0/69ab61e_1701680730102-000-346j9d3.jpg',
#  'title': 'Le narcotrafic, puissant facteur de déstabilisation'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/04/28/0/0/5760/3840/110/73/60/0/8e8b73b_1682699699391-pns-6612625-1.jpg',
#  'title': 'Les cigarettes électroniques jetables, appréciées des ados et très '
#           'polluantes, bientôt interdites en France ?'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/12/0/0/5472/3648/110/73/60/0/f2c43d5_65bcb97c4f1449e4b8bc6e4f842b9217-1-7eebd5a3eeff4b358328500b5ba5c092.jpg',
#  'title': 'A Mayotte, la crise de l’eau se déverse dans les tribunaux'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/30/0/4/2391/1594/110/73/60/0/f41a2ef_1701345946869-pns-704000573.jpg',
#  'title': 'Contre les douleurs sexuelles, les kinés spécialisés à l’écoute des '
#           'femmes : « Avant, j’ai testé l’hypnose, l’acupuncture, '
#           'l’ostéopathie… »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/14/0/0/8256/5504/110/73/60/0/7bbcc51_2023-11-14t034056z-1373459227-rc2wq3azi8y4-rtrmadp-3-bangladesh-disease-dengue.JPG',
#  'title': 'Le Bangladesh fait face à la pire épidémie de dengue jamais '
#           'enregistrée dans le pays'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/31/785/0/3004/2002/110/73/60/0/c8d026f_1698745330039-5.jpg',
#  'title': 'Comment les embryons sont-ils créés en laboratoire ?'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/0/0/1500/1000/110/73/60/0/7484424_314857-3349040.jpg',
#  'title': 'A Saint-Denis, les médecins de l’hôpital Delafontaine craignent de '
#           'perdre leur AME'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/01/0/0/6376/4250/110/73/60/0/ddba20c_1701441242298-000-32wf9nc.jpg',
#  'title': 'Kebabs, burgers, tacos : ce que l’explosion des fast-foods dit de '
#           'la France'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/10/0/0/3366/2244/110/73/60/0/f542360_1699629567411-ile-fandouillec-jup113033.jpg',
#  'title': 'La ria d’Etel, le Morbihan envoûtant'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/90/0/7543/5028/110/73/60/0/070ac02_1702900965429-ecolessirenes-clr.jpg',
#  'title': 'Sur Parcoursup, le risque de se perdre dans le maquis des diplômes'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/20/0/0/3000/2000/110/73/60/0/d5a4f17_1703071525837-illu-jyros.jpg',
#  'title': 'Dans le jeu vidéo, un calculateur d’empreinte carbone bientôt '
#           'obligatoire pour obtenir des aides du CNC'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/0/0/1600/1066/110/73/60/0/3c1faef_1702891930075-5777078-jpg-r-1920-1080-f-jpg-q-x-xxyxx.jpg',
#  'title': 'Un certain goût cinématographique pour l’univers culinaire'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/0/535/4050/2700/110/73/60/0/961bfe0_1702891537538-still-4.jpg',
#  'title': '« Menus-Plaisirs. Les Troisgros » : le festin étoilé de Frederick '
#           'Wiseman'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/06/47/0/1500/1000/110/73/60/0/f77311b_1701860742570-hello-actors-studio-robert-de-niro-03.jpg',
#  'title': 'DVD : « Hello Actors Studio », retour sur une épopée intellectuelle '
#           'et collective'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/68/0/1346/897/110/73/60/0/265308a_1702892349913-photo-2-pour-ton-mariage-o-iliade-et-films-eagles-team-entertainment-m141.jpg',
#  'title': '« Pour ton mariage » : Oury Milshtein rembobine les fils de sa vie'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/13/3/0/2780/1853/110/73/60/0/58a842f_1702474909735-chungking-express-thejokers-films.jpg',
#  'title': 'Trois films des années fastes de Wong Kar-wai ressortent au cinéma '
#           'dans des versions restaurées'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/0/0/6000/4000/110/73/60/0/aef023a_1702892928932-dsc05107.jpg',
#  'title': '« La Fille de son père », d’Erwan Le Duc : plongée à toute allure '
#           'dans un marathon de tendresse'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/19/0/0/4999/3333/110/73/60/0/a77d918_2023-12-19t134416z-68920733-rc2b05a47p9b-rtrmadp-3-christmas-season-thailand.JPG',
#  'title': 'Climat, biodiversité : la liste de Noël de « Chaleur humaine »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/05/813/0/2520/1680/110/73/60/0/754caf8_1701768744599-81a1519-copie.jpg',
#  'title': 'En Champagne, trois vignerons savourent leur autonomie : « Cela '
#           'nous permet une liberté immense »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/19/0/0/5791/3861/110/73/60/0/f762ba1_1702990553662-fred-sancere-kristof-guez-16-juin-2020.jpg',
#  'title': 'Fred Sancère, pilote inspiré d’un lieu nomade et volatil'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/13/0/0/8256/5504/110/73/60/0/4d6e21e_1702483972355-cnrs-20230079-0003-hd.jpg',
#  'title': 'Sandra Lavorel, médaille d’or du CNRS et écologue tout-terrain'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/19/0/250/1500/1000/110/73/60/0/e6873ef_1703002858093-05-jeunesse2023.jpg',
#  'title': 'Les seize albums jeunesse préférés des critiques du « Monde » en '
#           '2023'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/19/0/0/1800/1200/110/73/60/0/2f96c11_1702981208746-lettresdamour.png',
#  'title': 'Les secrets des lettres d’amour de 1758'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/0/0/6857/4571/110/73/60/0/24c65af_1702893840549-0045.jpg',
#  'title': 'A la Fondation Pernod Ricard, Josèfa Ntjam, chantre geek '
#           'afrofuturiste'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/12/574/0/3000/2000/110/73/60/0/c7f8645_1702387310345-lin-adi6549-image-1.jpg',
#  'title': 'A la redécouverte du chien laineux'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/04/11/1330/0/4065/2710/110/73/60/0/e33a7f7_1681203848766-lepoque-lemonde-heleneblanc-fondbleu.jpg',
#  'title': 'Amours de jeunesse : « Il est habillé comme l’as de pique, mais son '
#           'charme opère une deuxième fois »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/13/0/0/5616/3744/110/73/60/0/c7b13bf_1702480942755-000-par8039694.jpg',
#  'title': 'Jacques Genin, chocolatier au grand cœur, se confie dans « A voix '
#           'nue », sur France Culture'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/1441/0/4000/2666/110/73/60/0/b2a16c5_1702917040489-079-img2200667203.jpg',
#  'title': '« Et le son fut ! », sur France Culture : « LSD, la série '
#           'documentaire » nous en met plein les oreilles'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/14/1/0/7044/4696/110/73/60/0/db04047_1702566203113-ni202311170243.jpg',
#  'title': '« Plus belle la vie » revient, en faisant le pari d’être « encore '
#           'plus belle » sur TF1'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/15/759/0/2859/1906/110/73/60/0/59c7c0b_1702632488674-couverture-3d-petits-grands-gai-teaux-de-nos-rei-gions.jpg',
#  'title': 'Cinq livres gourmands pour croquer Noël à pleines dents (2/2)'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/15/0/6/5958/3972/110/73/60/0/ff3de89_1702645651306-23-antichambre-031.jpg',
#  'title': 'Avec « Antichambre », Stereoptik crée un poème visuel et musical '
#           'plein de délicatesse pour jeune public'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/07/442/0/3307/2204/110/73/60/0/0cca5d5_1701941463472-81a1367-copie.jpg',
#  'title': 'Le champagne de vignerons, une autre façon de faire'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/352/0/2504/1669/110/73/60/0/b06c8f8_1702907369353-itar-fresh-batignolles-balcon-prefa.jpg',
#  'title': 'Le grand retour du préfabriqué dans la construction'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/13/1971/0/4733/3155/110/73/60/0/2259025_1702468245404-inima-restaurant-32.jpg',
#  'title': 'Le menu végétarien de la cheffe Oxana Cretu pour fêter Noël à la '
#           'moldave'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/08/0/0/1600/1066/110/73/60/0/99b2b8c_1702051105771-5202283.jpg',
#  'title': 'Face aux super-héros, la flamme nostalgique des grands du cinéma '
#           'américain'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/0/0/5314/3543/110/73/60/0/a07d66e_1702918956816-gettyimages-496655509.jpg',
#  'title': 'Pour protéger son cœur, manger à la bonne heure'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/0/0/1800/1200/110/73/60/0/e3c739b_1702913005539-series-2023.png',
#  'title': '« Succession », « Sambre », « Silo » : les meilleures séries de '
#           '2023'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/13/147/0/3543/2362/110/73/60/0/8ed5871_1702470895370-felder-009.jpg',
#  'title': 'Le pain d’épices de Christophe Felder : « La satisfaction de '
#           'fabriquer un gâteau classique dans les règles de l’art »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/07/0/0/2496/1664/110/73/60/0/cf1246f_1701967147110-img-0812.jpeg',
#  'title': 'Des crémants dans presque toutes les régions de France'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/179/0/4306/2870/110/73/60/0/b3f1cef_1702889062594-bios-2455329.jpg',
#  'title': 'L’odyssée de la langue, cet organe singulier'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/15/0/0/6000/4000/110/73/60/0/19e2dd4_413616f1dcf4491b90e721ce153c7d0a-0-ef30caa3e152473e9b9ce50816263895.jpg',
#  'title': 'Shohei Ohtani, le prince du « yakyu » japonais, devenu roi du '
#           'base-ball américain'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/18/0/139/832/555/110/73/60/0/d5167f2_1702906894750-scie-5023-anatomie-de-la-langue-media-d-appel-3.png',
#  'title': 'Notre langue, ciseleuse hors pair de la parole'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/17/0/8/4272/2848/110/73/60/0/6425eb9_1702849682103-bios-492316.jpg',
#  'title': 'Râpeuse, extensible, bifide ou adhésive : quatre langues '
#           'extraordinaires'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/12/476/0/3840/2560/110/73/60/0/1330ab9_1702389764965-alexandra-alvarez-garcia-maria-grazia-chiuri-library-01-12-2023-17a0780.jpg',
#  'title': 'Maria Grazia Chiuri, directrice artistique de Dior femme : « Je '
#           'suis obsédée par la légèreté des vêtements »'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/15/455/0/2441/1627/110/73/60/0/d3c801b_1702649215398-p67-portra400-137-helias-lake-portrait-mid-credit-jerome-tanon.jpg',
#  'title': 'Alpinisme : Hélias Millerioux et le Nuptse, la montagne d’une vie'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/17/470/447/6414/4276/110/73/60/0/517cf59_5144171-01-06.jpg',
#  'title': 'Mondial féminin de handball 2023 : l’équipe de France, tombeuse de '
#           'la Norvège en finale, s’avance en favorite aux Jeux olympiques de '
#           'Paris'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/16/200/0/1200/800/110/73/60/0/6587a50_1702718614947-alela-diane.jpg',
#  'title': 'Nos choix de chansons et d’albums de Noël : Alela Diane, Nils '
#           'Landgren, Brenda Lee, Gregory Porter…'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/15/0/625/3375/2250/110/73/60/0/d8cd041_1702646101531-byebyetibc3a9riade-2.jpg',
#  'title': '« Bye Bye Tibériade », sur Arte.tv : l’album de famille et le livre '
#           'd’histoire de Lina Soualem'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/14/0/0/3000/2000/110/73/60/0/8342f79_1702556059658-colosseo-nuovadomus-carosello7.jpeg',
#  'title': 'La découverte à Rome d’une spectaculaire mosaïque antique, composée '
#           'de coquillages, de fragments de verre et de marbre'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/le-fil-good/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/11/104/0/1500/1000/110/73/60/0/a734f1d_316123-3351140.jpg',
#  'title': 'L’Asie, aux petits bonheurs et à livre ouvert'}
# 2023-12-20 14:13:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sciences/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/04/27/0/0/4253/2835/110/73/60/0/a40be1e_1682585330590-2d85c17-1680106845701-le-monde-tribune-def-01.jpg',
#  'title': 'Pesticides : « L’Anses doit s’appuyer sur toutes les données '
#           'scientifiques non biaisées par des conflits d’intérêts »'}
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/les-decodeurs/> (referer: https://www.lemonde.fr)
# 2023-12-20 14:13:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/actualite-en-continu/> (referer: https://www.lemonde.fr)
# ...
#           'de la communauté juive'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/15/22/0/1000/666/110/73/60/0/1708422_1700061301885-802fed1ed1fafd88cf68cf3b13438a64-pcu-cimetiere-allemand-de-moulin-sous-touvent-2-1000x710.jpeg',
#  'title': 'Antisémitisme : dix stèles juives dégradées dans un cimetière '
#           'militaire allemand de l’Oise'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/14/0/0/4999/3333/110/73/60/0/ed9750f_1699980468862-ad044contreantisemitisme-dsc03112.jpg',
#  'title': 'Antisémitisme : 1 518 actes recensés en France depuis le 7 octobre, '
#           'peu de condamnations'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/projet-de-loi-immigration/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/05/3/0/5900/3933/110/73/60/0/fb59212_1701818301407-jmug231205017.jpg',
#  'title': 'Immigration : l’examen du projet de loi menacé par une motion de '
#           'rejet à l’Assemblée nationale'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/projet-de-loi-immigration/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/07/0/0/7408/4938/110/73/60/0/1c99c62_5057794-01-06.jpg',
#  'title': 'Projet de loi « immigration » : Eric Ciotti refuse de voter le '
#           'projet de loi du gouvernement'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/projet-de-loi-immigration/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/03/17/3/0/5900/3933/110/73/60/0/d958da4_1679036591828-jmug230316046.jpg',
#  'title': 'Claire Hédon, Défenseure des droits : « Le projet de “loi '
#           'immigration”, un texte d’une gravité majeure pour les droits '
#           'fondamentaux »'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/projet-de-loi-immigration/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/05/3/0/5900/3933/110/73/60/0/2e43c72_1701818297979-jmug231205012.jpg',
#  'title': 'Projet de loi « immigration » : la droite affiche ses divisions '
#           'avant l’examen du texte à l’Assemblée'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/projet-de-loi-immigration/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/05/3/0/5900/3933/110/73/60/0/45748ba_1701818309606-jmug231205023.jpg',
#  'title': 'Projet de loi sur l’immigration : « Dans quelle France allons-nous '
#           'nous réveiller demain ? »'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/10/0/0/4723/3149/110/73/60/0/745d314_1702242238824-vdsc1920-a-12-23.jpg',
#  'title': 'En Cisjordanie, l’Autorité palestinienne sous la pression '
#           'sécuritaire d’Israël depuis l’attaque du 7 octobre'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/10/0/0/4605/3070/110/73/60/0/787ea0e_1702234760643-000-8pl7fy.jpg',
#  'title': 'Valérie Pécresse retire le prix Simone-Veil à la journaliste Zineb '
#           'El Rhazoui pour un post sur Israël'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/28/416/0/3000/2000/110/73/60/0/8638b5c_44ed7ba1273d4e2f87da2b37455bb4a1-0-5d9222f07e734cc58a2263f215ce961d.jpg',
#  'title': 'La frégate française « Languedoc » a abattu deux drones provenant '
#           'du Yémen en mer Rouge'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/12/06/0/27/1446/964/110/73/60/0/35f4f99_315701-3350673.jpg',
#  'title': '« Shttl », un film happé par l’histoire'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/12/0/0/6000/4000/110/73/60/0/1e9530b_1699831220478-cbi1153053.jpg',
#  'title': '« On ne peut comprendre la diffusion de l’antisémitisme économique '
#           'sans étudier concrètement le monde du commerce et ses pratiques »'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/12/0/0/6000/4000/110/73/60/0/667a93d_1699831193349-cbi1153034.jpg',
#  'title': 'Chiffres de l’antisémitisme : la Grande Mosquée de Paris se '
#           'désolidarise des propos de l’un de ses imams'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/13/0/0/7000/4666/110/73/60/0/374a400_1699888267495-901493.jpg',
#  'title': 'Antisémitisme : Emmanuel Macron demande aux cultes de l’« empathie '
#           '» et « un effort pédagogique » envers les jeunes'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/13/0/0/5515/3676/110/73/60/0/7c419a5_5863910-01-06.jpg',
#  'title': 'Emmanuel Macron appelle les cultes à un « effort pédagogique » '
#           'auprès des jeunes'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/26/0/0/7755/5170/110/73/60/0/8d96011_773a6a796e1e45038b2374f069278b43-0-1bf17a20754a4c0fbfb8d47629c20ad8.jpg',
#  'title': 'Chant antisémite dans le métro parisien : huit adolescents en garde '
#           'à vue'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/03/1486/1201/3315/2210/110/73/60/0/2069cff_2023-11-03t164107z-400828605-rc2s54a6xbzz-rtrmadp-3-europe-weather-france-macron.JPG',
#  'title': 'Emmanuel Macron, un absent omniprésent de la marche contre '
#           'l’antisémitisme'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/12/0/0/4999/3333/110/73/60/0/f18384e_1699828910607-ad017contreantisemitisme-dsc02886.jpg',
#  'title': 'Marche contre l’antisémitisme : les leçons politiques d’une '
#           'manifestation apolitique'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/12/0/0/4999/3333/110/73/60/0/221fa23_1699828871909-ad008contreantisemitisme-dsc02777.jpg',
#  'title': 'Marche contre l’antisémitisme : une foule compacte, digne, '
#           'soucieuse de « montrer aux juifs de France qu’ils ne sont pas seuls '
#           '»'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/12/0/0/3403/2269/110/73/60/0/6c20428_2023-11-12t160315z-1179984280-rc2rb4aemc8x-rtrmadp-3-israel-palestinians-france-antisemitism.JPG',
#  'title': 'En vidéo : une foule immense a défilé contre l’antisémitisme à '
#           'Paris'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/12/0/0/1500/1000/110/73/60/0/bdd94e4_1699804682782-gj3a0702.jpg',
#  'title': 'Marche contre l’antisémitisme : plus de 182 000 personnes ont '
#           'défilé en France, dont 105 000 à Paris'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/09/14/0/4752/3168/110/73/60/0/a11a75d_a602b892b8a242289e3950d0253d900b-0-a97fc08906d046c4860d8a2079f1a66c.jpg',
#  'title': 'Grégoire Kauffmann, historien : « La présence sidérante du RN à la '
#           'manifestation contre l’antisémitisme est le signe d’une profonde '
#           'recomposition du jeu politique »'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/11/145/0/1600/1066/110/73/60/0/f84d6f2_1699702249862-photo-2023-11-11-12-16-19-1.jpg',
#  'title': 'Emmanuel Macron prône « l’unité » face à « une insupportable '
#           'résurgence » de l’antisémitisme'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/10/0/0/5625/3750/110/73/60/0/1721b31_1699627393015-000-32le4q2.jpg',
#  'title': 'Chems-Eddine Hafiz, recteur de la Grande Mosquée de Paris : « C’est '
#           'l’heure du choix : pas entre les musulmans et les juifs, pas entre '
#           'Israël et la Palestine, mais entre l’humanisme et l’horreur »'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/10/1/0/4881/3254/110/73/60/0/6ecfc61_1699645844625-181171.jpg',
#  'title': 'Emmanuel Macron ne se rendra pas à la marche contre '
#           'l’antisémitisme, mais salue des rassemblements qui sont « un motif '
#           'd’espérance »'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/10/11/0/1109/739/110/73/60/0/5c583ed_1699625622078-thomas-chopard-copie.jpg',
#  'title': 'Images de la Shoah : regards d’historiens'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/24/0/0/4999/3333/110/73/60/0/7bbfd38_1698132631094-bg-manifgazaparis-17006.JPG',
#  'title': 'Marche contre l’antisémitisme : La France insoumise isolée au sein '
#           'de la gauche'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/09/0/0/3000/2000/110/73/60/0/72a0263_1699545962074-008-feb2990.jpg',
#  'title': 'Nonna Mayer : « Les stéréotypes antisémites gardent un certain '
#           'impact dans une petite partie de la gauche »'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/09/0/0/3681/2454/110/73/60/0/0a9d976_1699546810074-181502.jpg',
#  'title': 'Marche contre l’antisémitisme : le dilemme d’Emmanuel Macron'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/31/1/0/8192/5461/110/73/60/0/1210b62_52aea18fdf1640d8875bcb65e7d85388-0-81760ae424974b8fb5611664eb6acf00.jpg',
#  'title': 'Jean Szlamowicz et Pierre-André Taguieff : « Israël est une nation '
#           'agressée depuis son origine par des pays qui veulent sa destruction '
#           'et l’annihilation de la souveraineté juive »'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/05/0/0/3000/2000/110/73/60/0/44378b2_1699188423362-ad030marchesoutienisrael-dsc09883.jpg',
#  'title': 'Le rejet de l’antisémitisme n’est pas négociable'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/08/60/0/1125/750/110/73/60/0/4d8b85f_1699440025496-web-634-mag-pardo-002.jpg',
#  'title': 'Jonas Pardo, celui qui veut déconstruire l’antisémitisme au sein de '
#           'la gauche'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/27/3/0/5900/3933/110/73/60/0/a59a031_1698423309378-jmug231026011.jpg',
#  'title': 'Avec la présence du RN, la « grande marche civique » contre '
#           'l’antisémitisme perturbe la gauche et la majorité présidentielle'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/08/0/0/7996/5330/110/73/60/0/c046c82_1699460509285-913742.jpg',
#  'title': 'Devant les francs-maçons, Emmanuel Macron fait l’éloge de la raison '
#           'face aux « porteurs de haine »'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/07/1/0/8192/5461/110/73/60/0/eddbc1f_1699378121526-000-33em994.jpg',
#  'title': '« Grande marche » contre l’antisémitisme : la venue du RN '
#           'embarrasse la gauche et la majorité'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/31/0/142/3546/2364/110/73/60/0/50429f9_1698756709501-maxbestof276211.jpeg',
#  'title': 'Maurice Lévy : « Jamais, depuis la Shoah, la communauté juive de '
#           'France ne s’était sentie aussi isolée »'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/10/12/0/0/5313/3542/110/73/60/0/9c9f431_2023-10-12t185731z-641330607-rc26r3aeofon-rtrmadp-3-israel-palestinians-france-flight.JPG',
#  'title': 'Le Quai d’Orsay ouvre une enquête administrative sur une ancienne '
#           'collaboratrice après la diffusion d’une vidéo dans laquelle elle '
#           'arrache des portraits d’otages israéliens'}
# 2023-12-20 14:13:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'description': None,
#  'image': 'https://img.lemde.fr/2023/11/07/1/0/8192/5461/110/73/60/0/eddbc1f_1699378121526-000-33em994.jpg',
#  'title': 'Antisémitisme : Gérard Larcher et Yaël Braun-Pivet appellent à une '
#           'marche, le RN annonce sa participation et LFI réserve sa réponse'}
# 2023-12-20 14:13:52 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-20 14:13:52 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 7458,
#  'downloader/request_count': 29,
#  'downloader/request_method_count/GET': 29,
#  'downloader/response_bytes': 2403653,
#  'downloader/response_count': 29,
#  'downloader/response_status_count/200': 29,
#  'elapsed_time_seconds': 1.682301,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 20, 13, 13, 52, 281766, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 9609472,
#  'httpcompression/response_count': 29,
#  'item_scraped_count': 1440,
#  'log_count/DEBUG': 1470,
#  'log_count/ERROR': 3,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'request_depth_max': 1,
#  'response_received_count': 29,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 28,
#  'scheduler/dequeued/memory': 28,
#  'scheduler/enqueued': 28,
#  'scheduler/enqueued/memory': 28,
#  'spider_exceptions/IndexError': 3,
#  'start_time': datetime.datetime(2023, 12, 20, 13, 13, 50, 599465, tzinfo=datetime.timezone.utc)}
# 2023-12-20 14:13:52 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Postprocessing
#
# Si l'on se réfère au diagramme d'architecture de Scrapy, on voit qu'il
# est possible d'insérer des composants supplémentaires dans le flux de
# traitement. Ces composants s'appellent `Pipelines`.
#
# Par défaut, tous les `Item` générés au sein d'un projet Scrapy passent
# par les `Pipelines`. Les pipelines sont utilisés la plupart du temps
# pour :
#
# -   Nettoyer du contenu HTML ;
# -   Valider les données scrapées ;
# -   Supprimer les items qu'on ne souhaite pas stocker ;
# -   Stocker ces objets dans des bases de données.
#
# Les pipelines doivent être définis dans le fichier `pipelines.py`.
#
# Dans notre cas on peut vouloir nettoyer le champ `title` pour enlever
# les caractères superflus.
#
# Nous allons alors transferer la fonction de nettoyage du code html dans
# une Pipeline.

# %%
# %load newscrawler/newscrawler/pipelines.py

# Define your item pipelines here
#
# Don't forget to add your pipeline to the ITEM_PIPELINES setting
# See: https://docs.scrapy.org/en/latest/topics/item-pipeline.html

from scrapy.exceptions import DropItem

class TextPipeline(object):

    def process_item(self, item, spider):
        if item['title']:
            item["title"] = clean_spaces(item["title"])
            return item
        else:
            raise DropItem("Missing title in %s" % item)


def clean_spaces(string):
    if string:
        return " ".join(string.split())

# %% [markdown]
# Pour dire au process Scrapy de faire transiter les items par ces
# pipelines. Il faut le spécifier dans le fichier de paramétrage
# `settings.py`.

# %%
ITEM_PIPELINES = {
     'newscrawler.pipelines.TextPipeline': 300,
 }

# %% [markdown]
# On peut maintenant supprimer la fonction `clean_spaces()` de
# l'extraction des données et laisser le Pipeline faire son travail. La
# valeur entière définie permet de déterminer l'ordre dans lequel les
# pipelines vont être appelés. Ces entiers peuvent être compris entre 0 et
# 1000.
#
# On relance notre spider :

# %%
scrapy crawl lemonde -o ../data/articles.json
# Out:
#   Cell In[40], line 1
#     scrapy crawl lemonde -o ../data/articles.json
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# On peut aussi utiliser les Pipelines pour stocker les données récupérées
# dans une base de données. Pour stocker les items dans des documents
# mongo :

# %%
import pymongo

class MongoPipeline(object):

    collection_name = 'scrapy_items'

    def open_spider(self, spider):
        self.client = pymongo.MongoClient()
        self.db = self.client["lemonde"]

    def close_spider(self, spider):
        self.client.close()

    def process_item(self, item, spider):
        self.db[self.collection_name].insert_one(dict(item))
        return item

# %% [markdown]
# Ici on redéfinit deux autres méthodes: `open_spider()`et
# `close_spider()`, ces méthodes sont appelées comme leur nom l'indique,
# lorsque la Spider est instanciée et fermée.
#
# Ces méthodes nous permettent d'ouvrir la connexion Mongo et de la fermer
# lorsque le scraping se termine. La méthode `process_item()` est appelé à
# chaque fois qu'un item passe dans le mécanisme interne de scrapy. Ici,
# la méthode permet d'insérer l'item en tant que document mongo.
#
# Pour que ce pipeline soit appelé il faut l'ajouter dans les settings du
# projet.

# %%
ITEM_PIPELINES = {
    'newscrawler.pipelines.TextPipeline': 100,
    'newscrawler.pipelines.MongoPipeline': 300
}

# %% [markdown]
# Le pipeline est ajoutée à la fin du process pour profiter des deux
# précédents.
#
# ## Settings
#
# Scrapy permet de gérer le comportement des spiders avec certains
# paramètres. Comme expliqué dans le premier cours, il est important de
# suivre des règles en respectant la structure des différents sites. Il
# existe énormément de paramètres mais nous allons (dans le cadre de ce
# cours) aborder les plus utilisés :
#
# -   DOWNLOAD\_DELAY : Le temps de téléchargement entre chaque requête
#     sur le même domaine ;
# -   CONCURRENT\_REQUESTS\_PER\_DOMAIN : Nombre de requêtes simultanées
#     par domaine ;
# -   CONCURRENT\_REQUESTS\_PER\_IP : Nombre de requêtes simultanées par
#     IP ;
# -   DEFAULT\_REQUEST\_HEADERS : Headers HTTP utilisés pour les requêtes
#     ;
# -   ROBOTSTXT\_OBEY : Scrapy récupère le robots.txt et adapte le
#     scraping en fonction des règles trouvées ;
# -   USER\_AGENT : UserAgent utilisé pour faire les requêtes ;
# -   BOT\_NAME : Nom du bot annoncé lors des requêtes
# -   HTTPCACHE\_ENABLED : Utilisation du cache HTTP, utile lors du
#     parcours multiple de la même page.
#
# Le fichiers `settings.py` permet de définir les paramètres globaux d'un
# projet. Si votre projet contient un grand nombre de spiders, il peut
# être intéressant d'avoir des paramètres distincts pour chaque spider. Un
# moyen simple est d'ajouter un attribut `custom_settings` à votre spider
# :

# %%
class LeMondeSpider(scrapy.Spider):
        name = "lemonde"
        allowed_domains = ["lemonde.fr"]
        start_urls = ['http://lemonde.fr/']
        custom_settings = {
            "HTTPCACHE_ENABLED":True, 
            "CONCURRENT_REQUESTS_PER_DOMAIN":100
        }
